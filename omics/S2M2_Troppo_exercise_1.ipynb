# %% [markdown]
# # S2M2
#
# ## Integrating Omics data into *Genome-Scale Metabolic Models (GEMs)* with *Troppo*
#
#
# High-throughput data from various omics fields can be integrated into *GEMs* to improve phenotype prediction. This approach aims to either further constrain the solution space or create context-specific models from generic *GEMs*.
# When considering omics data to integrate into models, transcriptomics appears as the most used. Transcript profiles describe the expression under specific conditions for all known genes of the studied organism. Moreover, it is the most accessible to obtain experimentally and already has well-established techniques, such as microarrays and RNA-seq.
#
# ## *Troppo*
#
# Troppo (Tissue-specific RecOnstruction and Phenotype Prediction using Omics data) is a Python package containing methods for tissue specific reconstruction to use with constraint-based models.
#
# The current methods implemented are:
# - FastCORE
# - CORDA
# - GIMME
# - (t)INIT
# - iMAT

# %% [markdown]
# # How to use *GIMME* with *Troppo*
#
# A typical workflow follows two main steps. The first is to attribute a score to each reaction of the model, in accordance with the omics data imputed. The second is to use the scores and apply an integration method to select a subset of reactions to build the final model.
#
# Integration scoring methods implemented in *Troppo* are:
# - continuous: `ContinuousScoreIntegrationStrategy`
# - threshold: `ThresholdSelectionIntegrationStrategy`
# - default_core: `DefaultCoreIntegrationStrategy`
# - adjusted_score: `AdjustedScoreIntegrationStrategy`
# - custom: `CustomSelectionIntegrationStrategy`
#
# Omics integration methods implemented in *Troppo* are:
# - gimme: `GIMME`
# - tinit: `tINIT`
# - fastcore: `GIMME`
# - imat: `IMAT`
# - swiftcore: `SWIFTCORE`
# - corda: `CORDA`
#
# This example can be applied for all the Omics integration methods implemented in this package. Note that the appropriate integration scoring method can differ between integration algorithms. For instance, for *GIMME* a continuous scoring method can be used, while for `fastcore` a threshold scoring method is more adequate.
#
# ### Imports and Setup

# %%
import pandas as pd
import numpy as np
import cobra
import re

from troppo.omics.readers.generic import TabularReader
from troppo.methods_wrappers import ModelBasedWrapper, ReconstructionWrapper
from troppo.omics.integration import ContinuousScoreIntegrationStrategy, CustomSelectionIntegrationStrategy
from troppo.methods.reconstruction.gimme import GIMME, GIMMEProperties
from cobamp.utilities.parallel import batch_run
from copy import deepcopy
# Out:
# C:\Users\biosy\anaconda3\envs\s2m2\lib\site-packages\cobamp\wrappers\external_wrappers.py:12: UserWarning:
# The wrappers.external_wrappers module will be deprecated in a future release in favour of the wrappers module.
#     Available ModelObjectReader classes can still be loaded using cobamp.wrappers.<class>. An appropriate model
#     reader can also be created using the get_model_reader function on cobamp.wrappers
#   reader can also be created using the get_model_reader function on cobamp.wrappers''')

# %% [markdown]
# ### Initial Setup

# %% [markdown]
# Define the parsing rules for the GPRs that will be used later on.

# %%
patt = re.compile('__COBAMPGPRDOT__[0-9]{1}')
replace_alt_transcripts = lambda x: patt.sub('', x)

# %% [markdown]
# #### Read model and omics data
#
# You have to download the .csv file containing the gene expression for breast cancer cell lines present in the CCLE panel. The nomenclature has been normalized for what is found in the metabolic model of this exercise.

# %%
model = cobra.io.load_matlab_model('data/redHUMAN_recon2_smin.mat')
model
# Out:
# This model seems to have metCharge instead of metCharges field. Will use metCharge for what metCharges represents.
# No defined compartments in model redHUMAN_recon2_smin_02Sep2019_135437. Compartments will be deduced heuristically using regular expressions.
# Using regular expression found the following compartments:c, e, l, m, n, r, x
# <Model redHUMAN_recon2_smin_02Sep2019_135437 at 0x1923e805f48>

# %% [markdown]
# For future usage, note that the dataset that will be used as input in *Troppo* needs to have the samples as rows and gene IDs in the columns.

# %%
omics_data = pd.read_csv('data/CCLE_breast_cancer_expression.csv', index_col=0)
omics_data.shape
# Out:
# (56, 579)

# %% [markdown]
# ### Create a container for the omics data.
#
# The `TabularReader` class is used to read and store the omics data in a container that can then be used by *Troppo*.
#
# Relevant arguments from the `TabularReader` class:
# - `path_or_df`: the omics data can be either a pandas dataframe or a path to a dataset file. The file can be in any format supported by pandas.
# - `index_col`: the name of the column that contains the identifiers of the genes.
# - `sample_in_rows`: a boolean indicating whether the samples are in rows or columns.
# - `header_offset`: the number of rows to skip before reading the header.
# - `omics_type`: a string containing the type of omics data. This is used to select the appropriate integration method.
# - `nomenclature`: a string containing the nomenclature of the identifiers in the omics data. This is used to map the identifiers to the identifiers in the model.
#
# The `to_containers()` method returns a list of containers, one for each sample of the dataset. In this example, we will be using only one sample, however, the process can be iterated for all the samples in the dataset.
# The `get_integrated_data_map()` method is used to map the identifiers in the omics data to the identifiers in the model. This is done by using the `gpr_gene_parse_function` argument from the `ModelBasedWrapper` class.

# %%
omics_container = TabularReader(path_or_df=omics_data, nomenclature='entrez_id', omics_type='transcriptomics').to_containers()
omics_container
# Out:
# [<troppo.omics.core.OmicsContainer at 0x19230715488>,
#  <troppo.omics.core.OmicsContainer at 0x1924086f6c8>,
#  <troppo.omics.core.OmicsContainer at 0x1923ff296c8>,
#  <troppo.omics.core.OmicsContainer at 0x1924086f7c8>,
#  <troppo.omics.core.OmicsContainer at 0x1924020f588>,
#  <troppo.omics.core.OmicsContainer at 0x1924020fec8>,
#  <troppo.omics.core.OmicsContainer at 0x1924020ff08>,
#  <troppo.omics.core.OmicsContainer at 0x1924020f5c8>,
#  <troppo.omics.core.OmicsContainer at 0x1924020fb88>,
#  <troppo.omics.core.OmicsContainer at 0x1924020f148>,
#  <troppo.omics.core.OmicsContainer at 0x1924020f488>,
#  <troppo.omics.core.OmicsContainer at 0x1924020f108>,
#  <troppo.omics.core.OmicsContainer at 0x1924020f808>,
#  <troppo.omics.core.OmicsContainer at 0x1924020ffc8>,
#  <troppo.omics.core.OmicsContainer at 0x1924020f7c8>,
#  <troppo.omics.core.OmicsContainer at 0x1924020f888>,
#  <troppo.omics.core.OmicsContainer at 0x1924020f9c8>,
#  <troppo.omics.core.OmicsContainer at 0x1924020f0c8>,
#  <troppo.omics.core.OmicsContainer at 0x19240a0c9c8>,
#  <troppo.omics.core.OmicsContainer at 0x1924020f348>,
#  <troppo.omics.core.OmicsContainer at 0x1924020f548>,
#  <troppo.omics.core.OmicsContainer at 0x1924020fa88>,
#  <troppo.omics.core.OmicsContainer at 0x19240c48e48>,
#  <troppo.omics.core.OmicsContainer at 0x1923ff14708>,
#  <troppo.omics.core.OmicsContainer at 0x19240c48fc8>,
#  <troppo.omics.core.OmicsContainer at 0x19230a72108>,
#  <troppo.omics.core.OmicsContainer at 0x192404e5f88>,
#  <troppo.omics.core.OmicsContainer at 0x1923ff14048>,
#  <troppo.omics.core.OmicsContainer at 0x19230afe808>,
#  <troppo.omics.core.OmicsContainer at 0x1923ff14b88>,
#  <troppo.omics.core.OmicsContainer at 0x1927ae585c8>,
#  <troppo.omics.core.OmicsContainer at 0x19231596088>,
#  <troppo.omics.core.OmicsContainer at 0x19230ab6f48>,
#  <troppo.omics.core.OmicsContainer at 0x19231596488>,
#  <troppo.omics.core.OmicsContainer at 0x1924020fa48>,
#  <troppo.omics.core.OmicsContainer at 0x19231596f88>,
#  <troppo.omics.core.OmicsContainer at 0x1924020fe48>,
#  <troppo.omics.core.OmicsContainer at 0x1923fed5948>,
#  <troppo.omics.core.OmicsContainer at 0x1923fed5488>,
#  <troppo.omics.core.OmicsContainer at 0x1923fed5508>,
#  <troppo.omics.core.OmicsContainer at 0x1923fed5b08>,
#  <troppo.omics.core.OmicsContainer at 0x1923fed5908>,
#  <troppo.omics.core.OmicsContainer at 0x1923fed5fc8>,
#  <troppo.omics.core.OmicsContainer at 0x1923fed5d88>,
#  <troppo.omics.core.OmicsContainer at 0x19230acd4c8>,
#  <troppo.omics.core.OmicsContainer at 0x19230acdcc8>,
#  <troppo.omics.core.OmicsContainer at 0x1923fed5b48>,
#  <troppo.omics.core.OmicsContainer at 0x19230acdf48>,
#  <troppo.omics.core.OmicsContainer at 0x19230a64488>,
#  <troppo.omics.core.OmicsContainer at 0x19230a0c7c8>,
#  <troppo.omics.core.OmicsContainer at 0x19230a64608>,
#  <troppo.omics.core.OmicsContainer at 0x19230a0c2c8>,
#  <troppo.omics.core.OmicsContainer at 0x19230a0c088>,
#  <troppo.omics.core.OmicsContainer at 0x1923fed5dc8>,
#  <troppo.omics.core.OmicsContainer at 0x1923fed5348>,
#  <troppo.omics.core.OmicsContainer at 0x1923fed5608>]

# %%
single_sample = omics_container[0]

# %%
print(single_sample)
# Out:
# transcriptomics container
# Condition: ACH-000017
# Nomenclature: entrez_id
# 579 Expression Values

# %% [markdown]
# ### Create a model wrapper.
#
# The `ModelBasedWrapper` class is used to wrap the model so that it can be used by *Troppo*.
#
# Relevant arguments from this class include:
# - `model`: the model to be wrapped.
# - `ttg_ratio`: the ratio between the number of reactions to be selected and the total number of reactions in the model.
# - `gpr_gene_parse_function`: a function that parses the GPRs of the model. This is used to map the identifiers in the omics data to the identifiers in the model.
#
# Important attributes from this class include:
# - `model_reader`: a COBRAModelObjectReader instance containing all the information of the model, such as, reaction_ids, metabolite_ids, GPRs, bounds, etc.
# - `S`: the stoichiometric matrix of the model.
# - `lb`: the lower bounds of the reactions in the model.
# - `ub`: the upper bounds of the reactions in the model.
#
# In this specific example we will use the `ReconstructionWrapper` class instead of the base `ModelBasedWrapper` class.

# %%
model_wrapper = ReconstructionWrapper(model=model, ttg_ratio=9999, gpr_gene_parse_function=replace_alt_transcripts)
model_wrapper
# Out:
# C:\Users\biosy\anaconda3\envs\s2m2\lib\site-packages\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: _10993
#   warnings.warn('Could not normalize this rule: ' + rule)
# C:\Users\biosy\anaconda3\envs\s2m2\lib\site-packages\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: _89874
#   warnings.warn('Could not normalize this rule: ' + rule)
# C:\Users\biosy\anaconda3\envs\s2m2\lib\site-packages\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: _57835 or _8671 or _57835 or _57835 or _57835
#   warnings.warn('Could not normalize this rule: ' + rule)
# C:\Users\biosy\anaconda3\envs\s2m2\lib\site-packages\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: (_4967 and (_1738 and _8050) and _1743) or (_4967 and (_1738 and _8050) and _1743)
#   warnings.warn('Could not normalize this rule: ' + rule)
# C:\Users\biosy\anaconda3\envs\s2m2\lib\site-packages\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: _3242
#   warnings.warn('Could not normalize this rule: ' + rule)
# C:\Users\biosy\anaconda3\envs\s2m2\lib\site-packages\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: _18 or _18
#   warnings.warn('Could not normalize this rule: ' + rule)
# C:\Users\biosy\anaconda3\envs\s2m2\lib\site-packages\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: _23498
#   warnings.warn('Could not normalize this rule: ' + rule)
# C:\Users\biosy\anaconda3\envs\s2m2\lib\site-packages\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: _51166 or _883 or _51166
#   warnings.warn('Could not normalize this rule: ' + rule)
# C:\Users\biosy\anaconda3\envs\s2m2\lib\site-packages\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: _10165 or _8604
#   warnings.warn('Could not normalize this rule: ' + rule)
# C:\Users\biosy\anaconda3\envs\s2m2\lib\site-packages\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: _2805
#   warnings.warn('Could not normalize this rule: ' + rule)
# C:\Users\biosy\anaconda3\envs\s2m2\lib\site-packages\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: _2806
#   warnings.warn('Could not normalize this rule: ' + rule)
# C:\Users\biosy\anaconda3\envs\s2m2\lib\site-packages\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: _2348 or _2348 or _2348 or _2348 or _2352 or _2348 or _2348
#   warnings.warn('Could not normalize this rule: ' + rule)
# C:\Users\biosy\anaconda3\envs\s2m2\lib\site-packages\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: _6573 or _6573
#   warnings.warn('Could not normalize this rule: ' + rule)
# C:\Users\biosy\anaconda3\envs\s2m2\lib\site-packages\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: _65985
#   warnings.warn('Could not normalize this rule: ' + rule)
# C:\Users\biosy\anaconda3\envs\s2m2\lib\site-packages\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: _8639
#   warnings.warn('Could not normalize this rule: ' + rule)
# C:\Users\biosy\anaconda3\envs\s2m2\lib\site-packages\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: _51166 or _51166
#   warnings.warn('Could not normalize this rule: ' + rule)
# C:\Users\biosy\anaconda3\envs\s2m2\lib\site-packages\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: _223
#   warnings.warn('Could not normalize this rule: ' + rule)
# C:\Users\biosy\anaconda3\envs\s2m2\lib\site-packages\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: _206358
#   warnings.warn('Could not normalize this rule: ' + rule)
# C:\Users\biosy\anaconda3\envs\s2m2\lib\site-packages\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: _6529 or _6538 or _6540 or _6539
#   warnings.warn('Could not normalize this rule: ' + rule)
# C:\Users\biosy\anaconda3\envs\s2m2\lib\site-packages\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: _38 or _3032 or _10449
#   warnings.warn('Could not normalize this rule: ' + rule)
# C:\Users\biosy\anaconda3\envs\s2m2\lib\site-packages\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: _39
#   warnings.warn('Could not normalize this rule: ' + rule)
# C:\Users\biosy\anaconda3\envs\s2m2\lib\site-packages\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: _6566 or _9194
#   warnings.warn('Could not normalize this rule: ' + rule)
# C:\Users\biosy\anaconda3\envs\s2m2\lib\site-packages\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: _6566
#   warnings.warn('Could not normalize this rule: ' + rule)
# C:\Users\biosy\anaconda3\envs\s2m2\lib\site-packages\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: _6566 or _9123 or _9194
#   warnings.warn('Could not normalize this rule: ' + rule)
# C:\Users\biosy\anaconda3\envs\s2m2\lib\site-packages\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: _47 or _47
#   warnings.warn('Could not normalize this rule: ' + rule)
# C:\Users\biosy\anaconda3\envs\s2m2\lib\site-packages\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: _36 or _34
#   warnings.warn('Could not normalize this rule: ' + rule)
# C:\Users\biosy\anaconda3\envs\s2m2\lib\site-packages\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: _34 or _27034
#   warnings.warn('Could not normalize this rule: ' + rule)
# C:\Users\biosy\anaconda3\envs\s2m2\lib\site-packages\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: _134526
#   warnings.warn('Could not normalize this rule: ' + rule)
# C:\Users\biosy\anaconda3\envs\s2m2\lib\site-packages\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: _3658 or _48
#   warnings.warn('Could not normalize this rule: ' + rule)
# C:\Users\biosy\anaconda3\envs\s2m2\lib\site-packages\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: _50 or _48
#   warnings.warn('Could not normalize this rule: ' + rule)
# C:\Users\biosy\anaconda3\envs\s2m2\lib\site-packages\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: _65985 or _55902 or _55902
#   warnings.warn('Could not normalize this rule: ' + rule)
# C:\Users\biosy\anaconda3\envs\s2m2\lib\site-packages\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: _84532
#   warnings.warn('Could not normalize this rule: ' + rule)
# C:\Users\biosy\anaconda3\envs\s2m2\lib\site-packages\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: _1571
#   warnings.warn('Could not normalize this rule: ' + rule)
# C:\Users\biosy\anaconda3\envs\s2m2\lib\site-packages\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: _112611 or _98 or _97 or _97
#   warnings.warn('Could not normalize this rule: ' + rule)
# C:\Users\biosy\anaconda3\envs\s2m2\lib\site-packages\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: _3177
#   warnings.warn('Could not normalize this rule: ' + rule)
# C:\Users\biosy\anaconda3\envs\s2m2\lib\site-packages\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: _122481 or _203 or _26289 or _26289 or _204
#   warnings.warn('Could not normalize this rule: ' + rule)
# C:\Users\biosy\anaconda3\envs\s2m2\lib\site-packages\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: _205 or _205 or _204 or _204 or _204 or _205
#   warnings.warn('Could not normalize this rule: ' + rule)
# C:\Users\biosy\anaconda3\envs\s2m2\lib\site-packages\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: _26289 or _26289
#   warnings.warn('Could not normalize this rule: ' + rule)
# C:\Users\biosy\anaconda3\envs\s2m2\lib\site-packages\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: _50808
#   warnings.warn('Could not normalize this rule: ' + rule)
# C:\Users\biosy\anaconda3\envs\s2m2\lib\site-packages\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: _262
#   warnings.warn('Could not normalize this rule: ' + rule)
# C:\Users\biosy\anaconda3\envs\s2m2\lib\site-packages\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: _132 or _132
#   warnings.warn('Could not normalize this rule: ' + rule)
# C:\Users\biosy\anaconda3\envs\s2m2\lib\site-packages\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: _353
#   warnings.warn('Could not normalize this rule: ' + rule)
# C:\Users\biosy\anaconda3\envs\s2m2\lib\site-packages\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: _64902 or _64850
#   warnings.warn('Could not normalize this rule: ' + rule)
# C:\Users\biosy\anaconda3\envs\s2m2\lib\site-packages\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: _191 or _10768 or _10768
#   warnings.warn('Could not normalize this rule: ' + rule)
# C:\Users\biosy\anaconda3\envs\s2m2\lib\site-packages\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: _8402 or _1468
#   warnings.warn('Could not normalize this rule: ' + rule)
# C:\Users\biosy\anaconda3\envs\s2m2\lib\site-packages\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: _64849 or _64849
#   warnings.warn('Could not normalize this rule: ' + rule)
# C:\Users\biosy\anaconda3\envs\s2m2\lib\site-packages\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: _6510
#   warnings.warn('Could not normalize this rule: ' + rule)
# C:\Users\biosy\anaconda3\envs\s2m2\lib\site-packages\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: _6509 or _6510
#   warnings.warn('Could not normalize this rule: ' + rule)
# C:\Users\biosy\anaconda3\envs\s2m2\lib\site-packages\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: _6520 and _56301
#   warnings.warn('Could not normalize this rule: ' + rule)
# C:\Users\biosy\anaconda3\envs\s2m2\lib\site-packages\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: _56301 and _6520
#   warnings.warn('Could not normalize this rule: ' + rule)
# C:\Users\biosy\anaconda3\envs\s2m2\lib\site-packages\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: _153201 or _206358
#   warnings.warn('Could not normalize this rule: ' + rule)
# C:\Users\biosy\anaconda3\envs\s2m2\lib\site-packages\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: _54407 or _6542 or _11254 or _6541 or _81539 or _55089 or _84889 or (_340024 and (_57393 or _59272))
#   warnings.warn('Could not normalize this rule: ' + rule)
# C:\Users\biosy\anaconda3\envs\s2m2\lib\site-packages\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: _2875 or _84706
#   warnings.warn('Could not normalize this rule: ' + rule)
# C:\Users\biosy\anaconda3\envs\s2m2\lib\site-packages\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: _92745 or _10991
#   warnings.warn('Could not normalize this rule: ' + rule)
# C:\Users\biosy\anaconda3\envs\s2m2\lib\site-packages\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: _115286 or _115286 or _115286
#   warnings.warn('Could not normalize this rule: ' + rule)
# C:\Users\biosy\anaconda3\envs\s2m2\lib\site-packages\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: _9057 and _6520
#   warnings.warn('Could not normalize this rule: ' + rule)
# C:\Users\biosy\anaconda3\envs\s2m2\lib\site-packages\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: _383 or _384
#   warnings.warn('Could not normalize this rule: ' + rule)
# C:\Users\biosy\anaconda3\envs\s2m2\lib\site-packages\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: _384
#   warnings.warn('Could not normalize this rule: ' + rule)
# C:\Users\biosy\anaconda3\envs\s2m2\lib\site-packages\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: _11254
#   warnings.warn('Could not normalize this rule: ' + rule)
# C:\Users\biosy\anaconda3\envs\s2m2\lib\site-packages\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: _6541 or _6542 or _55089 or _84889
#   warnings.warn('Could not normalize this rule: ' + rule)
# C:\Users\biosy\anaconda3\envs\s2m2\lib\site-packages\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: _83884 or _10166
#   warnings.warn('Could not normalize this rule: ' + rule)
# C:\Users\biosy\anaconda3\envs\s2m2\lib\site-packages\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: _440 or _440 or _440
#   warnings.warn('Could not normalize this rule: ' + rule)
# C:\Users\biosy\anaconda3\envs\s2m2\lib\site-packages\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: _81539 or _11254 or _54407 or _55089 or (_340024 and (_57393 or _59272))
#   warnings.warn('Could not normalize this rule: ' + rule)
# C:\Users\biosy\anaconda3\envs\s2m2\lib\site-packages\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: _8604 or _10165
#   warnings.warn('Could not normalize this rule: ' + rule)
# C:\Users\biosy\anaconda3\envs\s2m2\lib\site-packages\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: ((_513 and _498 and _506 and _509 and _514) or (_498 and _513 and _514 and _506 and _509) or (_513 and _509 and _498 and _514 and _506) or (_498 and _513 and _506 and _509 and _514) or (_513 and _498 and _514 and _506 and _509) or (_513 and _498 and _506 and _509 and _514) or (_513 and _498 and _514 and _506 and _509) or (_513 and _498 and _509 and _506 and _514) or (_498 and _509 and _513 and _506 and _514) or (_513 and _498 and _506 and _509 and _514) or (_513 and _514 and _506 and _509 and _498) or (_513 and _506 and _509 and _498 and _514) or (_513 and _509 and _506 and _498 and _514) or (_509 and _513 and _514 and _506 and _498) or (_513 and _498 and _509 and _514 and _506) or (_513 and _498 and _514 and _506 and _509) or (_513 and _509 and _498 and _506 and _514) or (_513 and _506 and _509 and _498 and _514) or (_509 and _513 and _506 and _498 and _514) or (_513 and _514 and _506 and _509 and _498) or (_509 and _513 and _498 and _506 and _514) or (_513 and _509 and _514 and _506 and _498) or (_498 and _509 and _513 and _514 and _506) or (_509 and _513 and _498 and _514 and _506)) and ((_10632 and _4905 and _10476 and _9551 and _522 and _516 and _521 and _515) or (_518 and _4905 and _515 and _10476 and _521 and _10632 and _9551 and _522) or (_4905 and _515 and _10476 and _521 and _10632 and _517 and _9551 and _522) or (_10632 and _4905 and _10476 and _522 and _9551 and _518 and _521 and _515) or (_4905 and _515 and _10476 and _516 and _521 and _10632 and _9551 and _522) or (_518 and _4905 and _9551 and _515 and _10476 and _521 and _10632 and _522) or (_10632 and _4905 and _10476 and _9551 and _522 and _515 and _518 and _521) or (_518 and _10632 and _4905 and _10476 and _515 and _9551 and _522 and _521) or (_10632 and _4905 and _10476 and _515 and _522 and _9551 and _518 and _521) or (_4905 and _9551 and _10476 and _522 and _516 and _521 and _515 and _10632) or (_10632 and _517 and _4905 and _10476 and _522 and _9551 and _521 and _515) or (_10632 and _4905 and _10476 and _9551 and _515 and _522 and _518 and _521) or (_10632 and _4905 and _516 and _9551 and _515 and _10476 and _522 and _521) or (_10632 and _4905 and _10476 and _9551 and _518 and _522 and _521 and _515) or (_4905 and _10476 and _521 and _515 and _10632 and _9551 and _522 and _518) or (_4905 and _9551 and _515 and _10476 and _516 and _521 and _10632 and _522) or (_10632 and _4905 and _516 and _10476 and _9551 and _522 and _521 and _515) or (_4905 and _10476 and _521 and _515 and _10632 and _522 and _518 and _9551) or (_4905 and _9551 and _10476 and _521 and _515 and _10632 and _518 and _522) or (_10632 and _517 and _4905 and _10476 and _9551 and _515 and _522 and _521) or (_4905 and _10476 and _522 and _521 and _515 and _10632 and _518 and _9551) or (_4905 and _522 and _515 and _10476 and _521 and _10632 and _517 and _9551) or (_10632 and _517 and _4905 and _10476 and _9551 and _522 and _521 and _515) or (_518 and _4905 and _515 and _10476 and _521 and _10632 and _9551 and _522) or (_10632 and _4905 and _10476 and _515 and _522 and _9551 and _518 and _521) or (_4905 and _9551 and _515 and _10476 and _521 and _10632 and _517 and _522) or (_4905 and _10476 and _516 and _521 and _515 and _10632 and _9551 and _522) or (_518 and _10632 and _4905 and _10476 and _9551 and _515 and _522 and _521) or (_10632 and _4905 and _516 and _9551 and _10476 and _522 and _521 and _515) or (_4905 and _515 and _522 and _10476 and _516 and _521 and _10632 and _9551) or (_4905 and _9551 and _515 and _10476 and _521 and _518 and _10632 and _522) or (_10632 and _517 and _4905 and _10476 and _9551 and _515 and _522 and _521) or (_10632 and _4905 and _516 and _515 and _10476 and _9551 and _522 and _521) or (_10632 and _4905 and _10476 and _517 and _515 and _522 and _9551 and _521) or (_10632 and _4905 and _516 and _10476 and _9551 and _522 and _521 and _515) or (_4905  ...
#   warnings.warn('Could not normalize this rule: ' + rule)
# C:\Users\biosy\anaconda3\envs\s2m2\lib\site-packages\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: _291 or _293 or _292
#   warnings.warn('Could not normalize this rule: ' + rule)
# C:\Users\biosy\anaconda3\envs\s2m2\lib\site-packages\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: _140679
#   warnings.warn('Could not normalize this rule: ' + rule)
# C:\Users\biosy\anaconda3\envs\s2m2\lib\site-packages\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: _23743 or _635
#   warnings.warn('Could not normalize this rule: ' + rule)
# C:\Users\biosy\anaconda3\envs\s2m2\lib\site-packages\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: _847
#   warnings.warn('Could not normalize this rule: ' + rule)
# C:\Users\biosy\anaconda3\envs\s2m2\lib\site-packages\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: _790
#   warnings.warn('Could not normalize this rule: ' + rule)
# C:\Users\biosy\anaconda3\envs\s2m2\lib\site-packages\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: _1373 or _1373
#   warnings.warn('Could not normalize this rule: ' + rule)
# C:\Users\biosy\anaconda3\envs\s2m2\lib\site-packages\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: _55349
#   warnings.warn('Could not normalize this rule: ' + rule)
# C:\Users\biosy\anaconda3\envs\s2m2\lib\site-packages\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: _60482
#   warnings.warn('Could not normalize this rule: ' + rule)
# C:\Users\biosy\anaconda3\envs\s2m2\lib\site-packages\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: _6582 or _6584 or _6582
#   warnings.warn('Could not normalize this rule: ' + rule)
# C:\Users\biosy\anaconda3\envs\s2m2\lib\site-packages\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: _19 or (_64240 and _64241)
#   warnings.warn('Could not normalize this rule: ' + rule)
# C:\Users\biosy\anaconda3\envs\s2m2\lib\site-packages\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: _10948
#   warnings.warn('Could not normalize this rule: ' + rule)
# C:\Users\biosy\anaconda3\envs\s2m2\lib\site-packages\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: _171425 or _171425
#   warnings.warn('Could not normalize this rule: ' + rule)
# C:\Users\biosy\anaconda3\envs\s2m2\lib\site-packages\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: _9058
#   warnings.warn('Could not normalize this rule: ' + rule)
# C:\Users\biosy\anaconda3\envs\s2m2\lib\site-packages\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: _6576
#   warnings.warn('Could not normalize this rule: ' + rule)
# C:\Users\biosy\anaconda3\envs\s2m2\lib\site-packages\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: _1159 or _1160 or _548596
#   warnings.warn('Could not normalize this rule: ' + rule)
# C:\Users\biosy\anaconda3\envs\s2m2\lib\site-packages\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: _1152 or (_1158 and _1152) or _1158
#   warnings.warn('Could not normalize this rule: ' + rule)
# C:\Users\biosy\anaconda3\envs\s2m2\lib\site-packages\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: _5172
#   warnings.warn('Could not normalize this rule: ' + rule)
# C:\Users\biosy\anaconda3\envs\s2m2\lib\site-packages\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: _65010 or _65010 or _65010
#   warnings.warn('Could not normalize this rule: ' + rule)
# C:\Users\biosy\anaconda3\envs\s2m2\lib\site-packages\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: _8034
#   warnings.warn('Could not normalize this rule: ' + rule)
# C:\Users\biosy\anaconda3\envs\s2m2\lib\site-packages\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: _6535 or _386757
#   warnings.warn('Could not normalize this rule: ' + rule)
# C:\Users\biosy\anaconda3\envs\s2m2\lib\site-packages\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: _1431 or _1431
#   warnings.warn('Could not normalize this rule: ' + rule)
# C:\Users\biosy\anaconda3\envs\s2m2\lib\site-packages\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: _1503 or _56474
#   warnings.warn('Could not normalize this rule: ' + rule)
# C:\Users\biosy\anaconda3\envs\s2m2\lib\site-packages\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: (_7384 and _7388 and _4519 and _29796 and _10975 and _7385 and _7386 and _1537 and _27089 and _7381) or (_7384 and _7388 and _4519 and _29796 and _10975 and _7385 and _1537 and _7386 and _27089 and _7381)
#   warnings.warn('Could not normalize this rule: ' + rule)
# C:\Users\biosy\anaconda3\envs\s2m2\lib\site-packages\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: (_6520 and _56301) or (_8140 and _6520)
#   warnings.warn('Could not normalize this rule: ' + rule)
# C:\Users\biosy\anaconda3\envs\s2m2\lib\site-packages\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: (_6520 and _23428) or (_6520 and _23428) or (_56301 and _6520)
#   warnings.warn('Could not normalize this rule: ' + rule)
# C:\Users\biosy\anaconda3\envs\s2m2\lib\site-packages\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: _1036
#   warnings.warn('Could not normalize this rule: ' + rule)
# C:\Users\biosy\anaconda3\envs\s2m2\lib\site-packages\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: _11254 or _54407 or (_340024 and (_57393 or _59272))
#   warnings.warn('Could not normalize this rule: ' + rule)
# C:\Users\biosy\anaconda3\envs\s2m2\lib\site-packages\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: _124935
#   warnings.warn('Could not normalize this rule: ' + rule)
# C:\Users\biosy\anaconda3\envs\s2m2\lib\site-packages\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: _1491 or _1491
#   warnings.warn('Could not normalize this rule: ' + rule)
# C:\Users\biosy\anaconda3\envs\s2m2\lib\site-packages\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: _875
#   warnings.warn('Could not normalize this rule: ' + rule)
# C:\Users\biosy\anaconda3\envs\s2m2\lib\site-packages\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: _64902
#   warnings.warn('Could not normalize this rule: ' + rule)
# C:\Users\biosy\anaconda3\envs\s2m2\lib\site-packages\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: _5860
#   warnings.warn('Could not normalize this rule: ' + rule)
# C:\Users\biosy\anaconda3\envs\s2m2\lib\site-packages\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: _29958
#   warnings.warn('Could not normalize this rule: ' + rule)
# C:\Users\biosy\anaconda3\envs\s2m2\lib\site-packages\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: _60386
#   warnings.warn('Could not normalize this rule: ' + rule)
# C:\Users\biosy\anaconda3\envs\s2m2\lib\site-packages\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: _669 or _5223 or _5224 or _5224 or _669
#   warnings.warn('Could not normalize this rule: ' + rule)
# C:\Users\biosy\anaconda3\envs\s2m2\lib\site-packages\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: _64080
#   warnings.warn('Could not normalize this rule: ' + rule)
# C:\Users\biosy\anaconda3\envs\s2m2\lib\site-packages\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: _1892 or (_3030 and _3032)
#   warnings.warn('Could not normalize this rule: ' + rule)
# C:\Users\biosy\anaconda3\envs\s2m2\lib\site-packages\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: _549 or (_3030 and _3032) or _1892
#   warnings.warn('Could not normalize this rule: ' + rule)
# C:\Users\biosy\anaconda3\envs\s2m2\lib\site-packages\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: _2023 or _2027 or _2027 or _2026
#   warnings.warn('Could not normalize this rule: ' + rule)
# C:\Users\biosy\anaconda3\envs\s2m2\lib\site-packages\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: _226 or _226 or _226 or _230 or _229
#   warnings.warn('Could not normalize this rule: ' + rule)
# C:\Users\biosy\anaconda3\envs\s2m2\lib\site-packages\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: _2203 or _8789
#   warnings.warn('Could not normalize this rule: ' + rule)
# C:\Users\biosy\anaconda3\envs\s2m2\lib\site-packages\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: _10840
#   warnings.warn('Could not normalize this rule: ' + rule)
# C:\Users\biosy\anaconda3\envs\s2m2\lib\site-packages\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: _125061
#   warnings.warn('Could not normalize this rule: ' + rule)
# C:\Users\biosy\anaconda3\envs\s2m2\lib\site-packages\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: _10841 or _10841
#   warnings.warn('Could not normalize this rule: ' + rule)
# C:\Users\biosy\anaconda3\envs\s2m2\lib\site-packages\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: _10840 or _160428
#   warnings.warn('Could not normalize this rule: ' + rule)
# C:\Users\biosy\anaconda3\envs\s2m2\lib\site-packages\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: _2271
#   warnings.warn('Could not normalize this rule: ' + rule)
# C:\Users\biosy\anaconda3\envs\s2m2\lib\site-packages\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: _2184
#   warnings.warn('Could not normalize this rule: ' + rule)
# C:\Users\biosy\anaconda3\envs\s2m2\lib\site-packages\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: _1468
#   warnings.warn('Could not normalize this rule: ' + rule)
# C:\Users\biosy\anaconda3\envs\s2m2\lib\site-packages\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: _2819
#   warnings.warn('Could not normalize this rule: ' + rule)
# C:\Users\biosy\anaconda3\envs\s2m2\lib\site-packages\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: _2820
#   warnings.warn('Could not normalize this rule: ' + rule)
# C:\Users\biosy\anaconda3\envs\s2m2\lib\site-packages\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: _5832
#   warnings.warn('Could not normalize this rule: ' + rule)
# C:\Users\biosy\anaconda3\envs\s2m2\lib\site-packages\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: _132789 or _10007
#   warnings.warn('Could not normalize this rule: ' + rule)
# C:\Users\biosy\anaconda3\envs\s2m2\lib\site-packages\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: _9563
#   warnings.warn('Could not normalize this rule: ' + rule)
# C:\Users\biosy\anaconda3\envs\s2m2\lib\site-packages\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: _2539
#   warnings.warn('Could not normalize this rule: ' + rule)
# C:\Users\biosy\anaconda3\envs\s2m2\lib\site-packages\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: _9563 or _2539
#   warnings.warn('Could not normalize this rule: ' + rule)
# C:\Users\biosy\anaconda3\envs\s2m2\lib\site-packages\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: _57818 or _2538 or _92579
#   warnings.warn('Could not normalize this rule: ' + rule)
# C:\Users\biosy\anaconda3\envs\s2m2\lib\site-packages\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: _2542
#   warnings.warn('Could not normalize this rule: ' + rule)
# C:\Users\biosy\anaconda3\envs\s2m2\lib\site-packages\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: _2593 or _2593
#   warnings.warn('Could not normalize this rule: ' + rule)
# C:\Users\biosy\anaconda3\envs\s2m2\lib\site-packages\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: _2597 or _26330
#   warnings.warn('Could not normalize this rule: ' + rule)
# C:\Users\biosy\anaconda3\envs\s2m2\lib\site-packages\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: _275 and _1738 and _2731 and _2653
#   warnings.warn('Could not normalize this rule: ' + rule)
# C:\Users\biosy\anaconda3\envs\s2m2\lib\site-packages\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: _2673 or _9945
#   warnings.warn('Could not normalize this rule: ' + rule)
# C:\Users\biosy\anaconda3\envs\s2m2\lib\site-packages\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: _6470 or _6470
#   warnings.warn('Could not normalize this rule: ' + rule)
# C:\Users\biosy\anaconda3\envs\s2m2\lib\site-packages\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: _6472 or _6470
#   warnings.warn('Could not normalize this rule: ' + rule)
# C:\Users\biosy\anaconda3\envs\s2m2\lib\site-packages\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: _2987
#   warnings.warn('Could not normalize this rule: ' + rule)
# C:\Users\biosy\anaconda3\envs\s2m2\lib\site-packages\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: _66035 or _6517 or _56606 or _154091 or _6513 or _11182 or _29988 or _6514 or _155184 or _56606 or _144195 or _6515 or _81031
#   warnings.warn('Could not normalize this rule: ' + rule)
# C:\Users\biosy\anaconda3\envs\s2m2\lib\site-packages\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: _6523
#   warnings.warn('Could not normalize this rule: ' + rule)
# C:\Users\biosy\anaconda3\envs\s2m2\lib\site-packages\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: _115584 or _6526 or _6524 or _125206 or _159963 or _200010
#   warnings.warn('Could not normalize this rule: ' + rule)
# C:\Users\biosy\anaconda3\envs\s2m2\lib\site-packages\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: _2752 or _51557
#   warnings.warn('Could not normalize this rule: ' + rule)
# C:\Users\biosy\anaconda3\envs\s2m2\lib\site-packages\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: _2729 and _2730
#   warnings.warn('Could not normalize this rule: ' + rule)
# C:\Users\biosy\anaconda3\envs\s2m2\lib\site-packages\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: _2571 or _2572 or _2571
#   warnings.warn('Could not normalize this rule: ' + rule)
# C:\Users\biosy\anaconda3\envs\s2m2\lib\site-packages\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: _2747 or _2746
#   warnings.warn('Could not normalize this rule: ' + rule)
# C:\Users\biosy\anaconda3\envs\s2m2\lib\site-packages\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: _2744 or _27165 or _27165
#   warnings.warn('Could not normalize this rule: ' + rule)
# C:\Users\biosy\anaconda3\envs\s2m2\lib\site-packages\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: _5471
#   warnings.warn('Could not normalize this rule: ' + rule)
# C:\Users\biosy\anaconda3\envs\s2m2\lib\site-packages\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: _83733 or _8604 or _79751 or _10165
#   warnings.warn('Could not normalize this rule: ' + rule)
# C:\Users\biosy\anaconda3\envs\s2m2\lib\site-packages\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: _2639 or _2639
#   warnings.warn('Could not normalize this rule: ' + rule)
# C:\Users\biosy\anaconda3\envs\s2m2\lib\site-packages\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: _57084 or _246213 or _57030
#   warnings.warn('Could not normalize this rule: ' + rule)
# C:\Users\biosy\anaconda3\envs\s2m2\lib\site-packages\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: _2628
#   warnings.warn('Could not normalize this rule: ' + rule)
# C:\Users\biosy\anaconda3\envs\s2m2\lib\site-packages\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: _23464
#   warnings.warn('Could not normalize this rule: ' + rule)
# C:\Users\biosy\anaconda3\envs\s2m2\lib\site-packages\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: _6539
#   warnings.warn('Could not normalize this rule: ' + rule)
# C:\Users\biosy\anaconda3\envs\s2m2\lib\site-packages\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: _6536 or _6536
#   warnings.warn('Could not normalize this rule: ' + rule)
# C:\Users\biosy\anaconda3\envs\s2m2\lib\site-packages\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: _8833
#   warnings.warn('Could not normalize this rule: ' + rule)
# C:\Users\biosy\anaconda3\envs\s2m2\lib\site-packages\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: _5226
#   warnings.warn('Could not normalize this rule: ' + rule)
# C:\Users\biosy\anaconda3\envs\s2m2\lib\site-packages\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: _27232
#   warnings.warn('Could not normalize this rule: ' + rule)
# C:\Users\biosy\anaconda3\envs\s2m2\lib\site-packages\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: _2936
#   warnings.warn('Could not normalize this rule: ' + rule)
# C:\Users\biosy\anaconda3\envs\s2m2\lib\site-packages\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: _7001 or _5052 or _2877 or _2876 or _5052 or _2876 or _5052 or _7001 or _2879 or _7001
#   warnings.warn('Could not normalize this rule: ' + rule)
# C:\Users\biosy\anaconda3\envs\s2m2\lib\site-packages\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: _10935 or _10935 or _2879 or _2876
#   warnings.warn('Could not normalize this rule: ' + rule)
# C:\Users\biosy\anaconda3\envs\s2m2\lib\site-packages\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: _2937
#   warnings.warn('Could not normalize this rule: ' + rule)
# C:\Users\biosy\anaconda3\envs\s2m2\lib\site-packages\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: _761 or _771 or _377677 or _762 or _766 or _23632 or _766 or _771 or _759 or _768 or _760 or _765
#   warnings.warn('Could not normalize this rule: ' + rule)
# C:\Users\biosy\anaconda3\envs\s2m2\lib\site-packages\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: _53905 or _50506 or _53905
#   warnings.warn('Could not normalize this rule: ' + rule)
# C:\Users\biosy\anaconda3\envs\s2m2\lib\site-packages\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: _358 or _361 or _4284 or _359 or _362 or _343
#   warnings.warn('Could not normalize this rule: ' + rule)
# C:\Users\biosy\anaconda3\envs\s2m2\lib\site-packages\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: _343
#   warnings.warn('Could not normalize this rule: ' + rule)
# C:\Users\biosy\anaconda3\envs\s2m2\lib\site-packages\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: _3028 or _3033 or (_3030 and _3032)
#   warnings.warn('Could not normalize this rule: ' + rule)
# C:\Users\biosy\anaconda3\envs\s2m2\lib\site-packages\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: _3028 or _1962 or _3033
#   warnings.warn('Could not normalize this rule: ' + rule)
# C:\Users\biosy\anaconda3\envs\s2m2\lib\site-packages\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: _6522 or _83697 or _6521 or _6508 or _6508
#   warnings.warn('Could not normalize this rule: ' + rule)
# C:\Users\biosy\anaconda3\envs\s2m2\lib\site-packages\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: _3098 or _80201 or _2645 or _3098 or _3099 or _2645 or _3098 or _2645 or _3098 or _3101 or _3098
#   warnings.warn('Could not normalize this rule: ' + rule)
# C:\Users\biosy\anaconda3\envs\s2m2\lib\site-packages\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: _3081
#   warnings.warn('Could not normalize this rule: ' + rule)
# C:\Users\biosy\anaconda3\envs\s2m2\lib\site-packages\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: _11112
#   warnings.warn('Could not normalize this rule: ' + rule)
# C:\Users\biosy\anaconda3\envs\s2m2\lib\site-packages\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: _3034
#   warnings.warn('Could not normalize this rule: ' + rule)
# C:\Users\biosy\anaconda3\envs\s2m2\lib\site-packages\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: _1644 or _3067
#   warnings.warn('Could not normalize this rule: ' + rule)
# C:\Users\biosy\anaconda3\envs\s2m2\lib\site-packages\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: _11254 or _54407
#   warnings.warn('Could not normalize this rule: ' + rule)
# C:\Users\biosy\anaconda3\envs\s2m2\lib\site-packages\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: _6581 or _6582 or _6582 or _6584
#   warnings.warn('Could not normalize this rule: ' + rule)
# C:\Users\biosy\anaconda3\envs\s2m2\lib\site-packages\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: _6570 or _6571
#   warnings.warn('Could not normalize this rule: ' + rule)
# C:\Users\biosy\anaconda3\envs\s2m2\lib\site-packages\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: _55089
#   warnings.warn('Could not normalize this rule: ' + rule)
# C:\Users\biosy\anaconda3\envs\s2m2\lib\site-packages\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: _10991
#   warnings.warn('Could not normalize this rule: ' + rule)
# C:\Users\biosy\anaconda3\envs\s2m2\lib\site-packages\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: _8942
#   warnings.warn('Could not normalize this rule: ' + rule)
# C:\Users\biosy\anaconda3\envs\s2m2\lib\site-packages\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: _3158
#   warnings.warn('Could not normalize this rule: ' + rule)
# C:\Users\biosy\anaconda3\envs\s2m2\lib\site-packages\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: _3155 or _54511
#   warnings.warn('Could not normalize this rule: ' + rule)
# C:\Users\biosy\anaconda3\envs\s2m2\lib\site-packages\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: _6541 or _84889 or _6542
#   warnings.warn('Could not normalize this rule: ' + rule)
# C:\Users\biosy\anaconda3\envs\s2m2\lib\site-packages\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: _9016 or _7352 or _7352 or _7351 or _9016 or _7350 or _9481
#   warnings.warn('Could not normalize this rule: ' + rule)
# C:\Users\biosy\anaconda3\envs\s2m2\lib\site-packages\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: (_3421 and _3420 and _3419) or (_3420 and _3421 and _3419) or (_3420 and _3421 and _3419) or (_3420 and _3421 and _3419) or (_3421 and _3419 and _3420) or (_3421 and _3419 and _3420)
#   warnings.warn('Could not normalize this rule: ' + rule)
# C:\Users\biosy\anaconda3\envs\s2m2\lib\site-packages\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: _3417
#   warnings.warn('Could not normalize this rule: ' + rule)
# C:\Users\biosy\anaconda3\envs\s2m2\lib\site-packages\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: _3418
#   warnings.warn('Could not normalize this rule: ' + rule)
# C:\Users\biosy\anaconda3\envs\s2m2\lib\site-packages\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: _11254 or (_340024 and (_57393 or _59272))
#   warnings.warn('Could not normalize this rule: ' + rule)
# C:\Users\biosy\anaconda3\envs\s2m2\lib\site-packages\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: _586
#   warnings.warn('Could not normalize this rule: ' + rule)
# C:\Users\biosy\anaconda3\envs\s2m2\lib\site-packages\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: _587
#   warnings.warn('Could not normalize this rule: ' + rule)
# C:\Users\biosy\anaconda3\envs\s2m2\lib\site-packages\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: _8501 or _124935
#   warnings.warn('Could not normalize this rule: ' + rule)
# C:\Users\biosy\anaconda3\envs\s2m2\lib\site-packages\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: _144193
#   warnings.warn('Could not normalize this rule: ' + rule)
# C:\Users\biosy\anaconda3\envs\s2m2\lib\site-packages\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: _6560 or _10723 or _9990
#   warnings.warn('Could not normalize this rule: ' + rule)
# C:\Users\biosy\anaconda3\envs\s2m2\lib\site-packages\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: _8564
#   warnings.warn('Could not normalize this rule: ' + rule)
# C:\Users\biosy\anaconda3\envs\s2m2\lib\site-packages\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: (_3945 and _3939) or _160287 or _3948 or _3939 or _3948 or _55293 or _3945 or _92483
#   warnings.warn('Could not normalize this rule: ' + rule)
# C:\Users\biosy\anaconda3\envs\s2m2\lib\site-packages\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: _81539 or _84889 or _6520 or _6542 or _6541 or _11254 or _55089 or (_340024 and (_57393 or _59272))
#   warnings.warn('Could not normalize this rule: ' + rule)
# C:\Users\biosy\anaconda3\envs\s2m2\lib\site-packages\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: _124637
#   warnings.warn('Could not normalize this rule: ' + rule)
# C:\Users\biosy\anaconda3\envs\s2m2\lib\site-packages\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: _9194 or _23539 or _6566 or _9123 or _682
#   warnings.warn('Could not normalize this rule: ' + rule)
# C:\Users\biosy\anaconda3\envs\s2m2\lib\site-packages\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: _160728
#   warnings.warn('Could not normalize this rule: ' + rule)
# C:\Users\biosy\anaconda3\envs\s2m2\lib\site-packages\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: _11254 or _6584
#   warnings.warn('Could not normalize this rule: ' + rule)
# C:\Users\biosy\anaconda3\envs\s2m2\lib\site-packages\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: _2954 or _2954 or _2954
#   warnings.warn('Could not normalize this rule: ' + rule)
# C:\Users\biosy\anaconda3\envs\s2m2\lib\site-packages\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: _56922 and _64087
#   warnings.warn('Could not normalize this rule: ' + rule)
# C:\Users\biosy\anaconda3\envs\s2m2\lib\site-packages\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: _130752 or _4190
#   warnings.warn('Could not normalize this rule: ' + rule)
# C:\Users\biosy\anaconda3\envs\s2m2\lib\site-packages\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: _4191 or _4190
#   warnings.warn('Could not normalize this rule: ' + rule)
# C:\Users\biosy\anaconda3\envs\s2m2\lib\site-packages\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: _4200
#   warnings.warn('Could not normalize this rule: ' + rule)
# C:\Users\biosy\anaconda3\envs\s2m2\lib\site-packages\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: _4199
#   warnings.warn('Could not normalize this rule: ' + rule)
# C:\Users\biosy\anaconda3\envs\s2m2\lib\site-packages\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: _4200 or _10873
#   warnings.warn('Could not normalize this rule: ' + rule)
# C:\Users\biosy\anaconda3\envs\s2m2\lib\site-packages\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: _4143 or (_27430 and _4144) or (_27430 and _4144)
#   warnings.warn('Could not normalize this rule: ' + rule)
# C:\Users\biosy\anaconda3\envs\s2m2\lib\site-packages\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: _6520 and _8140
#   warnings.warn('Could not normalize this rule: ' + rule)
# C:\Users\biosy\anaconda3\envs\s2m2\lib\site-packages\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: _4548
#   warnings.warn('Could not normalize this rule: ' + rule)
# C:\Users\biosy\anaconda3\envs\s2m2\lib\site-packages\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: _81539 or _11254 or _54407 or _6584 or (_340024 and (_57393 or _59272))
#   warnings.warn('Could not normalize this rule: ' + rule)
# C:\Users\biosy\anaconda3\envs\s2m2\lib\site-packages\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: _549
#   warnings.warn('Could not normalize this rule: ' + rule)
# C:\Users\biosy\anaconda3\envs\s2m2\lib\site-packages\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: _84693
#   warnings.warn('Could not normalize this rule: ' + rule)
# C:\Users\biosy\anaconda3\envs\s2m2\lib\site-packages\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: _4594
#   warnings.warn('Could not normalize this rule: ' + rule)
# C:\Users\biosy\anaconda3\envs\s2m2\lib\site-packages\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: _4329
#   warnings.warn('Could not normalize this rule: ' + rule)
# C:\Users\biosy\anaconda3\envs\s2m2\lib\site-packages\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: _4522 or _100287639 or _441024
#   warnings.warn('Could not normalize this rule: ' + rule)
# C:\Users\biosy\anaconda3\envs\s2m2\lib\site-packages\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: _4522 or _4524
#   warnings.warn('Could not normalize this rule: ' + rule)
# ...
#   warnings.warn('Could not normalize this rule: ' + rule)
# C:\Users\biosy\anaconda3\envs\s2m2\lib\site-packages\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: _7167 or _286016
#   warnings.warn('Could not normalize this rule: ' + rule)
# C:\Users\biosy\anaconda3\envs\s2m2\lib\site-packages\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: _6999 or _169355 or _3620
#   warnings.warn('Could not normalize this rule: ' + rule)
# C:\Users\biosy\anaconda3\envs\s2m2\lib\site-packages\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: _120103 or _117247
#   warnings.warn('Could not normalize this rule: ' + rule)
# C:\Users\biosy\anaconda3\envs\s2m2\lib\site-packages\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: _117247
#   warnings.warn('Could not normalize this rule: ' + rule)
# C:\Users\biosy\anaconda3\envs\s2m2\lib\site-packages\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: _2805 or _6898
#   warnings.warn('Could not normalize this rule: ' + rule)
# C:\Users\biosy\anaconda3\envs\s2m2\lib\site-packages\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: _23169
#   warnings.warn('Could not normalize this rule: ' + rule)
# C:\Users\biosy\anaconda3\envs\s2m2\lib\site-packages\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: _51727
#   warnings.warn('Could not normalize this rule: ' + rule)
# C:\Users\biosy\anaconda3\envs\s2m2\lib\site-packages\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: _131669
#   warnings.warn('Could not normalize this rule: ' + rule)
# C:\Users\biosy\anaconda3\envs\s2m2\lib\site-packages\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: _6523 or _6563 or _6528 or _8170
#   warnings.warn('Could not normalize this rule: ' + rule)
# C:\Users\biosy\anaconda3\envs\s2m2\lib\site-packages\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: _366
#   warnings.warn('Could not normalize this rule: ' + rule)
# C:\Users\biosy\anaconda3\envs\s2m2\lib\site-packages\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: _51181
#   warnings.warn('Could not normalize this rule: ' + rule)
# C:\Users\biosy\anaconda3\envs\s2m2\lib\site-packages\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: _953 or _956 or _377841
#   warnings.warn('Could not normalize this rule: ' + rule)
# C:\Users\biosy\anaconda3\envs\s2m2\lib\site-packages\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: _1373
#   warnings.warn('Could not normalize this rule: ' + rule)
# C:\Users\biosy\anaconda3\envs\s2m2\lib\site-packages\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: _8659
#   warnings.warn('Could not normalize this rule: ' + rule)
# C:\Users\biosy\anaconda3\envs\s2m2\lib\site-packages\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: _84706 or _2875
#   warnings.warn('Could not normalize this rule: ' + rule)
# C:\Users\biosy\anaconda3\envs\s2m2\lib\site-packages\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: _56954
#   warnings.warn('Could not normalize this rule: ' + rule)
# C:\Users\biosy\anaconda3\envs\s2m2\lib\site-packages\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: _3704
#   warnings.warn('Could not normalize this rule: ' + rule)
# C:\Users\biosy\anaconda3\envs\s2m2\lib\site-packages\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: _5313
#   warnings.warn('Could not normalize this rule: ' + rule)
# C:\Users\biosy\anaconda3\envs\s2m2\lib\site-packages\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: _374569
#   warnings.warn('Could not normalize this rule: ' + rule)
# C:\Users\biosy\anaconda3\envs\s2m2\lib\site-packages\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: _3945 or _3939 or _3948
#   warnings.warn('Could not normalize this rule: ' + rule)
# C:\Users\biosy\anaconda3\envs\s2m2\lib\site-packages\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: _7915
#   warnings.warn('Could not normalize this rule: ' + rule)
# C:\Users\biosy\anaconda3\envs\s2m2\lib\site-packages\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: _5211
#   warnings.warn('Could not normalize this rule: ' + rule)
# C:\Users\biosy\anaconda3\envs\s2m2\lib\site-packages\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: _275
#   warnings.warn('Could not normalize this rule: ' + rule)
# C:\Users\biosy\anaconda3\envs\s2m2\lib\site-packages\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: _2645 or _3098 or _3099 or _3101
#   warnings.warn('Could not normalize this rule: ' + rule)
# C:\Users\biosy\anaconda3\envs\s2m2\lib\site-packages\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: _5053
#   warnings.warn('Could not normalize this rule: ' + rule)
# C:\Users\biosy\anaconda3\envs\s2m2\lib\site-packages\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: _51166
#   warnings.warn('Could not normalize this rule: ' + rule)
# C:\Users\biosy\anaconda3\envs\s2m2\lib\site-packages\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: _224 or _217 or _219 or _223 or _501
#   warnings.warn('Could not normalize this rule: ' + rule)
# C:\Users\biosy\anaconda3\envs\s2m2\lib\site-packages\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: _18
#   warnings.warn('Could not normalize this rule: ' + rule)
# C:\Users\biosy\anaconda3\envs\s2m2\lib\site-packages\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: _6389 and _6390 and _6391 and _6392
#   warnings.warn('Could not normalize this rule: ' + rule)
# C:\Users\biosy\anaconda3\envs\s2m2\lib\site-packages\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: _2639
#   warnings.warn('Could not normalize this rule: ' + rule)
# C:\Users\biosy\anaconda3\envs\s2m2\lib\site-packages\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: _501
#   warnings.warn('Could not normalize this rule: ' + rule)
# C:\Users\biosy\anaconda3\envs\s2m2\lib\site-packages\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: _35
#   warnings.warn('Could not normalize this rule: ' + rule)
# C:\Users\biosy\anaconda3\envs\s2m2\lib\site-packages\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: _55276
#   warnings.warn('Could not normalize this rule: ' + rule)
# C:\Users\biosy\anaconda3\envs\s2m2\lib\site-packages\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: _26275
#   warnings.warn('Could not normalize this rule: ' + rule)
# C:\Users\biosy\anaconda3\envs\s2m2\lib\site-packages\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: _34 or _3712
#   warnings.warn('Could not normalize this rule: ' + rule)
# C:\Users\biosy\anaconda3\envs\s2m2\lib\site-packages\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: _3030 and _1962 and _1892
#   warnings.warn('Could not normalize this rule: ' + rule)
# C:\Users\biosy\anaconda3\envs\s2m2\lib\site-packages\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: _34
#   warnings.warn('Could not normalize this rule: ' + rule)
# C:\Users\biosy\anaconda3\envs\s2m2\lib\site-packages\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: _4524
#   warnings.warn('Could not normalize this rule: ' + rule)
# C:\Users\biosy\anaconda3\envs\s2m2\lib\site-packages\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: _293
#   warnings.warn('Could not normalize this rule: ' + rule)
# C:\Users\biosy\anaconda3\envs\s2m2\lib\site-packages\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: _10478
#   warnings.warn('Could not normalize this rule: ' + rule)
# C:\Users\biosy\anaconda3\envs\s2m2\lib\site-packages\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: _6542
#   warnings.warn('Could not normalize this rule: ' + rule)
# C:\Users\biosy\anaconda3\envs\s2m2\lib\site-packages\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: _60386 or _89874
#   warnings.warn('Could not normalize this rule: ' + rule)
# C:\Users\biosy\anaconda3\envs\s2m2\lib\site-packages\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: _64240 and _64241
#   warnings.warn('Could not normalize this rule: ' + rule)
# C:\Users\biosy\anaconda3\envs\s2m2\lib\site-packages\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: _6535
#   warnings.warn('Could not normalize this rule: ' + rule)
# C:\Users\biosy\anaconda3\envs\s2m2\lib\site-packages\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: _11136
#   warnings.warn('Could not normalize this rule: ' + rule)
# C:\Users\biosy\anaconda3\envs\s2m2\lib\site-packages\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: _6576 or _284111
#   warnings.warn('Could not normalize this rule: ' + rule)
# C:\Users\biosy\anaconda3\envs\s2m2\lib\site-packages\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: _593 and _594 and _1738 and _1629
#   warnings.warn('Could not normalize this rule: ' + rule)
# C:\Users\biosy\anaconda3\envs\s2m2\lib\site-packages\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: _9194 or _6566
#   warnings.warn('Could not normalize this rule: ' + rule)
# C:\Users\biosy\anaconda3\envs\s2m2\lib\site-packages\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: _83884
#   warnings.warn('Could not normalize this rule: ' + rule)
# C:\Users\biosy\anaconda3\envs\s2m2\lib\site-packages\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: _10057
#   warnings.warn('Could not normalize this rule: ' + rule)
# C:\Users\biosy\anaconda3\envs\s2m2\lib\site-packages\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: _57835
#   warnings.warn('Could not normalize this rule: ' + rule)
# C:\Users\biosy\anaconda3\envs\s2m2\lib\site-packages\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: _8140
#   warnings.warn('Could not normalize this rule: ' + rule)
# C:\Users\biosy\anaconda3\envs\s2m2\lib\site-packages\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: _9057
#   warnings.warn('Could not normalize this rule: ' + rule)
# C:\Users\biosy\anaconda3\envs\s2m2\lib\site-packages\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: _6568
#   warnings.warn('Could not normalize this rule: ' + rule)
# C:\Users\biosy\anaconda3\envs\s2m2\lib\site-packages\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: _6579
#   warnings.warn('Could not normalize this rule: ' + rule)
# C:\Users\biosy\anaconda3\envs\s2m2\lib\site-packages\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: _10861
#   warnings.warn('Could not normalize this rule: ' + rule)
# C:\Users\biosy\anaconda3\envs\s2m2\lib\site-packages\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: _54020
#   warnings.warn('Could not normalize this rule: ' + rule)
# C:\Users\biosy\anaconda3\envs\s2m2\lib\site-packages\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: _8402
#   warnings.warn('Could not normalize this rule: ' + rule)
# C:\Users\biosy\anaconda3\envs\s2m2\lib\site-packages\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: _8501
#   warnings.warn('Could not normalize this rule: ' + rule)
# C:\Users\biosy\anaconda3\envs\s2m2\lib\site-packages\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: _10327
#   warnings.warn('Could not normalize this rule: ' + rule)
# C:\Users\biosy\anaconda3\envs\s2m2\lib\site-packages\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: _26
#   warnings.warn('Could not normalize this rule: ' + rule)
# C:\Users\biosy\anaconda3\envs\s2m2\lib\site-packages\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: _883
#   warnings.warn('Could not normalize this rule: ' + rule)
# C:\Users\biosy\anaconda3\envs\s2m2\lib\site-packages\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: _5315
#   warnings.warn('Could not normalize this rule: ' + rule)
# C:\Users\biosy\anaconda3\envs\s2m2\lib\site-packages\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: _284111
#   warnings.warn('Could not normalize this rule: ' + rule)
# C:\Users\biosy\anaconda3\envs\s2m2\lib\site-packages\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: _9152
#   warnings.warn('Could not normalize this rule: ' + rule)
# C:\Users\biosy\anaconda3\envs\s2m2\lib\site-packages\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: _9497
#   warnings.warn('Could not normalize this rule: ' + rule)
# C:\Users\biosy\anaconda3\envs\s2m2\lib\site-packages\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: _6574 or _6575
#   warnings.warn('Could not normalize this rule: ' + rule)
# C:\Users\biosy\anaconda3\envs\s2m2\lib\site-packages\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: _142680
#   warnings.warn('Could not normalize this rule: ' + rule)
# C:\Users\biosy\anaconda3\envs\s2m2\lib\site-packages\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: _6534
#   warnings.warn('Could not normalize this rule: ' + rule)
# C:\Users\biosy\anaconda3\envs\s2m2\lib\site-packages\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: _1351 and _1347 and _1329 and _1327 and _341947 and _9167 and _1350 and _4512 and _1349 and _1339 and _1345 and _4513 and _9377 and _125965 and _4514 and _170712 and _1346 and _1340 and _84701 and _1337
#   warnings.warn('Could not normalize this rule: ' + rule)
# C:\Users\biosy\anaconda3\envs\s2m2\lib\site-packages\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: (_9056 or _9057) and _6520
#   warnings.warn('Could not normalize this rule: ' + rule)
# C:\Users\biosy\anaconda3\envs\s2m2\lib\site-packages\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: _23428 and _6520
#   warnings.warn('Could not normalize this rule: ' + rule)
# C:\Users\biosy\anaconda3\envs\s2m2\lib\site-packages\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: _6533
#   warnings.warn('Could not normalize this rule: ' + rule)
# C:\Users\biosy\anaconda3\envs\s2m2\lib\site-packages\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: _6541
#   warnings.warn('Could not normalize this rule: ' + rule)
# C:\Users\biosy\anaconda3\envs\s2m2\lib\site-packages\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: _8140 and _6520
#   warnings.warn('Could not normalize this rule: ' + rule)
# C:\Users\biosy\anaconda3\envs\s2m2\lib\site-packages\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: _11136 and _6519
#   warnings.warn('Could not normalize this rule: ' + rule)
# C:\Users\biosy\anaconda3\envs\s2m2\lib\site-packages\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: _54716 and _57393
#   warnings.warn('Could not normalize this rule: ' + rule)
# C:\Users\biosy\anaconda3\envs\s2m2\lib\site-packages\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: _6509
#   warnings.warn('Could not normalize this rule: ' + rule)
# C:\Users\biosy\anaconda3\envs\s2m2\lib\site-packages\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: (_2110 and _2109 and _2108) or (_2109 and _2108)
#   warnings.warn('Could not normalize this rule: ' + rule)
# C:\Users\biosy\anaconda3\envs\s2m2\lib\site-packages\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: _29920 or _65263 or _5831
#   warnings.warn('Could not normalize this rule: ' + rule)
# C:\Users\biosy\anaconda3\envs\s2m2\lib\site-packages\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: _58510
#   warnings.warn('Could not normalize this rule: ' + rule)
# C:\Users\biosy\anaconda3\envs\s2m2\lib\site-packages\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: _6580
#   warnings.warn('Could not normalize this rule: ' + rule)
# C:\Users\biosy\anaconda3\envs\s2m2\lib\site-packages\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: _10864
#   warnings.warn('Could not normalize this rule: ' + rule)

# %% [markdown]
# ### Map the identifiers in the omics data to the identifiers in the model
#
# For this we can use the `get_integrated_data_map()` method from the `TabularReader` class. This maps the gene ids in the omics dataset reaction ids in the model through their GPRs, and attributes a score to each reaction in accordance with the expression values of the associated genes. This method returns a dictionary with the reaction ids as keys and the scores as values.
#
# Important arguments from this method include:
# - `model_reader`: a COBRAModelObjectReader instance containing all the information of the model. It can be accessed through the `model_wrapper.model_reader`.
# - `and_func`: a function that is used to combine the scores of the genes associated with a reaction for AND rules in the GPR. In this example, we will be using the minimum function, which means that the score of a reaction with AND in their GPRs will be the minimum score of the genes associated with it.
# - `or_func`: a function that is used to combine the scores of the genes associated with a reaction for OR rules in the GPR. In this example, we will be using the sum function, which means that the score of a reaction with OR in their GPRs will be the sum of the scores of the genes associated with it.

# %%
data_map = single_sample.get_integrated_data_map(model_reader=model_wrapper.model_reader, and_func=min, or_func=sum)

# %% [markdown]
# ### Integrate scores
#
# The `integrate()` method from the `ContinuousScoreIntegrationStrategy` class is used to integrate the scores of the reactions in the model. This method returns a dictionary with the reaction ids as keys and the integrated scores as values. In the case of this continuous scoring method, the resulting scores are the same as the scores in the data map. However, for other scoring methods, such as threshold scoring methods, the result will be a list of reactions with a score above the selected threshold.
#
# Moreover, this method allows us to apply an additional function to the method, which can be useful if you have any protected reactions that need to be in the final model or to remove nan values from the result. This can be done by passing the function as the `score_apply` argument of the `ContinuousScoreIntegrationStrategy` class.
#
# In this example, we will be using a function that replaces the nan values with 0 and returns a list with all the scores. This is the required format for the *GIMME* method.

# %%
def score_apply(reaction_map_scores):
    return {k:0  if v is None else v for k, v in reaction_map_scores.items()}

continuous_integration = ContinuousScoreIntegrationStrategy(score_apply=score_apply)
scores = continuous_integration.integrate(data_map=data_map)

print(scores)
# Out:
# {'2AMACHYD': 0.475084882949, '2AMADPTm': 0.150559676575, '2DR1PP': 0, '2HCO3_NAt': 2.6904623550171003, '2OXOADOXm': 9.76137105052, '2OXOADPTm': 0.150559676575, '34HPPOR': 0.0143552929771, '3AIBt': 0, '3AIBTm': 1.496922466008, '3AIBtm': 1.496922466008, '3HAO': 0.650764559117, '3HBCOAHLm': 0, '3HKYNAKGAT': 2.9180564378900007, '3MOBt2im': 0, '3MOPt2im': 0, '3SALAASPm': 9.261276459529999, '3SALATAi': 5.09254574154, '3SALATAim': 6.91683488515, '3SPYRSP': 0, '3SPYRSPm': 0, '4ABUTtm': 0, '4MOPt2im': 0, '5MTHFt': 15.807559610700002, '5MTHFt2': 9.09317165802, 'AACOAT': 4.80322703643, 'AACTOOR': 0.111031312389, 'AACTtm': 0, 'AASAD3m': 0, 'AATAi': 1.3919876262200002, 'ABTArm': 1.496922466008, 'ABUTD': 5.591559745830001, 'ABUTt2r': 3.0478873294, 'ABUTt4_2_r': 0.20769798096859998, 'ACACT10m': 18.406597148190002, 'ACACT1r': 4.66106547981, 'ACACt2': 0.9456077031814, 'ACACt2m': 0.8479969065549999, 'ACETONEt2': 8.835628723441399, 'ACETONEt2m': 0.8479969065549999, 'ACITL': 15.32896568072, 'ACOAD10m': 7.7508744396600004, 'ACOAD9m': 10.56166026712, 'ACOAHi': 0.0, 'ACONT': 5.134951961010001, 'ACONTm': 7.52393982994, 'ACS': 16.740330243149998, 'ACSm': 1.96347412397, 'ACt2m': 0, 'ACt2r': 0, 'ACTLMO': 0.214124805353, 'ACTNMO': 0.214124805353, 'ACYP': 13.349931208410002, 'ADCim': 0, 'ADEt': 3.9909548604, 'ADK1': 14.388764111778, 'ADK1m': 22.584401080032002, 'ADK3': 0.35264554528, 'ADK3m': 3.34056226903, 'ADMDC': 5.387155717660001, 'ADNK1': 13.2949168529, 'ADPT': 6.562852959580001, 'ADPtx': 0, 'AGTim': 0.0, 'AHC': 19.71498043656, 'AKGDm': 9.76137105052, 'AKGMALtm': 12.34034701253, 'AKGt4_3': 3.3651465947, 'ALAASNNaEx': 7.88856061771, 'ALACYSNaEx': 11.04560432786, 'ALAGLNexR': 0.0, 'ALAGLNNaEx': 7.88856061771, 'ALAGLYexR': 0.0, 'ALASERNaEx': 11.04560432786, 'ALAt2r': 3.1182766572914, 'ALAt4': 16.241051064228497, 'ALATA_L': 6.58115236573, 'ALATHRNaEx': 11.04560432786, 'ALAtN1': 0.572792677258, 'AMCOXO': 0, 'AMETt2m': 10.10211319695, 'AMPtp': 0, 'AOBUTDsm': 0, 'APAT2rm': 1.496922466008, 'ARGLYSex': 3.64038956005, 'ARGN': 1.5830376237964001, 'ARGNm': 1.4854268271700002, 'ARGt4': 0.17632277264, 'ARGtiDF': 4.808193965862099, 'ARGtm': 3.718854770921401, 'ASNALANaEx': 7.88856061771, 'ASNCYSNaEx': 7.88856061771, 'ASNGLNNaEx': 7.88856061771, 'ASNS1': 18.04440480705, 'ASNSERNaEx': 7.88856061771, 'ASNt4': 11.447212391343498, 'ASNTHRNaEx': 7.88856061771, 'ASNtN1': 0.572792677258, 'ASPGLUm': 9.261276459529999, 'ASPTA': 5.09254574154, 'ASPTAm': 6.91683488515, 'ATP1ter': 0, 'ATPS4m': 3284.6024824945275, 'ATPtm': 21.65419370283, 'ATPtx': 0, 'BALAtmr': 0, 'BALAVECSEC': 0.0, 'BETALDHxm': 0, 'BHMT': 0.0143552929771, 'CATm': 5.4822029263, 'CATp': 5.4822029263, 'CBPS': 4.641546029090001, 'CBPSam': 12.722132977580001, 'CHLtm': 0, 'CHOLD2m': 0.1243281350019999, 'CHOLt4': 0.0, 'CHOLtu': 4.33055840003, 'CHSTEROLt': 0.3362833878640999, 'CHSTEROLt1': 8.668991321510001, 'CHSTEROLt2': 0, 'CHSTEROLt3': 0, 'CITL': 3.46236648314, 'CITRtm': 3.718854770921401, 'CITt4_2': 0.0285691521968, 'CITtam': 6.71232064074, 'CITtbm': 6.71232064074, 'CK': 13.5528145315114, 'CKc': 4.598722499680001, 'CLFORtex': 0.0143552929771, 'CLHCO3tex2': 13.60629274461, 'CLOHtex2': 13.60629274461, 'CLOXAtex2': 13.60629274461, 'CO2t': 0, 'CO2ter': 0, 'CO2tm': 0, 'COAtm': 4.1366835777, 'CREATt4_2_r': 6.6842072014267995, 'CREATtmdiffir': 0, 'CSm': 14.03628905788, 'CTPS1': 6.7259933062199995, 'CTPS2': 6.7259933062199995, 'CYOR_u10m': 11.671342958960002, 'CYSALANaEx': 11.04560432786, 'CYSASNNaEx': 7.88856061771, 'CYSGLNNaEx': 7.88856061771, 'CYSGLUexR': 7.156335936689999, 'CYSGLYexR': 5.952727271460001, 'CYSO': 0.0565835283664, 'CYSSERNaEx': 11.04560432786, 'CYSt4': 5.3456064337564, 'CYStec': 3.52857131887, 'CYSTGL': 4.82285249146, 'CYSTHRNaEx': 11.04560432786, 'CYSTS': 2.49825086753, 'D_3AIBt': 0, 'D3AIBTm': 0.0, 'DATPtn': 0, 'DCTPtn': 0, 'DGTPtn': 0, 'DHPR': 2.56071495447, 'ATPM': 0, 'DMGDHm': 0.13750352375, 'DMGtm': 0, 'DNDPt11m': 5.012568673500001, 'DNDPt23m': 5.012568673500001, 'DNDPt24m': 5.012568673500001, 'DND ...

# %% [markdown]
# Below is and example on how to use the `CustomSelectionIntegrationStrategy` class to integrate the scores of the reactions in the model. This is basically a threshold scoring method that allows us to also keep a set of protected reactions. This will output a list of core reactions that will be used to build the final model with the *FastCORE* method.

# %%
from math import log
threshold =  (5 * log(2))
protected_reactions = ['biomass']

def integration_fx(reaction_map_scores):
    return [[k for k, v in reaction_map_scores.get_scores().items() if (v is not None and v > threshold) or k in protected_reactions]]

threshold_integration = CustomSelectionIntegrationStrategy(group_functions=[integration_fx])
threshold_scores = threshold_integration.integrate(data_map=data_map)

print(threshold_scores)
# Out:
# [['2OXOADOXm', '3SALAASPm', '3SALATAi', '3SALATAim', '5MTHFt', '5MTHFt2', 'AACOAT', 'ABUTD', 'ACACT10m', 'ACACT1r', 'ACETONEt2', 'ACITL', 'ACOAD10m', 'ACOAD9m', 'ACONT', 'ACONTm', 'ACS', 'ACYP', 'ADEt', 'ADK1', 'ADK1m', 'ADMDC', 'ADNK1', 'ADPT', 'AHC', 'AKGDm', 'AKGMALtm', 'ALAASNNaEx', 'ALACYSNaEx', 'ALAGLNNaEx', 'ALASERNaEx', 'ALAt4', 'ALATA_L', 'ALATHRNaEx', 'AMETt2m', 'ARGLYSex', 'ARGtiDF', 'ARGtm', 'ASNALANaEx', 'ASNCYSNaEx', 'ASNGLNNaEx', 'ASNS1', 'ASNSERNaEx', 'ASNt4', 'ASNTHRNaEx', 'ASPGLUm', 'ASPTA', 'ASPTAm', 'ATPS4m', 'ATPtm', 'CATm', 'CATp', 'CBPS', 'CBPSam', 'CHOLtu', 'CHSTEROLt1', 'CITRtm', 'CITtam', 'CITtbm', 'CK', 'CKc', 'CLHCO3tex2', 'CLOHtex2', 'CLOXAtex2', 'COAtm', 'CREATt4_2_r', 'CSm', 'CTPS1', 'CTPS2', 'CYOR_u10m', 'CYSALANaEx', 'CYSASNNaEx', 'CYSGLNNaEx', 'CYSGLUexR', 'CYSGLYexR', 'CYSSERNaEx', 'CYSt4', 'CYStec', 'CYSTGL', 'CYSTHRNaEx', 'DNDPt11m', 'DNDPt23m', 'DNDPt24m', 'DNDPt34m', 'DNDPt35m', 'DNDPt9m', 'DPGase', 'DPGM', 'ECOAH12m', 'ECOAH1m', 'ECOAH9m', 'ENO', 'FBA', 'FBP', 'FKYNH', 'FTHFDH', 'FUM', 'FUMAC', 'FUMm', 'FUMSO3tm', 'FUMSO4tm', 'FUMtm', 'FUMTSULtm', 'G3PD2m', 'G5SDym', 'G6PDA', 'G6PDH2r', 'G6PDH2rer', 'G6PPer', 'G6Pter', 'GACMTRc', 'GAPD', 'GF6PTA', 'GHMT2r', 'GHMT2rm', 'GK1', 'GLCt1r', 'GLNALANaEx', 'GLNASNNaEx', 'GLNCYSNaEx', 'GLNS', 'GLNSERNaEx', 'GLNt4', 'GLNTHRNaEx', 'GLU5Km', 'GLUCYS', 'GLUDxm', 'GLUDym', 'GLUNm', 'GLUPRT', 'GLUt2m', 'GLUTCOADHm', 'GLYATm', 'GLYt4', 'GLYt7_211_r', 'GMPS2', 'GND', 'GNDer', 'GTHO', 'GTHOm', 'GTHP', 'GTHPm', 'GTHS', 'H2CO3D', 'HACD1m', 'HACD9m', 'HCO3_CLt', 'HEX1', 'HIBDm', 'HISt4', 'HISTAtu', 'HOMt4', 'Htm', 'ICDHxm', 'ICDHy', 'ICDHyrm', 'ILETAm', 'ILEtec', 'LDH_L', 'LEUt4', 'LEUTAm', 'LEUtec', 'L_LACt2r', 'LYSt4', 'LYStiDF', 'LYStm', 'MACACI', 'MALSO3tm', 'MALSO4tm', 'MALtm', 'MALTSULtm', 'MCCCrm', 'MDH', 'MDHm', 'ME1m', 'ME2', 'ME2m', 'METAT', 'METLEUex', 'METt4', 'METtec', 'MGCHrm', 'MMEm', 'MTHFC', 'MTHFD', 'NADH2_u10m', 'NAt3_1', 'NAt5', 'NDPK1', 'NDPK1m', 'NDPK2', 'NDPK3', 'NDPK4', 'NDPK5', 'NDPK8', 'NDPK9', 'NTD7', 'OIVD1m', 'OIVD2m', 'OIVD3m', 'ORNDC', 'ORNt3m', 'ORNt4m', 'ORNTArm', 'ORNtiDF', 'P5CDm', 'P5CRm', 'P5CRxm', 'PCm', 'PDHm', 'PEPCKm', 'PFK', 'PGCD', 'PGI', 'PGK', 'PGL', 'PGM', 'PHEt4', 'PHEtec', 'PIter', 'PPA', 'PPAm', 'PPCOACm', 'PPCOAOm', 'PPM', 'PRFGS', 'PRO1xm', 'PROD2m', 'PROt4', 'PRPNCOAHYDm', 'PRPPS', 'PSERT', 'PSFLIPm', 'PSP_L', 'PUNP1', 'PYK', 'PYRt2r', 'RPE', 'RPI', 'SERALANaEx', 'SERASNNaEx', 'SERCYSNaEx', 'SERGLNNaEx', 'SERt4', 'SERTHRNaEx', 'SO4CLtex2', 'SO4HCOtex', 'SO4OXAtex2', 'SPMS', 'SPODM', 'SPODMm', 'SPODMx', 'SPRMS', 'SUCCt2m', 'SUCD1m', 'SUCOAS1m', 'SUCOASm', 'SULFOX', 'TALA', 'THRALANaEx', 'THRASNNaEx', 'THRCYSNaEx', 'THRD_L', 'THRGLNNaEx', 'THRSERNaEx', 'THRt4', 'TKT1', 'TKT2', 'TPI', 'TRPt', 'TYRTA', 'UMPK', 'UMPK2', 'UMPK3', 'UMPK4', 'UMPK5', 'UMPK7', 'VALTAm', 'VALtec', 'XYLUR', 'r0010', 'r0021', 'r0022', 'r0034', 'r0074', 'r0081', 'r0085', 'r0086', 'r0119', 'r0142', 'r0173', 'r0191', 'r0249', 'r0301', 'r0317', 'r0354', 'r0355', 'r0426', 'r0464', 'r0509', 'r0541', 'r0549', 'r0552', 'r0553', 'r0570', 'r0596', 'r0655', 'r0683', 'r0779', 'r0801', 'r0812', 'r0819', 'r0821', 'r0822', 'r0829', 'r0830', 'r0879', 'r0885', 'r0913', 'r0915', 'r0917', 'r0942', 'r1090', 'r1147', 'r1453', 'r1530', 'r1544', 'r1546', 'r1547', 'r1548', 'r1549', 'r1551', 'r1552', 'r1553', 'r1554', 'r1556', 'r1557', 'r1559', 'r1560', 'r1561', 'r1562', 'r1563', 'r1564', 'r1565', 'r1566', 'r1567', 'r1568', 'r1569', 'r1570', 'r1571', 'r1573', 'r1574', 'r1575', 'r1576', 'r1578', 'r1579', 'r1580', 'r1581', 'r1583', 'r1584', 'r1585', 'r1586', 'r1587', 'r1588', 'r1589', 'r1590', 'r1591', 'r1592', 'r1593', 'r1594', 'r1595', 'r1596', 'r1597', 'r1598', 'r1599', 'r1600', 'r1602', 'r1603', 'r1604', 'r1605', 'r1606', 'r1607', 'r1608', 'r1609', 'r1610', 'r1611', 'r1612', 'r1613', 'r1614', 'r1615', 'r1616', 'r1617', 'r1618', 'r1619', 'r1620', 'r1621', 'r1622', 'r1623', 'r1624', 'r1625', 'r1626', 'r1627', 'r1628', 'r1629', 'r1630', 'r1631', 'r1632', 'r1633' ...

# %% [markdown]
# ### Run the GIMME algorithm
#
# The `GIMMEProperties` class is used to create the properties for the GIMME algorithm. This class contains the following arguments:
# - `exp_vector`: a list of scores for each reaction in the model. This can be obtained from the `integrate()` method of the `ContinuousScoreIntegrationStrategy` class.
# - `objectives`: a list of dictionaries with the reactions to be used as objectives. Each dictionary should have the reaction id as key and the coefficient as value.
# - `preprocess`: a boolean indicating if the model should be preprocessed before running the GIMME algorithm. This is useful if you want to remove reactions that are not connected to the biomass reaction.
# - `flux_threshold`: a threshold to remove reactions with fluxes below it. This is useful if you want to remove reactions that are not connected to the biomass reaction.
# - `obj_frac`: the flux fraction of the objective reactions to be used.
#
# The `GIMME` class is used to run the GIMME algorithm. This class contains the following arguments:
# - `S`: the stoichiometric matrix of the model. It can be accessed through the `model_wrapper.S`.
# - `lb`: the lower bounds of the reactions in the model. It can be accessed through the `model_wrapper.lb`.
# - `ub`: the upper bounds of the reactions in the model. It can be accessed through the `model_wrapper.ub`.
# - `properties`: a `GIMMEProperties` instance containing the properties for the GIMME algorithm.
#
# In the end, the `run()` method of the `GIMME` class will return a list of the active reactions index that should be keep in the final model.

# %%
# Get the index of the biomass reaction in the model. This will be used as objective for the GIMME algorithm.
idx_objective = model_wrapper.model_reader.r_ids.index('biomass')

# Create the properties for the GIMME algorithm.
properties = GIMMEProperties(exp_vector=[v for k, v in scores.items()], obj_frac=0.8, objectives=[{idx_objective: 1}],
                             preprocess=True, flux_threshold=0.8, solver='GLPK', 
                             reaction_ids= model_wrapper.model_reader.r_ids, metabolite_ids=model_wrapper.model_reader.m_ids)

# Run the GIMME algorithm.
gimme = GIMME(S=model_wrapper.S, lb=model_wrapper.lb, ub=model_wrapper.ub, properties=properties)

gimme_run = gimme.run()
gimme_run
# Out:
# Could not set parameters with this solver
# Could not set parameters with this solver
# Could not set parameters with this solver
# [3,
#  4,
#  8,
#  9,
#  12,
#  15,
#  16,
#  17,
#  21,
#  22,
#  23,
#  24,
#  28,
#  29,
#  30,
#  31,
#  33,
#  34,
#  35,
#  36,
#  37,
#  38,
#  39,
#  40,
#  41,
#  43,
#  44,
#  45,
#  46,
#  51,
#  53,
#  54,
#  55,
#  57,
#  58,
#  59,
#  60,
#  63,
#  64,
#  65,
#  66,
#  67,
#  68,
#  70,
#  72,
#  73,
#  74,
#  75,
#  76,
#  79,
#  82,
#  83,
#  84,
#  85,
#  87,
#  88,
#  89,
#  90,
#  91,
#  92,
#  93,
#  94,
#  95,
#  97,
#  98,
#  99,
#  101,
#  102,
#  108,
#  109,
#  110,
#  111,
#  115,
#  117,
#  119,
#  120,
#  121,
#  123,
#  124,
#  125,
#  126,
#  128,
#  129,
#  130,
#  132,
#  133,
#  134,
#  135,
#  137,
#  138,
#  139,
#  140,
#  141,
#  142,
#  143,
#  144,
#  145,
#  147,
#  148,
#  149,
#  150,
#  151,
#  152,
#  155,
#  156,
#  157,
#  158,
#  162,
#  163,
#  164,
#  165,
#  166,
#  167,
#  168,
#  169,
#  170,
#  171,
#  172,
#  173,
#  174,
#  175,
#  186,
#  187,
#  188,
#  189,
#  195,
#  196,
#  198,
#  202,
#  205,
#  207,
#  209,
#  210,
#  211,
#  214,
#  217,
#  218,
#  219,
#  221,
#  223,
#  224,
#  225,
#  226,
#  227,
#  228,
#  230,
#  231,
#  232,
#  233,
#  234,
#  236,
#  237,
#  238,
#  239,
#  240,
#  241,
#  242,
#  243,
#  244,
#  245,
#  246,
#  248,
#  249,
#  250,
#  251,
#  252,
#  253,
#  254,
#  256,
#  257,
#  264,
#  265,
#  266,
#  267,
#  269,
#  270,
#  271,
#  274,
#  275,
#  276,
#  277,
#  278,
#  279,
#  280,
#  283,
#  284,
#  286,
#  287,
#  289,
#  290,
#  291,
#  292,
#  297,
#  302,
#  303,
#  304,
#  305,
#  308,
#  309,
#  310,
#  311,
#  312,
#  313,
#  314,
#  315,
#  316,
#  317,
#  320,
#  325,
#  326,
#  329,
#  330,
#  331,
#  332,
#  334,
#  336,
#  337,
#  338,
#  342,
#  344,
#  345,
#  346,
#  347,
#  348,
#  350,
#  351,
#  352,
#  356,
#  357,
#  359,
#  360,
#  361,
#  363,
#  364,
#  366,
#  367,
#  368,
#  369,
#  370,
#  371,
#  372,
#  373,
#  374,
#  375,
#  376,
#  377,
#  378,
#  379,
#  380,
#  381,
#  382,
#  383,
#  384,
#  385,
#  386,
#  387,
#  388,
#  389,
#  390,
#  391,
#  394,
#  395,
#  396,
#  398,
#  399,
#  401,
#  408,
#  409,
#  410,
#  411,
#  413,
#  414,
#  415,
#  416,
#  417,
#  418,
#  419,
#  420,
#  423,
#  427,
#  431,
#  432,
#  433,
#  437,
#  438,
#  439,
#  440,
#  441,
#  442,
#  443,
#  444,
#  445,
#  446,
#  447,
#  448,
#  450,
#  452,
#  453,
#  455,
#  456,
#  457,
#  458,
#  459,
#  460,
#  461,
#  462,
#  463,
#  464,
#  466,
#  467,
#  468,
#  469,
#  470,
#  471,
#  472,
#  473,
#  474,
#  475,
#  476,
#  477,
#  478,
#  479,
#  480,
#  481,
#  482,
#  483,
#  484,
#  485,
#  486,
#  487,
#  488,
#  490,
#  491,
#  494,
#  495,
#  496,
#  497,
#  498,
#  500,
#  504,
#  505,
#  507,
#  508,
#  509,
#  512,
#  513,
#  514,
#  515,
#  516,
#  517,
#  518,
#  519,
#  520,
#  521,
#  522,
#  523,
#  524,
#  525,
#  526,
#  527,
#  528,
#  529,
#  531,
#  533,
#  534,
#  535,
#  536,
#  537,
#  538,
#  539,
#  543,
#  544,
#  545,
#  546,
#  547,
#  548,
#  549,
#  550,
#  553,
#  559,
#  560,
#  561,
#  565,
#  566,
#  567,
#  568,
#  569,
#  573,
#  574,
#  575,
#  576,
#  577,
#  580,
#  585,
#  588,
#  589,
#  590,
#  592,
#  593,
#  594,
#  595,
#  596,
#  598,
#  601,
#  603,
#  604,
#  605,
#  607,
#  608,
#  609,
#  610,
#  612,
#  613,
#  616,
#  617,
#  618,
#  619,
#  621,
#  622,
#  623,
#  625,
#  626,
#  627,
#  628,
#  629,
#  633,
#  635,
#  637,
#  639,
#  640,
#  641,
#  642,
#  644,
#  645,
#  650,
#  653,
#  657,
#  658,
#  659,
#  668,
#  669,
#  672,
#  674,
#  675,
#  676,
#  677,
#  678,
#  679,
#  680,
#  681,
#  682,
#  683,
#  684,
#  685,
#  686,
#  687,
#  688,
#  689,
#  690,
#  691,
#  692,
#  693,
#  694,
#  695,
#  696,
#  697,
#  698,
#  699,
#  700,
#  701,
#  702,
#  703,
#  704,
#  705,
#  706,
#  707,
#  708,
#  709,
#  710,
#  711,
#  712,
#  713,
#  714,
#  715,
#  716,
#  717,
#  718,
#  719,
#  720,
#  721,
#  722,
#  723,
#  724,
#  725,
#  726,
#  727,
#  728,
#  729,
#  730,
#  731,
#  732,
#  733,
#  734,
#  735,
#  736,
#  737,
#  738,
#  739,
#  740,
#  741,
#  742,
#  743,
#  744,
#  745,
#  746,
#  747,
#  748,
#  749,
#  750,
#  751,
#  752,
#  753,
#  754,
#  755,
#  756,
#  757,
#  758,
#  759,
#  760,
#  761,
#  762,
#  763,
#  764,
#  765,
#  766,
#  767,
#  768,
#  769,
#  770,
#  771,
#  772,
#  773,
#  774,
#  775,
#  776,
#  777,
#  778,
#  779,
#  780,
#  781,
#  782,
#  783,
#  784,
#  785,
#  786,
#  787,
#  788,
#  789,
#  790,
#  791,
#  792,
#  793,
#  794,
#  795,
#  796,
#  797,
#  798,
#  799,
#  800,
#  801,
#  802,
#  803,
#  804,
#  805,
#  806,
#  807,
#  808,
#  809,
#  810,
#  811,
#  812,
#  813,
#  814,
#  815,
#  816,
#  817,
#  818,
#  819,
#  820,
#  821,
#  822,
#  823,
#  824,
#  825,
#  826,
#  827,
#  828,
#  829,
#  830,
#  831,
#  832,
#  833,
#  834,
#  835,
#  836,
#  837,
#  838,
#  839,
#  840,
#  841,
#  842,
#  843,
#  844,
#  845,
#  846,
#  847,
#  848,
#  849,
#  850,
#  851,
#  852,
#  853,
#  854,
#  855,
#  856,
#  857,
#  858,
#  859,
#  860,
#  861,
#  862,
#  863,
#  864,
#  865,
#  866,
#  867,
#  868,
#  869,
#  870,
#  871,
#  872,
#  873,
#  874,
#  875,
#  876,
#  877,
#  878,
#  879,
#  880,
#  881,
#  882,
#  883,
#  884,
#  885,
#  886,
#  887,
#  888,
#  889,
#  890,
#  891,
#  892,
#  893,
#  894,
#  895,
#  896,
#  897,
#  898,
#  899,
#  900,
#  901,
#  902,
#  903,
#  904,
#  905,
#  906,
#  907,
#  908,
#  909,
#  910,
#  911,
#  912,
#  913,
#  914,
#  915,
#  916,
#  917,
#  918,
#  919,
#  920,
#  921,
#  922,
#  923,
#  924,
#  925,
#  926,
#  927,
#  928,
#  929,
#  930,
#  931,
#  932,
#  933,
#  934,
#  935,
#  936,
#  937,
#  938,
#  939,
#  940,
#  941,
#  942,
#  943,
#  944,
#  945,
#  946,
#  947,
#  948,
#  949,
#  950,
#  951,
#  952,
#  953,
#  954,
#  955,
#  956,
#  957,
#  958,
#  959,
#  960,
#  961,
#  962,
#  963,
#  964,
#  965,
#  966,
#  967,
#  968,
#  969,
#  970,
#  971,
#  972,
#  973,
#  974,
#  975,
#  976,
#  977,
#  978,
#  979,
#  980,
#  981,
#  982,
#  983,
#  984,
#  985,
#  986,
#  987,
#  988,
#  989,
#  990,
#  991,
#  992,
#  993,
#  994,
#  995,
#  996,
#  997,
#  998,
#  999,
#  1000,
#  1001,
#  1002,
#  1003,
#  1004,
#  1005,
#  1006,
#  1007,
#  1008,
#  1009,
#  1010,
#  1011,
#  1012,
#  1013,
#  1014,
#  1015,
#  1016,
#  1017,
#  1018,
#  1019,
#  1020,
#  1021,
#  1022,
#  1023,
#  1024,
#  1025,
#  1026,
#  1027,
#  1028,
#  1029,
#  1030,
#  1031,
#  1032,
#  1033,
#  1034,
#  1035,
#  1036,
#  1037,
#  1038,
#  1039,
#  1040,
#  1041,
#  1042,
#  1043,
#  1044,
#  1045,
#  1046,
#  1047,
#  1048,
#  1049,
#  1050,
#  1051,
#  1052,
#  1053,
#  1054,
#  1055,
#  1056,
#  1057,
#  1058,
#  1059,
#  1060,
#  1061,
#  1062,
#  1063,
#  1064,
#  1065,
#  1066,
#  1067,
#  1068,
#  1069,
#  1070,
#  1071,
#  1072,
#  1073,
#  1074,
#  1075,
#  1076,
#  1077,
#  1078,
#  1079,
#  1080,
#  1081,
#  1160,
#  1161,
#  1162,
#  1163,
#  1164,
#  1165,
#  1166,
#  1167,
#  1168,
#  1169,
#  1170,
#  1171,
#  1172,
#  1173,
#  1174,
#  1175,
#  1176,
#  1177,
#  1178,
#  1179,
#  1180,
#  1184,
#  1185,
#  1186,
#  1187,
#  1188,
#  1189,
#  1190,
#  1191,
#  1192,
#  1193,
#  1194,
#  1195,
#  1196,
#  1197,
#  1198,
#  1199,
#  1200,
#  1201,
#  1202,
#  1203,
#  1204,
#  1205,
#  1206,
#  1227,
#  1228,
#  1230,
#  1231,
#  1232,
#  1233,
#  1235,
#  1243,
#  1244,
#  1251,
#  1254,
#  1255,
#  1266,
#  1267,
#  1270,
#  1271,
#  1273,
#  1276,
#  1277,
#  1280,
#  1284,
#  1286,
#  1288,
#  1289,
#  1291,
#  1292,
#  1294,
#  1295,
#  1298,
#  1304,
#  1308,
#  1311,
#  1313,
#  1314,
#  1315,
#  1316,
#  1321,
#  1325,
#  1326,
#  1328,
#  1332,
#  1334,
#  1336,
#  1337,
#  1338,
#  1341,
#  1359,
#  1361,
#  1362,
#  1363,
#  1364,
#  1365,
#  1366,
#  1372,
#  1380,
#  1386,
#  1387,
#  1388,
#  1391,
#  1393,
#  1394]

# %% [markdown]
# Moreover, to access the flux distribution determined by the algorithm, you can use the `sol` attribute of the `GIMME` class.

# %%
gimme.sol.__dict__['_Solution__value_map']
# Out:
# OrderedDict([('2AMACHYD', 0.0),
#              ('2AMADPTm', 0.0),
#              ('2DR1PP', 0.0),
#              ('2HCO3_NAt', 0.0),
#              ('2OXOADOXm', 0.0),
#              ('2OXOADPTm', 0.0),
#              ('34HPPOR', 0.0),
#              ('3AIBt', 0.0),
#              ('3AIBTm', 0.0),
#              ('3AIBtm', 0.0),
#              ('3HAO', 0.0),
#              ('3HBCOAHLm', 0.0),
#              ('3HKYNAKGAT', 0.0),
#              ('3MOBt2im', 0.0),
#              ('3MOPt2im', 0.0),
#              ('3SALAASPm', 0.0),
#              ('3SALATAi', 0.0),
#              ('3SALATAim', 0.0),
#              ('3SPYRSP', 0.0),
#              ('3SPYRSPm', 0.0),
#              ('4ABUTtm', 0.0),
#              ('4MOPt2im', 0.003463076480964108),
#              ('5MTHFt', 0.0),
#              ('5MTHFt2', 0.0),
#              ('AACOAT', 0.0),
#              ('AACTOOR', 0.0),
#              ('AACTtm', 0.0),
#              ('AASAD3m', 0.0),
#              ('AATAi', 0.0),
#              ('ABTArm', 0.0),
#              ('ABUTD', 0.0),
#              ('ABUTt2r', 0.0),
#              ('ABUTt4_2_r', 0.0),
#              ('ACACT10m', 0.0),
#              ('ACACT1r', 0.0),
#              ('ACACt2', 0.0),
#              ('ACACt2m', 0.0),
#              ('ACETONEt2', 0.0),
#              ('ACETONEt2m', 0.0),
#              ('ACITL', 0.0),
#              ('ACOAD10m', 0.0),
#              ('ACOAD9m', 0.0),
#              ('ACOAHi', 0.0),
#              ('ACONT', 0.0),
#              ('ACONTm', 0.0015768901522000777),
#              ('ACS', 0.12796775738955382),
#              ('ACSm', 0.0),
#              ('ACt2m', 0.0),
#              ('ACt2r', 0.0),
#              ('ACTLMO', 0.0),
#              ('ACTNMO', 0.0),
#              ('ACYP', 0.0),
#              ('ADCim', 0.0),
#              ('ADEt', 0.0),
#              ('ADK1', 0.1549350869709241),
#              ('ADK1m', 0.0),
#              ('ADK3', 0.0),
#              ('ADK3m', 0.0),
#              ('ADMDC', 0.0),
#              ('ADNK1', 0.0),
#              ('ADPT', 0.0013175737692186634),
#              ('ADPtx', 0.0),
#              ('AGTim', 0.0),
#              ('AHC', 0.0013175737692186634),
#              ('AKGDm', 0.0037399629957364016),
#              ('AKGMALtm', 0.0),
#              ('AKGt4_3', 0.0),
#              ('ALAASNNaEx', 0.0),
#              ('ALACYSNaEx', 0.0),
#              ('ALAGLNexR', 0.0),
#              ('ALAGLNNaEx', 0.0),
#              ('ALAGLYexR', 0.0),
#              ('ALASERNaEx', 0.0),
#              ('ALAt2r', 0.03688542028802604),
#              ('ALAt4', 0.0),
#              ('ALATA_L', 0.014305030053787873),
#              ('ALATHRNaEx', 0.0),
#              ('ALAtN1', 0.0),
#              ('AMCOXO', 0.0),
#              ('AMETt2m', 0.0),
#              ('AMPtp', 0.0),
#              ('AOBUTDsm', 0.0),
#              ('APAT2rm', 0.0),
#              ('ARGLYSex', 0.0),
#              ('ARGN', 0.015373254431481641),
#              ('ARGNm', 0.0),
#              ('ARGt4', 0.0),
#              ('ARGtiDF', 0.025537338353439437),
#              ('ARGtm', 0.0),
#              ('ASNALANaEx', 0.007905414323590348),
#              ('ASNCYSNaEx', 0.0),
#              ('ASNGLNNaEx', 0.0),
#              ('ASNS1', 0.0),
#              ('ASNSERNaEx', 0.0),
#              ('ASNt4', 0.0),
#              ('ASNTHRNaEx', 0.0),
#              ('ASNtN1', 0.0),
#              ('ASPGLUm', 0.0),
#              ('ASPTA', 0.008530580237375789),
#              ('ASPTAm', 0.0),
#              ('ATP1ter', 0.0),
#              ('ATPS4m', 0.0),
#              ('ATPtm', 0.0),
#              ('ATPtx', 0.0),
#              ('BALAtmr', 0.0),
#              ('BALAVECSEC', 0.0),
#              ('BETALDHxm', 0.0),
#              ('BHMT', 0.0),
#              ('CATm', 0.00017537560498285675),
#              ('CATp', 0.0),
#              ('CBPS', 0.0032539723662082494),
#              ('CBPSam', 0.0),
#              ('CHLtm', 0.0),
#              ('CHOLD2m', 0.0),
#              ('CHOLt4', 0.0),
#              ('CHOLtu', 0.00486473324694294),
#              ('CHSTEROLt', 0.0),
#              ('CHSTEROLt1', 0.000577179413494018),
#              ('CHSTEROLt2', 0.0),
#              ('CHSTEROLt3', 0.000577179413494018),
#              ('CITL', 0.12796775738955382),
#              ('CITRtm', 0.0),
#              ('CITt4_2', 0.0),
#              ('CITtam', 0.0),
#              ('CITtbm', 0.29387315109725454),
#              ('CK', 0.0),
#              ('CKc', 0.0),
#              ('CLFORtex', 0.0),
#              ('CLHCO3tex2', 0.0),
#              ('CLOHtex2', 0.0),
#              ('CLOXAtex2', 0.0),
#              ('CO2t', 0.0),
#              ('CO2ter', 0.004328845601205136),
#              ('CO2tm', 0.4274567934540614),
#              ('COAtm', 0.0034630764809641112),
#              ('CREATt4_2_r', 0.0),
#              ('CREATtmdiffir', 0.0),
#              ('CSm', 0.12639086723735413),
#              ('CTPS1', 1.5730197240270507e-05),
#              ('CTPS2', 0.0013557958851754448),
#              ('CYOR_u10m', 0.0701502419931427),
#              ('CYSALANaEx', 0.0),
#              ('CYSASNNaEx', 0.0),
#              ('CYSGLNNaEx', 0.0),
#              ('CYSGLUexR', 0.0),
#              ('CYSGLYexR', 0.0),
#              ('CYSO', 0.0),
#              ('CYSSERNaEx', 0.02016464229817464),
#              ('CYSt4', 0.0),
#              ('CYStec', 0.0),
#              ('CYSTGL', 0.0013175737692186634),
#              ('CYSTHRNaEx', 0.0),
#              ('CYSTS', 0.0013175737692186634),
#              ('D_3AIBt', 0.0),
#              ('D3AIBTm', 0.0),
#              ('DATPtn', 0.0003729697665845616),
#              ('DCTPtn', 0.00026713043587130625),
#              ('DGTPtn', 0.0002800314609462179),
#              ('DHPR', 0.0),
#              ('ATPM', 0.0),
#              ('DMGDHm', 0.0),
#              ('DMGtm', 0.0),
#              ('DNDPt11m', 0.0),
#              ('DNDPt23m', 0.0),
#              ('DNDPt24m', 0.0),
#              ('DNDPt34m', 0.0),
#              ('DNDPt35m', 0.0),
#              ('DNDPt9m', 0.0),
#              ('DPGase', 0.0),
#              ('DPGM', 0.0),
#              ('DRBK', 0.0),
#              ('DTTPtn', 0.00037036692819225484),
#              ('ECOAH12m', 0.0),
#              ('ECOAH1m', 0.0),
#              ('ECOAH9m', 0.0),
#              ('ENO', 0.28242038022880306),
#              ('EX_3aib_e', 0.0),
#              ('EX_3aib_D_e', 0.0),
#              ('EX_4abut_e', 0.0),
#              ('EX_ac_e', 0.0),
#              ('EX_acac_e', 0.0),
#              ('EX_acetone_e', 0.0),
#              ('EX_ade_e', 0.0),
#              ('EX_akg_e', 0.0),
#              ('EX_ala_B_e', 0.0),
#              ('EX_ala_L_e', -0.0),
#              ('EX_arg_L_e', 0.025537338353439437),
#              ('EX_asn_L_e', 0.007905414323590314),
#              ('EX_asp_L_e', 0.00978149122964655),
#              ('EX_chol_e', 0.00486473324694294),
#              ('EX_chsterol_e', 0.0),
#              ('EX_cit_e', -0.0),
#              ('EX_co2_e', 0.0),
#              ('EX_creat_e', 0.0),
#              ('EX_for_e', 0.0),
#              ('EX_glc_e', 0.15951405462450038),
#              ('EX_gln_L_e', 0.020216839919201108),
#              ('EX_glu_L_e', 0.0),
#              ('EX_gly_e', 0.003116449611733425),
#              ('EX_glyb_e', 0.0),
#              ('EX_gthrd_e', 0.0),
#              ('EX_h_e', 0.0),
#              ('EX_h2o_e', 0.36591285064547585),
#              ('EX_h2o2_e', 0.0),
#              ('EX_hco3_e', 0.0),
#              ('EX_his_L_e', 0.00357624336758614),
#              ('EX_hista_e', 0.0),
#              ('EX_ile_L_e', 0.00809363914776441),
#              ('EX_lac_L_e', 0.0),
#              ('EX_leu_L_e', 0.01889745547979655),
#              ('EX_lys_L_e', 0.016751924476329446),
#              ('EX_met_L_e', 0.005646716433501182),
#              ('EX_mthgxl_e', 0.0),
#              ('EX_nh4_e', 0.0),
#              ('EX_o2_e', 0.03974360890306894),
#              ('EX_o2s_e', 0.0),
#              ('EX_orn_e', 0.0),
#              ('EX_phe_L_e', 0.00734073985106803),
#              ('EX_pi_e', 0.03512173934725061),
#              ('EX_pro_L_e', 0.0015366126240673051),
#              ('EX_pyr_e', 0.0),
#              ('EX_ser_L_e', 0.028653201678607753),
#              ('EX_so4_e', 0.0),
#              ('EX_succ_e', 0.1449105696204708),
#              ('EX_thr_L_e', 0.008846538444460787),
#              ('EX_trp_L_e', 0.00037644964834818905),
#              ('EX_tyr_L_e', 0.004517367488456613),
#              ('EX_urea_e', 0.015373254431481641),
#              ('EX_val_L_e', 0.009975859097783698),
#              ('FALDtm', 0.0),
#              ('FBA', 0.14571321605762227),
#              ('FBP', 0.0),
#              ('FDH', 0.000577179413494018),
#              ('FKYNH', 0.0),
#              ('FORtr', 0.000577179413494018),
#              ('FTCD', 0.0),
#              ('FTHFDH', 0.0072497220780096865),
#              ('FUM', 0.07928778308527618),
#              ('FUMAC', 0.0),
#              ('FUMm', 0.21405857593776148),
#              ('FUMSO3tm', 0.0),
#              ('FUMSO4tm', 0.0),
#              ('FUMtm', 0.0),
#              ('FUMTSULtm', 0.0),
#              ('G3PD1', 0.007915542759942995),
#              ('G3PD2m', 0.0),
#              ('G5SADrm', 0.010133269891283247),
#              ('G5SADs', 0.0),
#              ('G5SDym', 0.0),
#              ('G6PDA', 0.0),
#              ('G6PDH1rer', 0.0),
#              ('G6PDH2r', 0.0),
#              ('G6PDH2rer', 0.003174486774217099),
#              ('G6PPer', 0.0),
#              ('G6Pter', 0.003174486774217099),
#              ('GABAVESSEC', 0.0),
#              ('GACMTRc', 0.0),
#              ('GAPD', 0.28242038022880306),
#              ('GCC2am', 0.0),
#              ('GCC2bim', 0.0),
#              ('GCC2cm', 0.0),
#              ('GCCam', 0.0),
#              ('GCCbim', 0.0),
#              ('GCCcm', 0.0),
#              ('GF6PTA', -3.469446951953611e-18),
#              ('GHMT2r', 0.014004172581210558),
#              ('GHMT2rm', 3.0357660829594124e-18),
#              ('GK1', 0.0013018435719781992),
#              ('GLCMter', 0.0),
#              ('GLCt1r', 0.16640085128594856),
#              ('GLCt2_2', 0.006886796661448185),
#              ('GLCt4', 0.0),
#              ('GLCter', 0.0),
#              ('GLCURter', 0.0),
#              ('GLNALANaEx', 0.0),
#              ('GLNASNNaEx', 0.0),
#              ('GLNCYSNaEx', 0.0),
#              ('GLNS', 0.0),
#              ('GLNSERNaEx', 0.0),
#              ('GLNt4', 0.0),
#              ('GLNTHRNaEx', 0.0),
#              ('GLNtm', 0.0),
#              ('GLNtN1', 0.0),
#              ('GLU5Km', 0.0),
#              ('GLUCYS', 0.0),
#              ('GLUDC', 0.0),
#              ('GLUDxm', 0.0013175737692186127),
#              ('GLUDym', 0.0),
#              ('GluForTx', 0.0),
#              ('GLUNm', 4.336808689942018e-19),
#              ('GLUPRT', 0.003192041787504309),
#              ('GLUt2m', 0.0294289350937447),
#              ('GLUTCOADHm', 0.1385354590862967),
#              ('GLUVESSEC', 0.0),
#              ('GLXtm', 0.0),
#              ('GLXtp', 0.0),
#              ('GLYAMDTRc', 0.0),
#              ('GLYATm', 0.0),
#              ('GLYBt4_2_r', 0.0),
#              ('GLYBtm', 0.0),
#              ('GLYC3Ptm', 0.0),
#              ('GLYOp', 0.0),
#              ('GLYt2r', 0.0),
#              ('GLYt4', 0.0),
#              ('GLYt7_211_r', 1.973247953923618e-16),
#              ('GLYtm', 0.002635147538437333),
#              ('GLYtp', 0.0),
#              ('GLYVESSEC', 0.0),
#              ('GMPS2', 0.0),
#              ('GND', 0.0),
#              ('GNDer', 0.003174486774217099),
#              ('GNMT', 0.0013175737692186634),
#              ('GTHO', 0.0),
#              ('GTHOm', 0.0),
#              ('GTHP', 0.0),
#              ('GTHPm', 0.0),
#              ('GTHRDt', 1.2813377047516288),
#              ('GTHS', 0.0),
#              ('GULNDer', 0.0),
#              ('GULNter', 0.0),
#              ('H2CO3D', 0.6103044272474193),
#              ('H2O2syn', 0.0),
#              ('H2O2t', 0.0),
#              ('H2O2tm', 0.0),
#              ('H2O2tp', 0.0),
#              ('H2Ot', 0.36591285064547585),
#              ('H2Oter', 0.003174486774217099),
#              ('H2Otm', 0.0),
#              ('H2Otp', 0.0),
#              ('HACD1m', 0.0),
#              ('HACD9m', 0.0),
#              ('HCO3_CLt', 0.0),
#              ('HEX1', 0.15951405462450038),
#              ('HGNTOR', 0.0),
#              ('HIBDm', 2.6020852139652106e-18),
#              ('HISD', 0.0),
#              ('HISDC', 0.0),
#              ('HISt4', 0.00357624336758614),
#              ('HISTAtu', 0.0),
#              ('HISTAVESSEC', 0.0),
#              ('HIStiDF', 0.0),
#              ('HIStN1', 0.0),
#              ('HKYNH', 0.0),
#              ('HMGCOASim', 0.0),
#              ('HMGCOAtm', 0.003463076480964108),
#              ('HMGLm', 0.0),
#              ('HOMt4', 0.0),
#              ('Htm', 0.0),
#              ('Htr', 0.0017315382404820539),
#              ('Htx', 0.0),
#              ('ICDHxm', 0.0),
#              ('ICDHy', 0.0),
#              ('ICDHyrm', 0.0015768901522000777),
#              ('ILEt4', 0.0),
#              ('ILEt5m', 0.0),
#              ('ILETA', 0.0),
#              ('ILETAm', 0.0),
#              ('ILEtec', 0.0),
#              ('IZPN', 0.0),
#              ('KCC2t', 0.0),
#              ('KYN3OX', 0.0),
#              ('KYNAKGAT', 0.0),
#              ('KYNATESYN', 0.0),
#              ('LDH_L', 0.0),
#              ('LEUt4', 0.01889745547979655),
#              ('LEUt5m', 0.0),
#              ('LEUTA', 0.003463076480964108),
#              ('LEUTAm', 0.0),
#              ('LEUtec', 0.0),
#              ('L_LACDcm', 0.0),
#              ('L_LACt2r', 0.023111826965129652),
#              ('L_LACt4r', 0.023111826965129652),
#              ('LYSt4', 0.016751924476329446),
#              ('LYStiDF', 0.0),
#              ('LYStm', 0.0),
#              ('MACACI', 0.0),
#              ('MALSO3tm', 0.0),
#              ('MALSO4tm', 0.0),
#              ('MALtm', 0.07509153534551483),
#              ('MALTSULtm', 0.0),
#              ('MCCCrm', 0.003463076480964108),
#              ('MDH', 0.11943717715217839),
#              ('MDHm', 0.07003399858055977),
#              ('ME1m', 0.0),
#              ('ME2', 0.054700382880252814),
#              ('ME2m', 0.0),
#              ('METAT', 0.0013175737692186634),
#              ('METLEUex', 0.0),
#              ('METS', 0.0),
#              ('METt4', 0.0),
#              ('METtec', 0.0),
#              ('MGCHrm', 0.003463076480964108),
#              ('MGSA', 0.0),
#              ('MGSA2', 0.0),
#              ('MMEm', 0.0013175737692186634),
#              ('MMMm', 0.0013175737692186634),
#              ('MMSAD3m', 0.0),
#              ('MMTSADm', 0.0),
#              ('MTHFC', 0.013633805653018303),
#              ('MTHFD', 0.013633805653018303),
#              ('MTHGXLt', 0.0),
#              ('NADH2_u10m', 0.1301879793158476),
#              ('NADHtpu', 0.0),
#              ('NADHtru', 0.0),
#              ('NADPHtru', 0.0),
#              ('NADPtru', 0.0),
#              ('NADtpu', 0.0),
#              ('NADtru', 0.0),
#              ('NAHCO3_HCLt', 0.0),
#              ('NAt', 0.0),
#              ('NAt3_1', 0.0),
#              ('NAt5', 0.0),
#              ('NCCt', 0.0),
#              ('NDPK1', 0.7868062918242087),
#              ('NDPK1m', 0.49507866716535115),
#              ('NDPK2', 0.14896718842383053),
#              ('NDPK3', 0.0),
#              ('NDPK4', 0.0),
#              ('NDPK5', 0.0035340038271544673),
#              ('NDPK8', 0.0),
#              ('NDPK9', 0.0),
#              ('NH4t3r', 0.0),
#              ('NH4tp', 0.0),
#              ('NKCC2t', 0.0),
#              ('NRPPHRt4_2_r', 0.0),
#              ('NRPPHRtu', 0.0),
#              ('NRPPHRVESSEC', 0.0),
#              ('NTD7', 0.0),
#              ('O2St', 0.0),
#              ('O2Stm', 0.0),
#              ('O2Stx', 0.0),
#              ('O2t', 0.03974360890306894),
#              ('O2ter', 0.0051946147214461625),
#              ('O2tm', 0.03454899418162278),
#              ('O2tp', 0.0),
#              ('OBDHc', 0.0),
#              ('OCBTm', 0.0),
#              ('OIVD1m', 0.003463076480964108),
#              ('OIVD2m', 0.0),
#              ('OIVD3m', 0.0),
#              ('ORNDC', 0.0),
#              ('ORNt3m', 0.015373254431481638),
#              ('ORNt4m', 0.0),
#              ('ORNTArm', 0.015373254431481638),
#              ('ORNtiDF', 0.0),
#              ('OXAHCOtex', 0.0),
#              ('P5CDm', 0.0),
#              ('P5CRm', 0.0),
#              ('P5CRxm', 0.0),
#              ('PCLAD', 0.0),
#              ('PCm', 0.49029801691516833),
#              ('PCREATtmdiffir', 0.0),
#              ('PDHm', 0.12639086723735413),
#              ('PE_HStm', 0.0015666257949520984),
#              ('PEPCK', 0.0),
#              ('PEPCKm', 0.29387315109725454),
#              ('PFK', 0.0),
#              ('PGCD', 0.0),
#              ('PGI', 0.14789423431061924),
#              ('PGK', 0.28242038022880306),
#              ('PGL', 0.0),
#              ('PGLer', 0.003174486774217099),
#              ('PGM', 0.28242038022880306),
#              ('PHEt4', 0.00734073985106803),
#              ('PHEtec', 0.0),
#              ('PIt7', 0.0),
#              ('PIter', 0.0),
#              ('PPA', 0.0),
#              ('PPAm', 0.15687833216455435),
#              ('PPCOACm', 0.0013175737692186634),
#              ('PPCOAOm', 0.0),
#              ('PPItr', 0.001154358826988036),
#              ('PPM', 0.0013175737692186634),
#              ('PRFGS', 0.003192041787504309),
#              ('PRO1xm', 0.06164740302513578),
#              ('PROD2m', 0.0),
#              ('PROt2r', 0.0),
#              ('PROt4', 0.0),
#              ('PRPNCOAHYDm', 0.0),
#              ('PRPPS', 0.007763587922931222),
#              ('PSERT', 0.0),
#              ('PSFLIPm', 0.0015666257949520984),
#              ('PSP_L', 0.0),
#              ('PTRCOX1', 0.0),
#              ('PUNP1', 0.0013175737692186634),
#              ('PYK', 0.5755501946312808),
#              ('PYRt2m', 0.6166888841525225),
#              ('PYRt2p', 0.0),
#              ('PYRt2r', 0.0),
#              ('RETNt', 0.0),
#              ('RPE', 0.0),
#              ('RPI', 0.005355505027214072),
#              ('SACCD3m', 0.0),
#              ('SACCD4m', 0.0),
#              ('SARCStm', 0.0013175737692186634),
#              ('SARDHm', 0.0013175737692186634),
#              ('SERALANaEx', 0.0),
#              ('SERASNNaEx', 0.0),
#              ('SERCYSNaEx', 0.0),
#              ('SERGLNexR', 0.0),
#              ('SERGLNNaEx', 0.0),
#              ('SERGLYexR', 0.0),
#              ('SERHL', 0.0),
#              ('SERLYSNaex', 0.0),
#              ('SERt4', 0.06180530026135161),
#              ('SERTHRNaEx', 0.0),
#              ('SERtN1', 0.0),
#              ('SO4CLtex2', 0.0),
#              ('SO4HCOtex', 0.0),
#              ('SO4OXAtex2', 0.0),
#              ('SO4t4_2', 0.0),
#              ('SPMDOX', 0.0),
#              ('SPMS', 0.0),
#              ('SPODM', 0.0),
#              ('SPODMe', 0.0),
#              ('SPODMm', 0.0003507512099657135),
#              ('SPODMx', 0.0),
#              ('SPRMS', 0.0),
#              ('SUCCt2m', 0.0),
#              ('SUCCt4_2', 0.1449105696204708),
#              ('SUCD1m', 0.13985303285551573),
#              ('SUCOAS1m', 0.005057536764955065),
#              ('SUCOASm', 0.0),
#              ('SULFOX', 0.0),
#              ('TALA', 0.0010905091264984865),
#              ('THD1m', 0.0),
#              ('THRALANaEx', 0.0),
#              ('THRASNNaEx', 0.0),
#              ('THRCYSNaEx', 0.02016464229817464),
#              ('THRD_L', 0.0),
#              ('THRGLNexR', 0.0),
#              ('THRGLNNaEx', 0.0),
#              ('THRGLYexR', 0.0),
#              ('THRSERNaEx', 0.0),
#              ('THRt4', 0.0),
#              ('TKT1', 0.0010905091264984865),
#              ('TKT2', 0.0010905091264984865),
#              ('TPI', 0.13779767329767928),
#              ('TRPO2', 0.0),
#              ('TRPt', 0.0),
#              ('TRPt4', 0.0),
#              ('TYRt', 0.0),
#              ('TYRt4', 0.0),
#              ('TYRTA', 0.0),
#              ('UDPGLCAter', 0.0),
#              ('UMPK', 0.0),
#              ('UMPK2', 0.0),
#              ('UMPK3', 0.0),
#              ('UMPK4', 0.0),
#              ('UMPK5', 0.0),
#              ('UMPK7', 0.0032539723662082494),
#              ('UMPtr', 0.0),
#              ('URCN', 0.0),
#              ('UREAt', 0.015373254431481641),
#              ('UREAt5', 0.0),
#              ('UREAtm', 0.0),
#              ('VALt4', 0.0),
#              ('VALt5m', 0.0),
#              ('VALTA', 0.0),
#              ('VALTAm', 0.0),
#              ('VALtec', 0.009975859097783698),
#              ('XYLUR', 0.0),
#              ('EX_fald_e', 0.0),
#              ('EX_ptrc_e', 0.0),
#              ('EX_spmd_e', 0.0),
#              ('r0010', 0.0),
#              ('r0021', 0.0),
#              ('r0022', 0.0),
#              ('r0028', 0.0),
#              ('r0034', 0.0),
#              ('r0055', 0.0),
#              ('r0060', 0.0),
#              ('r0062', 0.0),
#              ('r0074', 0.005239984540198408),
#              ('r0081', 0.0),
#              ('r0085', 0.0),
#              ('r0086', 0.0),
#              ('r0119', 0.0),
#              ('r0122', 0.0),
#              ('r0127', 0.0),
#              ('r0142', 0.0),
#              ('r0153', 0.0),
#              ('r0156', 0.0),
#              ('r0157', 0.0),
#              ('r0165', 0.0),
#              ('r0173', 0.0),
#              ('r0178', 0.0),
#              ('r0179', 0.0),
#              ('r0191', 0.14571321605762227),
#              ('r0202', 0.0),
#              ('r0249', 0.0),
#              ('r0280', 0.0),
#              ('r0295', 0.0013175737692186665),
#              ('r0301', 0.0),
#              ('r0317', 0.0),
#              ('r0354', 0.0),
#              ('r0355', 0.0),
#              ('r0365', 0.0),
#              ('r0398', 0.0),
#              ('r0399', 0.0),
#              ('r0413', 0.0),
#              ('r0426', 0.0),
#              ('r0450', 0.0),
#              ('r0464', 0.0015768901522000777),
#              ('r0483', 2.6020852139652106e-18),
#              ('r0509', 0.0),
#              ('r0525', 0.0),
#              ('r0541', 0.1385354590862967),
#              ('r0549', 0.0015768901522000777),
#              ('r0552', 0.1552744728019834),
#              ('r0553', 0.1552744728019834),
#              ('r0560', 0.0),
#              ('r0570', 0.0),
#              ('r0596', 0.0),
#              ('r0645', 0.0),
#              ('r0647', 0.0),
#              ('r0655', 0.003463076480964108),
#              ('r0669', 0.0),
#              ('r0683', 0.0),
#              ('r0779', -2.6020852139652106e-18),
#              ('r0784', 0.0),
#              ('r0792', 0.0),
#              ('r0801', 0.7838942814976506),
#              ('r0812', 0.0),
#              ('r0817', 0.0),
#              ('r0819', 0.0),
#              ('r0821', 0.1449105696204708),
#              ('r0822', 0.21911611270271655),
#              ('r0829', 0.0),
#              ('r0830', 0.0),
#              ('r0838', 0.0),
#              ('r0839', 0.0),
#              ('r0840', 0.0),
#              ('r0841', 0.003174486774217099),
#              ('r0860', 0.0),
#              ('r0879', 0.0),
#              ('r0881', 0.0),
#              ('r0885', 0.8788693300750197),
#              ('r0899', 0.0),
#              ('r0911', 0.010133269891283247),
#              ('r0913', 0.0),
#              ('r0915', 0.0),
#              ('r0917', 0.0),
#              ('r0924', 0.0),
#              ('r0941', 0.4950786671653511),
#              ('r0942', 0.0),
#              ('r0944', 0.0),
#              ('r0946', 0.0),
#              ('r1030', 0.0),
#              ('r1050', 0.0),
#              ('r1051', 0.000577179413494018),
#              ('r1052', 0.0),
#              ('r1088', 0.0),
#              ('r1090', 0.0),
#              ('r1109', 0.0),
#              ('r1143', 0.0),
#              ('r1144', 0.0),
#              ('r1147', 0.0),
#              ('r1154', 0.0013175737692186634),
#              ('r1155', 0.0013175737692186634),
#              ('r1162', 0.0),
#              ('r1291', 0.0),
#              ('r1421', 0.0),
#              ('r1427', 0.0),
#              ('r1428', 0.0),
#              ('r1429', 0.0),
#              ('r1434', 0.0),
#              ('r1435', 0.0),
#              ('r1453', 0.07178067291641942),
#              ('r1454', 0.0),
#              ('r1464', 0.0),
#              ('r1493', 0.0),
#              ('r1530', 0.0),
#              ('r1538', 0.0),
#              ('r1544', 0.003116449611733405),
#              ('r1546', 0.0),
#              ('r1547', 0.0),
#              ('r1548', 0.0),
#              ('r1549', 0.0),
#              ('r1551', 0.0),
#              ('r1552', 0.0),
#              ('r1553', 0.0),
#              ('r1554', 0.0),
#              ('r1556', 0.0),
#              ('r1557', 0.0),
#              ('r1559', 0.0),
#              ('r1560', 0.028980005964435694),
#              ('r1561', 0.0),
#              ('r1562', 0.0),
#              ('r1563', 0.0),
#              ('r1564', 0.0),
#              ('r1565', 0.0),
#              ('r1566', 0.0),
#              ('r1567', 0.0),
#              ('r1568', 0.0),
#              ('r1569', 0.0),
#              ('r1570', 0.0),
#              ('r1571', 0.0),
#              ('r1573', 0.0),
#              ('r1574', 0.0),
#              ('r1575', 0.0),
#              ('r1576', 0.0),
#              ('r1578', 0.0),
#              ('r1579', 0.0),
#              ('r1580', 0.0),
#              ('r1581', 0.0),
#              ('r1583', 0.0),
#              ('r1584', 0.0),
#              ('r1585', 0.0),
#              ('r1586', 0.0),
#              ('r1587', 0.0),
#              ('r1588', 0.0),
#              ('r1589', 0.0),
#              ('r1590', 0.0),
#              ('r1591', 0.0),
#              ('r1592', 0.0),
#              ('r1593', 0.0),
#              ('r1594', 0.0),
#              ('r1595', 0.0),
#              ('r1596', 0.0),
#              ('r1597', 0.0),
#              ('r1598', 0.0),
#              ('r1599', 0.0),
#              ('r1600', 0.0),
#              ('r1602', 0.0),
#              ('r1603', 0.0),
#              ('r1604', 0.0),
#              ('r1605', 0.0),
#              ('r1606', 0.0),
#              ('r1607', 0.0),
#              ('r1608', 0.0),
#              ('r1609', 0.0),
#              ('r1610', 0.0),
#              ('r1611', 0.0),
#              ('r1612', 0.0),
#              ('r1613', 0.0),
#              ('r1614', 0.0),
#              ('r1615', 0.0),
#              ('r1616', 0.0),
#              ('r1617', 0.0),
#              ('r1618', 0.0),
#              ('r1619', 0.0),
#              ('r1620', 0.0),
#              ('r1621', 0.0),
#              ('r1622', 0.0),
#              ('r1623', 0.0),
#              ('r1624', 0.0),
#              ('r1625', 0.0),
#              ('r1626', 0.0),
#              ('r1627', 0.0),
#              ('r1628', 0.0),
#              ('r1629', 0.0),
#              ('r1630', 0.0),
#              ('r1631', 0.0),
#              ('r1632', 0.0),
#              ('r1633', 0.0),
#              ('r1634', 0.0),
#              ('r1635', 0.0),
#              ('r1636', 0.0),
#              ('r1637', 0.0),
#              ('r1638', 0.0),
#              ('r1639', 0.0),
#              ('r1640', 0.0),
#              ('r1641', 0.0),
#              ('r1642', 0.0),
#              ('r1643', 0.0),
#              ('r1644', 0.0),
#              ('r1645', 0.0),
#              ('r1646', 0.0),
#              ('r1647', 0.0),
#              ('r1648', 0.0),
#              ('r1649', 0.0),
#              ('r1650', 0.0),
#              ('r1651', 0.0),
#              ('r1652', 0.0),
#              ('r1653', 0.0),
#              ('r1654', 0.0),
#              ('r1655', 0.0),
#              ('r1656', 0.0),
#              ('r1657', 0.0),
#              ('r1658', 0.0),
#              ('r1659', 0.0),
#              ('r1660', 0.0),
#              ('r1661', 0.0),
#              ('r1662', 0.0),
#              ('r1664', 0.0),
#              ('r1665', 0.0),
#              ('r1666', 0.0),
#              ('r1667', 0.0),
#              ('r1668', 0.0),
#              ('r1669', 0.0),
#              ('r1670', 0.0),
#              ('r1671', 0.0),
#              ('r1672', 0.0),
#              ('r1673', 0.0),
#              ('r1674', 0.0),
#              ('r1675', 0.0),
#              ('r1676', 0.0),
#              ('r1677', 0.0),
#              ('r1678', 0.0),
#              ('r1679', 0.0),
#              ('r1680', 0.0),
#              ('r1681', 0.0),
#              ('r1682', 0.0),
#              ('r1683', 0.0),
#              ('r1684', 0.0),
#              ('r1685', 0.0),
#              ('r1686', 0.0),
#              ('r1687', 0.0),
#              ('r1690', 0.0),
#              ('r1691', 0.0),
#              ('r1692', 0.0),
#              ('r1693', 0.0),
#              ('r1695', 0.0),
#              ('r1696', 0.0),
#              ('r1698', 0.0),
#              ('r1700', 0.0),
#              ('r1701', 0.0),
#              ('r1702', 0.0),
#              ('r1705', 0.023333289530934512),
#              ('r1706', 0.0),
#              ('r1707', 0.0),
#              ('r1708', 0.0),
#              ('r1710', 0.0),
#              ('r1711', 0.0),
#              ('r1713', 0.0),
#              ('r1715', 0.0),
#              ('r1716', 0.0),
#              ('r1717', 0.0),
#              ('r1720', 0.0),
#              ('r1721', 0.0),
#              ('r1722', 0.0),
#              ('r1723', 0.0),
#              ('r1725', 0.0),
#              ('r1726', 0.0),
#              ('r1728', 0.0),
#              ('r1730', 0.0),
#              ('r1731', 0.0),
#              ('r1732', 0.0),
#              ('r1733', 0.0),
#              ('r1734', 0.0),
#              ('r1735', 0.0),
#              ('r1736', 0.0),
#              ('r1737', 0.0),
#              ('r1738', 0.0),
#              ('r1739', 0.0),
#              ('r1740', 0.0),
#              ('r1741', 0.0),
#              ('r1742', 0.0),
#              ('r1743', 0.0),
#              ('r1744', 0.0),
#              ('r1745', 0.0),
#              ('r1746', 0.0),
#              ('r1747', 0.0),
#              ('r1748', 0.0),
#              ('r1749', 0.0),
#              ('r1750', 0.00037644964834818905),
#              ('r1751', 0.0),
#              ('r1752', 0.0),
#              ('r1753', 0.0),
#              ('r1754', 0.0),
#              ('r1755', 0.0),
#              ('r1756', 0.0),
#              ('r1757', 0.0),
#              ('r1758', 0.0),
#              ('r1759', 0.0),
#              ('r1760', 0.0),
#              ('r1761', 0.0),
#              ('r1762', 0.0),
#              ('r1763', 0.0),
#              ('r1764', 0.0),
#              ('r1765', 0.0),
#              ('r1766', 0.0),
#              ('r1767', 0.0),
#              ('r1768', 0.0),
#              ('r1769', 0.0),
#              ('r1770', 0.0),
#              ('r1771', 0.0),
#              ('r1772', 0.0),
#              ('r1773', 0.0),
#              ('r1774', 0.0),
#              ('r1775', 0.0),
#              ('r1776', 0.0),
#              ('r1777', 0.0),
#              ('r1778', 0.0),
#              ('r1779', 0.0),
#              ('r1780', 0.004517367488456613),
#              ('r1781', 0.0),
#              ('r1782', 0.0),
#              ('r1783', 0.0),
#              ('r1784', 0.0),
#              ('r1785', 0.0),
#              ('r1786', 0.0),
#              ('r1787', 0.0),
#              ('r1788', 0.0),
#              ('r1789', 0.0),
#              ('r1790', 0.0),
#              ('r1791', 0.0),
#              ('r1792', 0.0),
#              ('r1796', 0.0),
#              ('r1797', 0.0),
#              ('r1798', 0.0),
#              ('r1799', 0.0),
#              ('r1800', 0.0),
#              ('r1801', 0.0),
#              ('r1803', 0.0),
#              ('r1805', 0.0),
#              ('r1806', 0.0),
#              ('r1807', 0.0),
#              ('r1808', 0.0),
#              ('r1809', 0.0),
#              ('r1810', 0.0),
#              ('r1811', 0.0),
#              ('r1812', 0.0),
#              ('r1813', 0.0),
#              ('r1814', 0.0),
#              ('r1815', 0.0),
#              ('r1816', 0.0),
#              ('r1817', 0.0),
#              ('r1818', 0.0),
#              ('r1819', 0.0),
#              ('r1820', 0.0),
#              ('r1821', 0.0),
#              ('r1822', 0.0),
#              ('r1823', 0.0),
#              ('r1824', 0.0),
#              ('r1825', 0.0),
#              ('r1826', 0.0),
#              ('r1827', 0.0),
#              ('r1828', 0.0),
#              ('r1829', 0.0),
#              ('r1830', 0.0),
#              ('r1831', 0.0),
#              ('r1832', 0.0),
#              ('r1833', 0.0),
#              ('r1834', 0.011318103853713854),
#              ('r1835', 0.0),
#              ('r1836', 0.0),
#              ('r1837', 0.0),
#              ('r1841', 0.0),
#              ('r1842', 0.0),
#              ('r1843', 0.0),
#              ('r1844', 0.0),
#              ('r1846', 0.0),
#              ('r1847', 0.0),
#              ('r1848', 0.0),
#              ('r1850', 0.0),
#              ('r1851', 0.0),
#              ('r1852', 0.0),
#              ('r1853', 0.0),
#              ('r1854', 0.0),
#              ('r1855', 0.0),
#              ('r1856', 0.0),
#              ('r1857', 0.0),
#              ('r1858', 0.0),
#              ('r1859', 0.0),
#              ('r1860', 0.0),
#              ('r1861', 0.0),
#              ('r1862', 0.0),
#              ('r1863', 0.0),
#              ('r1864', 0.0),
#              ('r1865', 0.0),
#              ('r1866', 0.0),
#              ('r1867', 0.0),
#              ('r1871', 0.0),
#              ('r1872', 0.0),
#              ('r1873', 0.0),
#              ('r1874', 0.0),
#              ('r1876', 0.0),
#              ('r1877', 0.0),
#              ('r1879', 0.0),
#              ('r1880', 0.0),
#              ('r1881', 0.0),
#              ('r1882', 0.0),
#              ('r1883', 0.0),
#              ('r1884', 0.0),
#              ('r1885', 0.0),
#              ('r1886', 0.0),
#              ('r1887', 0.0),
#              ('r1888', 0.0),
#              ('r1889', 0.0),
#              ('r1890', 0.0),
#              ('r1891', 0.0),
#              ('r1892', 0.0),
#              ('r1893', 0.0),
#              ('r1894', 0.0),
#              ('r1895', 0.0),
#              ('r1896', 0.0),
#              ('r1897', 0.0),
#              ('r1898', 0.0),
#              ('r1899', 0.0),
#              ('r1900', 0.00809363914776441),
#              ('r1901', 0.0),
#              ('r1902', 0.0),
#              ('r1903', 0.0),
#              ('r1904', 0.0),
#              ('r1905', 0.0),
#              ('r1906', 0.0),
#              ('r1907', 0.0),
#              ('r1908', 0.0),
#              ...])

# %% [markdown]
# Furthermore, is possible to reconstruct the model based on the integration results.

# %%
def sbml_model_reconstruction(model_template: cobra.Model, results):
    """
    This function is used to reconstruct the model based on the integration results.

    Parameters
    ----------
    model_template: cobra.Model
        The COBRA model template.
    sample: str
        The sample name.
    integration_result_dict: dict
        The integration results.
    """
    temp_model = deepcopy(model_template)

    temp_model.objective = 'biomass'  

    if isinstance(results, list):
        
        reactions_to_deactivate = [reaction for reaction in temp_model.reactions if reaction not in [temp_model.reactions[reaction_idx] for reaction_idx in results] if reaction.id != 'biomass']
        
        temp_model.remove_reactions(reactions_to_deactivate, remove_orphans=True)
        
    if isinstance(results, dict):
        
        reactions_to_deactivate = [reaction for reaction, value in results.items() if value is False if reaction != 'biomass']
                
        temp_model.remove_reactions(reactions_to_deactivate, remove_orphans=True)
        
    temp_model.id = 'Reconstructed Model'
    print('Model Objective:', temp_model.objective)
    print('Objective Production:', temp_model.optimize())
    print(f'Model reconstruction finished.')
    
    return temp_model

# %%
reconstructed_model = sbml_model_reconstruction(model, gimme_run)
reconstructed_model
# Out:
# C:\Users\biosy\anaconda3\envs\s2m2\lib\site-packages\cobra\core\group.py:147: UserWarning: need to pass in a list
#   warn("need to pass in a list")
# Model Objective: Maximize
# 1.0*biomass - 1.0*biomass_reverse_01e59
# Objective Production: <Solution 0.035 at 0x19235919a88>
# Model reconstruction finished.
# <Model Reconstructed Model at 0x19231336408>

# %% [markdown]
# Besides the Gimme class above demonstrated, Troppo allows a more direct approach to run the integration methods using `run_from_omics` method from the `ReconstructionWrapper` class.
# Below is an example on how to use the `run_from_omics` method for the GIMME algorithm.

# %%
parameters = {'threshold': threshold, 'reconstruction_wrapper': model_wrapper, 'algorithm': 'gimme'}

# %%
def reconstruction_function_gimme(omics_container, parameters: dict):

    def score_apply(reaction_map_scores):
        return {k:0  if v is None else v for k, v in reaction_map_scores.items()}
    
    threshold, rec_wrapper, method = [parameters[parameter] for parameter in
                                      ['threshold', 'reconstruction_wrapper', 'algorithm']]

    reac_ids = rec_wrapper.model_reader.r_ids
    metab_ids = rec_wrapper.model_reader.m_ids
    AND_OR_FUNCS = (min, sum)    

    if method == 'gimme':
            return rec_wrapper.run_from_omics(omics_data=omics_container, algorithm=method, and_or_funcs=AND_OR_FUNCS,
                                              integration_strategy=('continuous', score_apply), solver='GLPK', obj_frac=0.8,
                                              objectives=[{'biomass': 1}], preprocess=True, flux_threshold=0.8,
                                              reaction_ids=reac_ids, metabolite_ids=metab_ids)

# %%
reconstruction_function_gimme(single_sample, parameters)
# Out:
# Could not set parameters with this solver
# Could not set parameters with this solver
# Could not set parameters with this solver
# {'2AMACHYD': False,
#  '2AMADPTm': False,
#  '2DR1PP': False,
#  '2HCO3_NAt': True,
#  '2OXOADOXm': True,
#  '2OXOADPTm': False,
#  '34HPPOR': False,
#  '3AIBt': False,
#  '3AIBTm': True,
#  '3AIBtm': True,
#  '3HAO': False,
#  '3HBCOAHLm': False,
#  '3HKYNAKGAT': True,
#  '3MOBt2im': False,
#  '3MOPt2im': False,
#  '3SALAASPm': True,
#  '3SALATAi': True,
#  '3SALATAim': True,
#  '3SPYRSP': False,
#  '3SPYRSPm': False,
#  '4ABUTtm': False,
#  '4MOPt2im': True,
#  '5MTHFt': True,
#  '5MTHFt2': True,
#  'AACOAT': True,
#  'AACTOOR': False,
#  'AACTtm': False,
#  'AASAD3m': False,
#  'AATAi': True,
#  'ABTArm': True,
#  'ABUTD': True,
#  'ABUTt2r': True,
#  'ABUTt4_2_r': False,
#  'ACACT10m': True,
#  'ACACT1r': True,
#  'ACACt2': True,
#  'ACACt2m': True,
#  'ACETONEt2': True,
#  'ACETONEt2m': True,
#  'ACITL': True,
#  'ACOAD10m': True,
#  'ACOAD9m': True,
#  'ACOAHi': False,
#  'ACONT': True,
#  'ACONTm': True,
#  'ACS': True,
#  'ACSm': True,
#  'ACt2m': False,
#  'ACt2r': False,
#  'ACTLMO': False,
#  'ACTNMO': False,
#  'ACYP': True,
#  'ADCim': False,
#  'ADEt': True,
#  'ADK1': True,
#  'ADK1m': True,
#  'ADK3': False,
#  'ADK3m': True,
#  'ADMDC': True,
#  'ADNK1': True,
#  'ADPT': True,
#  'ADPtx': False,
#  'AGTim': False,
#  'AHC': True,
#  'AKGDm': True,
#  'AKGMALtm': True,
#  'AKGt4_3': True,
#  'ALAASNNaEx': True,
#  'ALACYSNaEx': True,
#  'ALAGLNexR': False,
#  'ALAGLNNaEx': True,
#  'ALAGLYexR': False,
#  'ALASERNaEx': True,
#  'ALAt2r': True,
#  'ALAt4': True,
#  'ALATA_L': True,
#  'ALATHRNaEx': True,
#  'ALAtN1': False,
#  'AMCOXO': False,
#  'AMETt2m': True,
#  'AMPtp': False,
#  'AOBUTDsm': False,
#  'APAT2rm': True,
#  'ARGLYSex': True,
#  'ARGN': True,
#  'ARGNm': True,
#  'ARGt4': False,
#  'ARGtiDF': True,
#  'ARGtm': True,
#  'ASNALANaEx': True,
#  'ASNCYSNaEx': True,
#  'ASNGLNNaEx': True,
#  'ASNS1': True,
#  'ASNSERNaEx': True,
#  'ASNt4': True,
#  'ASNTHRNaEx': True,
#  'ASNtN1': False,
#  'ASPGLUm': True,
#  'ASPTA': True,
#  'ASPTAm': True,
#  'ATP1ter': False,
#  'ATPS4m': True,
#  'ATPtm': True,
#  'ATPtx': False,
#  'BALAtmr': False,
#  'BALAVECSEC': False,
#  'BETALDHxm': False,
#  'BHMT': False,
#  'CATm': True,
#  'CATp': True,
#  'CBPS': True,
#  'CBPSam': True,
#  'CHLtm': False,
#  'CHOLD2m': False,
#  'CHOLt4': False,
#  'CHOLtu': True,
#  'CHSTEROLt': False,
#  'CHSTEROLt1': True,
#  'CHSTEROLt2': False,
#  'CHSTEROLt3': True,
#  'CITL': True,
#  'CITRtm': True,
#  'CITt4_2': False,
#  'CITtam': True,
#  'CITtbm': True,
#  'CK': True,
#  'CKc': True,
#  'CLFORtex': False,
#  'CLHCO3tex2': True,
#  'CLOHtex2': True,
#  'CLOXAtex2': True,
#  'CO2t': False,
#  'CO2ter': True,
#  'CO2tm': True,
#  'COAtm': True,
#  'CREATt4_2_r': True,
#  'CREATtmdiffir': False,
#  'CSm': True,
#  'CTPS1': True,
#  'CTPS2': True,
#  'CYOR_u10m': True,
#  'CYSALANaEx': True,
#  'CYSASNNaEx': True,
#  'CYSGLNNaEx': True,
#  'CYSGLUexR': True,
#  'CYSGLYexR': True,
#  'CYSO': False,
#  'CYSSERNaEx': True,
#  'CYSt4': True,
#  'CYStec': True,
#  'CYSTGL': True,
#  'CYSTHRNaEx': True,
#  'CYSTS': True,
#  'D_3AIBt': False,
#  'D3AIBTm': False,
#  'DATPtn': True,
#  'DCTPtn': True,
#  'DGTPtn': True,
#  'DHPR': True,
#  'ATPM': False,
#  'DMGDHm': False,
#  'DMGtm': False,
#  'DNDPt11m': True,
#  'DNDPt23m': True,
#  'DNDPt24m': True,
#  'DNDPt34m': True,
#  'DNDPt35m': True,
#  'DNDPt9m': True,
#  'DPGase': True,
#  'DPGM': True,
#  'DRBK': True,
#  'DTTPtn': True,
#  'ECOAH12m': True,
#  'ECOAH1m': True,
#  'ECOAH9m': True,
#  'ENO': True,
#  'EX_3aib_e': False,
#  'EX_3aib_D_e': False,
#  'EX_4abut_e': False,
#  'EX_ac_e': False,
#  'EX_acac_e': False,
#  'EX_acetone_e': False,
#  'EX_ade_e': False,
#  'EX_akg_e': False,
#  'EX_ala_B_e': False,
#  'EX_ala_L_e': False,
#  'EX_arg_L_e': True,
#  'EX_asn_L_e': True,
#  'EX_asp_L_e': True,
#  'EX_chol_e': True,
#  'EX_chsterol_e': False,
#  'EX_cit_e': False,
#  'EX_co2_e': False,
#  'EX_creat_e': False,
#  'EX_for_e': False,
#  'EX_glc_e': True,
#  'EX_gln_L_e': True,
#  'EX_glu_L_e': False,
#  'EX_gly_e': True,
#  'EX_glyb_e': False,
#  'EX_gthrd_e': False,
#  'EX_h_e': False,
#  'EX_h2o_e': True,
#  'EX_h2o2_e': False,
#  'EX_hco3_e': False,
#  'EX_his_L_e': True,
#  'EX_hista_e': False,
#  'EX_ile_L_e': True,
#  'EX_lac_L_e': False,
#  'EX_leu_L_e': True,
#  'EX_lys_L_e': True,
#  'EX_met_L_e': True,
#  'EX_mthgxl_e': False,
#  'EX_nh4_e': False,
#  'EX_o2_e': True,
#  'EX_o2s_e': False,
#  'EX_orn_e': False,
#  'EX_phe_L_e': True,
#  'EX_pi_e': True,
#  'EX_pro_L_e': True,
#  'EX_pyr_e': False,
#  'EX_ser_L_e': True,
#  'EX_so4_e': False,
#  'EX_succ_e': True,
#  'EX_thr_L_e': True,
#  'EX_trp_L_e': True,
#  'EX_tyr_L_e': True,
#  'EX_urea_e': True,
#  'EX_val_L_e': True,
#  'FALDtm': False,
#  'FBA': True,
#  'FBP': True,
#  'FDH': True,
#  'FKYNH': True,
#  'FORtr': True,
#  'FTCD': False,
#  'FTHFDH': True,
#  'FUM': True,
#  'FUMAC': True,
#  'FUMm': True,
#  'FUMSO3tm': True,
#  'FUMSO4tm': True,
#  'FUMtm': True,
#  'FUMTSULtm': True,
#  'G3PD1': True,
#  'G3PD2m': True,
#  'G5SADrm': True,
#  'G5SADs': False,
#  'G5SDym': True,
#  'G6PDA': True,
#  'G6PDH1rer': True,
#  'G6PDH2r': True,
#  'G6PDH2rer': True,
#  'G6PPer': True,
#  'G6Pter': True,
#  'GABAVESSEC': False,
#  'GACMTRc': True,
#  'GAPD': True,
#  'GCC2am': False,
#  'GCC2bim': False,
#  'GCC2cm': False,
#  'GCCam': False,
#  'GCCbim': False,
#  'GCCcm': False,
#  'GF6PTA': True,
#  'GHMT2r': True,
#  'GHMT2rm': True,
#  'GK1': True,
#  'GLCMter': False,
#  'GLCt1r': True,
#  'GLCt2_2': True,
#  'GLCt4': True,
#  'GLCter': False,
#  'GLCURter': False,
#  'GLNALANaEx': True,
#  'GLNASNNaEx': True,
#  'GLNCYSNaEx': True,
#  'GLNS': True,
#  'GLNSERNaEx': True,
#  'GLNt4': True,
#  'GLNTHRNaEx': True,
#  'GLNtm': False,
#  'GLNtN1': False,
#  'GLU5Km': True,
#  'GLUCYS': True,
#  'GLUDC': False,
#  'GLUDxm': True,
#  'GLUDym': True,
#  'GluForTx': False,
#  'GLUNm': True,
#  'GLUPRT': True,
#  'GLUt2m': True,
#  'GLUTCOADHm': True,
#  'GLUVESSEC': False,
#  'GLXtm': False,
#  'GLXtp': False,
#  'GLYAMDTRc': False,
#  'GLYATm': True,
#  'GLYBt4_2_r': False,
#  'GLYBtm': False,
#  'GLYC3Ptm': False,
#  'GLYOp': False,
#  'GLYt2r': True,
#  'GLYt4': True,
#  'GLYt7_211_r': True,
#  'GLYtm': True,
#  'GLYtp': False,
#  'GLYVESSEC': False,
#  'GMPS2': True,
#  'GND': True,
#  'GNDer': True,
#  'GNMT': True,
#  'GTHO': True,
#  'GTHOm': True,
#  'GTHP': True,
#  'GTHPm': True,
#  'GTHRDt': True,
#  'GTHS': True,
#  'GULNDer': False,
#  'GULNter': False,
#  'H2CO3D': True,
#  'H2O2syn': False,
#  'H2O2t': False,
#  'H2O2tm': False,
#  'H2O2tp': False,
#  'H2Ot': True,
#  'H2Oter': True,
#  'H2Otm': False,
#  'H2Otp': False,
#  'HACD1m': True,
#  'HACD9m': True,
#  'HCO3_CLt': True,
#  'HEX1': True,
#  'HGNTOR': False,
#  'HIBDm': True,
#  'HISD': False,
#  'HISDC': True,
#  'HISt4': True,
#  'HISTAtu': True,
#  'HISTAVESSEC': False,
#  'HIStiDF': False,
#  'HIStN1': False,
#  'HKYNH': True,
#  'HMGCOASim': False,
#  'HMGCOAtm': True,
#  'HMGLm': True,
#  'HOMt4': True,
#  'Htm': True,
#  'Htr': True,
#  'Htx': False,
#  'ICDHxm': True,
#  'ICDHy': True,
#  'ICDHyrm': True,
#  'ILEt4': False,
#  'ILEt5m': False,
#  'ILETA': False,
#  'ILETAm': True,
#  'ILEtec': True,
#  'IZPN': False,
#  'KCC2t': True,
#  'KYN3OX': True,
#  'KYNAKGAT': True,
#  'KYNATESYN': False,
#  'LDH_L': True,
#  'LEUt4': True,
#  'LEUt5m': False,
#  'LEUTA': True,
#  'LEUTAm': True,
#  'LEUtec': True,
#  'L_LACDcm': True,
#  'L_LACt2r': True,
#  'L_LACt4r': True,
#  'LYSt4': True,
#  'LYStiDF': True,
#  'LYStm': True,
#  'MACACI': True,
#  'MALSO3tm': True,
#  'MALSO4tm': True,
#  'MALtm': True,
#  'MALTSULtm': True,
#  'MCCCrm': True,
#  'MDH': True,
#  'MDHm': True,
#  'ME1m': True,
#  'ME2': True,
#  'ME2m': True,
#  'METAT': True,
#  'METLEUex': True,
#  'METS': True,
#  'METt4': True,
#  'METtec': True,
#  'MGCHrm': True,
#  'MGSA': False,
#  'MGSA2': False,
#  'MMEm': True,
#  'MMMm': True,
#  'MMSAD3m': True,
#  'MMTSADm': False,
#  'MTHFC': True,
#  'MTHFD': True,
#  'MTHGXLt': False,
#  'NADH2_u10m': True,
#  'NADHtpu': False,
#  'NADHtru': False,
#  'NADPHtru': False,
#  'NADPtru': False,
#  'NADtpu': False,
#  'NADtru': False,
#  'NAHCO3_HCLt': True,
#  'NAt': True,
#  'NAt3_1': True,
#  'NAt5': True,
#  'NCCt': False,
#  'NDPK1': True,
#  'NDPK1m': True,
#  'NDPK2': True,
#  'NDPK3': True,
#  'NDPK4': True,
#  'NDPK5': True,
#  'NDPK8': True,
#  'NDPK9': True,
#  'NH4t3r': False,
#  'NH4tp': False,
#  'NKCC2t': True,
#  'NRPPHRt4_2_r': False,
#  'NRPPHRtu': False,
#  'NRPPHRVESSEC': False,
#  'NTD7': True,
#  'O2St': False,
#  'O2Stm': False,
#  'O2Stx': False,
#  'O2t': True,
#  'O2ter': True,
#  'O2tm': True,
#  'O2tp': False,
#  'OBDHc': False,
#  'OCBTm': False,
#  'OIVD1m': True,
#  'OIVD2m': True,
#  'OIVD3m': True,
#  'ORNDC': True,
#  'ORNt3m': True,
#  'ORNt4m': True,
#  'ORNTArm': True,
#  'ORNtiDF': True,
#  'OXAHCOtex': True,
#  'P5CDm': True,
#  'P5CRm': True,
#  'P5CRxm': True,
#  'PCLAD': False,
#  'PCm': True,
#  'PCREATtmdiffir': False,
#  'PDHm': True,
#  'PE_HStm': True,
#  'PEPCK': False,
#  'PEPCKm': True,
#  'PFK': True,
#  'PGCD': True,
#  'PGI': True,
#  'PGK': True,
#  'PGL': True,
#  'PGLer': True,
#  'PGM': True,
#  'PHEt4': True,
#  'PHEtec': True,
#  'PIt7': False,
#  'PIter': True,
#  'PPA': True,
#  'PPAm': True,
#  'PPCOACm': True,
#  'PPCOAOm': True,
#  'PPItr': True,
#  'PPM': True,
#  'PRFGS': True,
#  'PRO1xm': True,
#  'PROD2m': True,
#  'PROt2r': True,
#  'PROt4': True,
#  'PRPNCOAHYDm': True,
#  'PRPPS': True,
#  'PSERT': True,
#  'PSFLIPm': True,
#  'PSP_L': True,
#  'PTRCOX1': True,
#  'PUNP1': True,
#  'PYK': True,
#  'PYRt2m': True,
#  'PYRt2p': True,
#  'PYRt2r': True,
#  'RETNt': False,
#  'RPE': True,
#  'RPI': True,
#  'SACCD3m': False,
#  'SACCD4m': False,
#  'SARCStm': True,
#  'SARDHm': True,
#  'SERALANaEx': True,
#  'SERASNNaEx': True,
#  'SERCYSNaEx': True,
#  'SERGLNexR': False,
#  'SERGLNNaEx': True,
#  'SERGLYexR': False,
#  'SERHL': False,
#  'SERLYSNaex': False,
#  'SERt4': True,
#  'SERTHRNaEx': True,
#  'SERtN1': False,
#  'SO4CLtex2': True,
#  'SO4HCOtex': True,
#  'SO4OXAtex2': True,
#  'SO4t4_2': False,
#  'SPMDOX': False,
#  'SPMS': True,
#  'SPODM': True,
#  'SPODMe': True,
#  'SPODMm': True,
#  'SPODMx': True,
#  'SPRMS': True,
#  'SUCCt2m': True,
#  'SUCCt4_2': True,
#  'SUCD1m': True,
#  'SUCOAS1m': True,
#  'SUCOASm': True,
#  'SULFOX': True,
#  'TALA': True,
#  'THD1m': True,
#  'THRALANaEx': True,
#  'THRASNNaEx': True,
#  'THRCYSNaEx': True,
#  'THRD_L': True,
#  'THRGLNexR': False,
#  'THRGLNNaEx': True,
#  'THRGLYexR': False,
#  'THRSERNaEx': True,
#  'THRt4': True,
#  'TKT1': True,
#  'TKT2': True,
#  'TPI': True,
#  'TRPO2': True,
#  'TRPt': True,
#  'TRPt4': False,
#  'TYRt': False,
#  'TYRt4': False,
#  'TYRTA': True,
#  'UDPGLCAter': True,
#  'UMPK': True,
#  'UMPK2': True,
#  'UMPK3': True,
#  'UMPK4': True,
#  'UMPK5': True,
#  'UMPK7': True,
#  'UMPtr': False,
#  'URCN': False,
#  'UREAt': True,
#  'UREAt5': False,
#  'UREAtm': False,
#  'VALt4': False,
#  'VALt5m': False,
#  'VALTA': False,
#  'VALTAm': True,
#  'VALtec': True,
#  'XYLUR': True,
#  'EX_fald_e': False,
#  'EX_ptrc_e': False,
#  'EX_spmd_e': False,
#  'r0010': True,
#  'r0021': True,
#  'r0022': True,
#  'r0028': True,
#  'r0034': True,
#  'r0055': False,
#  'r0060': False,
#  'r0062': False,
#  'r0074': True,
#  'r0081': True,
#  'r0085': True,
#  'r0086': True,
#  'r0119': True,
#  'r0122': False,
#  'r0127': False,
#  'r0142': True,
#  'r0153': False,
#  'r0156': False,
#  'r0157': False,
#  'r0165': False,
#  'r0173': True,
#  'r0178': False,
#  'r0179': False,
#  'r0191': True,
#  'r0202': True,
#  'r0249': True,
#  'r0280': False,
#  'r0295': True,
#  'r0301': True,
#  'r0317': True,
#  'r0354': True,
#  'r0355': True,
#  'r0365': False,
#  'r0398': True,
#  'r0399': False,
#  'r0413': False,
#  'r0426': True,
#  'r0450': False,
#  'r0464': True,
#  'r0483': True,
#  'r0509': True,
#  'r0525': False,
#  'r0541': True,
#  'r0549': True,
#  'r0552': True,
#  'r0553': True,
#  'r0560': False,
#  'r0570': True,
#  'r0596': True,
#  'r0645': False,
#  'r0647': False,
#  'r0655': True,
#  'r0669': True,
#  'r0683': True,
#  'r0779': True,
#  'r0784': False,
#  'r0792': True,
#  'r0801': True,
#  'r0812': True,
#  'r0817': False,
#  'r0819': True,
#  'r0821': True,
#  'r0822': True,
#  'r0829': True,
#  'r0830': True,
#  'r0838': False,
#  'r0839': False,
#  'r0840': False,
#  'r0841': True,
#  'r0860': False,
#  'r0879': True,
#  'r0881': False,
#  'r0885': True,
#  'r0899': False,
#  'r0911': True,
#  'r0913': True,
#  'r0915': True,
#  'r0917': True,
#  'r0924': False,
#  'r0941': True,
#  'r0942': True,
#  'r0944': False,
#  'r0946': False,
#  'r1030': False,
#  'r1050': False,
#  'r1051': True,
#  'r1052': False,
#  'r1088': False,
#  'r1090': True,
#  'r1109': False,
#  'r1143': False,
#  'r1144': False,
#  'r1147': True,
#  'r1154': True,
#  'r1155': True,
#  'r1162': False,
#  'r1291': False,
#  'r1421': False,
#  'r1427': False,
#  'r1428': False,
#  'r1429': False,
#  'r1434': False,
#  'r1435': False,
#  'r1453': True,
#  'r1454': True,
#  'r1464': False,
#  'r1493': False,
#  'r1530': True,
#  'r1538': False,
#  'r1544': True,
#  'r1546': True,
#  'r1547': True,
#  'r1548': True,
#  'r1549': True,
#  'r1551': True,
#  'r1552': True,
#  'r1553': True,
#  'r1554': True,
#  'r1556': True,
#  'r1557': True,
#  'r1559': True,
#  'r1560': True,
#  'r1561': True,
#  'r1562': True,
#  'r1563': True,
#  'r1564': True,
#  'r1565': True,
#  'r1566': True,
#  'r1567': True,
#  'r1568': True,
#  'r1569': True,
#  'r1570': True,
#  'r1571': True,
#  'r1573': True,
#  'r1574': True,
#  'r1575': True,
#  'r1576': True,
#  'r1578': True,
#  'r1579': True,
#  'r1580': True,
#  'r1581': True,
#  'r1583': True,
#  'r1584': True,
#  'r1585': True,
#  'r1586': True,
#  'r1587': True,
#  'r1588': True,
#  'r1589': True,
#  'r1590': True,
#  'r1591': True,
#  'r1592': True,
#  'r1593': True,
#  'r1594': True,
#  'r1595': True,
#  'r1596': True,
#  'r1597': True,
#  'r1598': True,
#  'r1599': True,
#  'r1600': True,
#  'r1602': True,
#  'r1603': True,
#  'r1604': True,
#  'r1605': True,
#  'r1606': True,
#  'r1607': True,
#  'r1608': True,
#  'r1609': True,
#  'r1610': True,
#  'r1611': True,
#  'r1612': True,
#  'r1613': True,
#  'r1614': True,
#  'r1615': True,
#  'r1616': True,
#  'r1617': True,
#  'r1618': True,
#  'r1619': True,
#  'r1620': True,
#  'r1621': True,
#  'r1622': True,
#  'r1623': True,
#  'r1624': True,
#  'r1625': True,
#  'r1626': True,
#  'r1627': True,
#  'r1628': True,
#  'r1629': True,
#  'r1630': True,
#  'r1631': True,
#  'r1632': True,
#  'r1633': True,
#  'r1634': True,
#  'r1635': True,
#  'r1636': True,
#  'r1637': True,
#  'r1638': True,
#  'r1639': True,
#  'r1640': True,
#  'r1641': True,
#  'r1642': True,
#  'r1643': True,
#  'r1644': True,
#  'r1645': True,
#  'r1646': True,
#  'r1647': True,
#  'r1648': True,
#  'r1649': True,
#  'r1650': True,
#  'r1651': True,
#  'r1652': True,
#  'r1653': True,
#  'r1654': True,
#  'r1655': True,
#  'r1656': True,
#  'r1657': True,
#  'r1658': True,
#  'r1659': True,
#  'r1660': True,
#  'r1661': True,
#  'r1662': True,
#  'r1664': True,
#  'r1665': True,
#  'r1666': True,
#  'r1667': True,
#  'r1668': True,
#  'r1669': True,
#  'r1670': True,
#  'r1671': True,
#  'r1672': True,
#  'r1673': True,
#  'r1674': True,
#  'r1675': True,
#  'r1676': True,
#  'r1677': True,
#  'r1678': True,
#  'r1679': True,
#  'r1680': True,
#  'r1681': True,
#  'r1682': True,
#  'r1683': True,
#  'r1684': True,
#  'r1685': True,
#  'r1686': True,
#  'r1687': True,
#  'r1690': True,
#  'r1691': True,
#  'r1692': True,
#  'r1693': True,
#  'r1695': True,
#  'r1696': True,
#  'r1698': True,
#  'r1700': True,
#  'r1701': True,
#  'r1702': True,
#  'r1705': True,
#  'r1706': True,
#  'r1707': True,
#  'r1708': True,
#  'r1710': True,
#  'r1711': True,
#  'r1713': True,
#  'r1715': True,
#  'r1716': True,
#  'r1717': True,
#  'r1720': True,
#  'r1721': True,
#  'r1722': True,
#  'r1723': True,
#  'r1725': True,
#  'r1726': True,
#  'r1728': True,
#  'r1730': True,
#  'r1731': True,
#  'r1732': True,
#  'r1733': True,
#  'r1734': True,
#  'r1735': True,
#  'r1736': True,
#  'r1737': True,
#  'r1738': True,
#  'r1739': True,
#  'r1740': True,
#  'r1741': True,
#  'r1742': True,
#  'r1743': True,
#  'r1744': True,
#  'r1745': True,
#  'r1746': True,
#  'r1747': True,
#  'r1748': True,
#  'r1749': True,
#  'r1750': True,
#  'r1751': True,
#  'r1752': True,
#  'r1753': True,
#  'r1754': True,
#  'r1755': True,
#  'r1756': True,
#  'r1757': True,
#  'r1758': True,
#  'r1759': True,
#  'r1760': True,
#  'r1761': True,
#  'r1762': True,
#  'r1763': True,
#  'r1764': True,
#  'r1765': True,
#  'r1766': True,
#  'r1767': True,
#  'r1768': True,
#  'r1769': True,
#  'r1770': True,
#  'r1771': True,
#  'r1772': True,
#  'r1773': True,
#  'r1774': True,
#  'r1775': True,
#  'r1776': True,
#  'r1777': True,
#  'r1778': True,
#  'r1779': True,
#  'r1780': True,
#  'r1781': True,
#  'r1782': True,
#  'r1783': True,
#  'r1784': True,
#  'r1785': True,
#  'r1786': True,
#  'r1787': True,
#  'r1788': True,
#  'r1789': True,
#  'r1790': True,
#  'r1791': True,
#  'r1792': True,
#  'r1796': True,
#  'r1797': True,
#  'r1798': True,
#  'r1799': True,
#  'r1800': True,
#  'r1801': True,
#  'r1803': True,
#  'r1805': True,
#  'r1806': True,
#  'r1807': True,
#  'r1808': True,
#  'r1809': True,
#  'r1810': True,
#  'r1811': True,
#  'r1812': True,
#  'r1813': True,
#  'r1814': True,
#  'r1815': True,
#  'r1816': True,
#  'r1817': True,
#  'r1818': True,
#  'r1819': True,
#  'r1820': True,
#  'r1821': True,
#  'r1822': True,
#  'r1823': True,
#  'r1824': True,
#  'r1825': True,
#  'r1826': True,
#  'r1827': True,
#  'r1828': True,
#  'r1829': True,
#  'r1830': True,
#  'r1831': True,
#  'r1832': True,
#  'r1833': True,
#  'r1834': True,
#  'r1835': True,
#  'r1836': True,
#  'r1837': True,
#  'r1841': True,
#  'r1842': True,
#  'r1843': True,
#  'r1844': True,
#  'r1846': True,
#  'r1847': True,
#  'r1848': True,
#  'r1850': True,
#  'r1851': True,
#  'r1852': True,
#  'r1853': True,
#  'r1854': True,
#  'r1855': True,
#  'r1856': True,
#  'r1857': True,
#  'r1858': True,
#  'r1859': True,
#  'r1860': True,
#  'r1861': True,
#  'r1862': True,
#  'r1863': True,
#  'r1864': True,
#  'r1865': True,
#  'r1866': True,
#  'r1867': True,
#  'r1871': True,
#  'r1872': True,
#  'r1873': True,
#  'r1874': True,
#  'r1876': True,
#  'r1877': True,
#  'r1879': True,
#  'r1880': True,
#  'r1881': True,
#  'r1882': True,
#  'r1883': True,
#  'r1884': True,
#  'r1885': True,
#  'r1886': True,
#  'r1887': True,
#  'r1888': True,
#  'r1889': True,
#  'r1890': True,
#  'r1891': True,
#  'r1892': True,
#  'r1893': True,
#  'r1894': True,
#  'r1895': True,
#  'r1896': True,
#  'r1897': True,
#  'r1898': True,
#  'r1899': True,
#  'r1900': True,
#  'r1901': True,
#  'r1902': True,
#  'r1903': True,
#  'r1904': True,
#  'r1905': True,
#  'r1906': True,
#  'r1907': True,
#  'r1908': True,
#  ...}

# %% [markdown]
# # Run in Batch
#
# Using the reconstruction_function_gimme defined above, we can run the GIMME algorithm in batch for multiple samples. Below is and example on how to use the batch_run function for parallel reconstruction of the models.
# In this case we will use some samples from omics_container created previously.

# %%
batch_container = omics_container[0:3]
batch_container
# Out:
# [<troppo.omics.core.OmicsContainer at 0x19230715488>,
#  <troppo.omics.core.OmicsContainer at 0x1924086f6c8>,
#  <troppo.omics.core.OmicsContainer at 0x1923ff296c8>]

# %%
[c.condition for c in batch_container]
# Out:
# ['ACH-000017', 'ACH-000019', 'ACH-000028']

# %%
batch_gimme_res = batch_run(reconstruction_function_gimme, batch_container, parameters, threads=10)

# %%
results = {c.condition: res for c, res in zip(batch_container, batch_gimme_res)}
results
# Out:
# {'ACH-000017': {'2AMACHYD': False,
#   '2AMADPTm': False,
#   '2DR1PP': False,
#   '2HCO3_NAt': True,
#   '2OXOADOXm': True,
#   '2OXOADPTm': False,
#   '34HPPOR': False,
#   '3AIBt': False,
#   '3AIBTm': True,
#   '3AIBtm': True,
#   '3HAO': False,
#   '3HBCOAHLm': False,
#   '3HKYNAKGAT': True,
#   '3MOBt2im': False,
#   '3MOPt2im': False,
#   '3SALAASPm': True,
#   '3SALATAi': True,
#   '3SALATAim': True,
#   '3SPYRSP': False,
#   '3SPYRSPm': False,
#   '4ABUTtm': False,
#   '4MOPt2im': True,
#   '5MTHFt': True,
#   '5MTHFt2': True,
#   'AACOAT': True,
#   'AACTOOR': False,
#   'AACTtm': False,
#   'AASAD3m': False,
#   'AATAi': True,
#   'ABTArm': True,
#   'ABUTD': True,
#   'ABUTt2r': True,
#   'ABUTt4_2_r': False,
#   'ACACT10m': True,
#   'ACACT1r': True,
#   'ACACt2': True,
#   'ACACt2m': True,
#   'ACETONEt2': True,
#   'ACETONEt2m': True,
#   'ACITL': True,
#   'ACOAD10m': True,
#   'ACOAD9m': True,
#   'ACOAHi': False,
#   'ACONT': True,
#   'ACONTm': True,
#   'ACS': True,
#   'ACSm': True,
#   'ACt2m': False,
#   'ACt2r': False,
#   'ACTLMO': False,
#   'ACTNMO': False,
#   'ACYP': True,
#   'ADCim': False,
#   'ADEt': True,
#   'ADK1': True,
#   'ADK1m': True,
#   'ADK3': False,
#   'ADK3m': True,
#   'ADMDC': True,
#   'ADNK1': True,
#   'ADPT': True,
#   'ADPtx': False,
#   'AGTim': False,
#   'AHC': True,
#   'AKGDm': True,
#   'AKGMALtm': True,
#   'AKGt4_3': True,
#   'ALAASNNaEx': True,
#   'ALACYSNaEx': True,
#   'ALAGLNexR': False,
#   'ALAGLNNaEx': True,
#   'ALAGLYexR': False,
#   'ALASERNaEx': True,
#   'ALAt2r': True,
#   'ALAt4': True,
#   'ALATA_L': True,
#   'ALATHRNaEx': True,
#   'ALAtN1': False,
#   'AMCOXO': False,
#   'AMETt2m': True,
#   'AMPtp': False,
#   'AOBUTDsm': False,
#   'APAT2rm': True,
#   'ARGLYSex': True,
#   'ARGN': True,
#   'ARGNm': True,
#   'ARGt4': False,
#   'ARGtiDF': True,
#   'ARGtm': True,
#   'ASNALANaEx': True,
#   'ASNCYSNaEx': True,
#   'ASNGLNNaEx': True,
#   'ASNS1': True,
#   'ASNSERNaEx': True,
#   'ASNt4': True,
#   'ASNTHRNaEx': True,
#   'ASNtN1': False,
#   'ASPGLUm': True,
#   'ASPTA': True,
#   'ASPTAm': True,
#   'ATP1ter': False,
#   'ATPS4m': True,
#   'ATPtm': True,
#   'ATPtx': False,
#   'BALAtmr': False,
#   'BALAVECSEC': False,
#   'BETALDHxm': False,
#   'BHMT': False,
#   'CATm': True,
#   'CATp': True,
#   'CBPS': True,
#   'CBPSam': True,
#   'CHLtm': False,
#   'CHOLD2m': False,
#   'CHOLt4': False,
#   'CHOLtu': True,
#   'CHSTEROLt': False,
#   'CHSTEROLt1': True,
#   'CHSTEROLt2': False,
#   'CHSTEROLt3': True,
#   'CITL': True,
#   'CITRtm': True,
#   'CITt4_2': False,
#   'CITtam': True,
#   'CITtbm': True,
#   'CK': True,
#   'CKc': True,
#   'CLFORtex': False,
#   'CLHCO3tex2': True,
#   'CLOHtex2': True,
#   'CLOXAtex2': True,
#   'CO2t': False,
#   'CO2ter': True,
#   'CO2tm': True,
#   'COAtm': True,
#   'CREATt4_2_r': True,
#   'CREATtmdiffir': False,
#   'CSm': True,
#   'CTPS1': True,
#   'CTPS2': True,
#   'CYOR_u10m': True,
#   'CYSALANaEx': True,
#   'CYSASNNaEx': True,
#   'CYSGLNNaEx': True,
#   'CYSGLUexR': True,
#   'CYSGLYexR': True,
#   'CYSO': False,
#   'CYSSERNaEx': True,
#   'CYSt4': True,
#   'CYStec': True,
#   'CYSTGL': True,
#   'CYSTHRNaEx': True,
#   'CYSTS': True,
#   'D_3AIBt': False,
#   'D3AIBTm': False,
#   'DATPtn': True,
#   'DCTPtn': True,
#   'DGTPtn': True,
#   'DHPR': True,
#   'ATPM': False,
#   'DMGDHm': False,
#   'DMGtm': False,
#   'DNDPt11m': True,
#   'DNDPt23m': True,
#   'DNDPt24m': True,
#   'DNDPt34m': True,
#   'DNDPt35m': True,
#   'DNDPt9m': True,
#   'DPGase': True,
#   'DPGM': True,
#   'DRBK': True,
#   'DTTPtn': True,
#   'ECOAH12m': True,
#   'ECOAH1m': True,
#   'ECOAH9m': True,
#   'ENO': True,
#   'EX_3aib_e': False,
#   'EX_3aib_D_e': False,
#   'EX_4abut_e': False,
#   'EX_ac_e': False,
#   'EX_acac_e': False,
#   'EX_acetone_e': False,
#   'EX_ade_e': False,
#   'EX_akg_e': False,
#   'EX_ala_B_e': False,
#   'EX_ala_L_e': False,
#   'EX_arg_L_e': True,
#   'EX_asn_L_e': True,
#   'EX_asp_L_e': True,
#   'EX_chol_e': True,
#   'EX_chsterol_e': False,
#   'EX_cit_e': False,
#   'EX_co2_e': False,
#   'EX_creat_e': False,
#   'EX_for_e': False,
#   'EX_glc_e': True,
#   'EX_gln_L_e': True,
#   'EX_glu_L_e': False,
#   'EX_gly_e': True,
#   'EX_glyb_e': False,
#   'EX_gthrd_e': False,
#   'EX_h_e': False,
#   'EX_h2o_e': True,
#   'EX_h2o2_e': False,
#   'EX_hco3_e': False,
#   'EX_his_L_e': True,
#   'EX_hista_e': False,
#   'EX_ile_L_e': True,
#   'EX_lac_L_e': False,
#   'EX_leu_L_e': True,
#   'EX_lys_L_e': True,
#   'EX_met_L_e': True,
#   'EX_mthgxl_e': False,
#   'EX_nh4_e': False,
#   'EX_o2_e': True,
#   'EX_o2s_e': False,
#   'EX_orn_e': False,
#   'EX_phe_L_e': True,
#   'EX_pi_e': True,
#   'EX_pro_L_e': True,
#   'EX_pyr_e': False,
#   'EX_ser_L_e': True,
#   'EX_so4_e': False,
#   'EX_succ_e': True,
#   'EX_thr_L_e': True,
#   'EX_trp_L_e': True,
#   'EX_tyr_L_e': True,
#   'EX_urea_e': True,
#   'EX_val_L_e': True,
#   'FALDtm': False,
#   'FBA': True,
#   'FBP': True,
#   'FDH': True,
#   'FKYNH': True,
#   'FORtr': True,
#   'FTCD': False,
#   'FTHFDH': True,
#   'FUM': True,
#   'FUMAC': True,
#   'FUMm': True,
#   'FUMSO3tm': True,
#   'FUMSO4tm': True,
#   'FUMtm': True,
#   'FUMTSULtm': True,
#   'G3PD1': True,
#   'G3PD2m': True,
#   'G5SADrm': True,
#   'G5SADs': False,
#   'G5SDym': True,
#   'G6PDA': True,
#   'G6PDH1rer': True,
#   'G6PDH2r': True,
#   'G6PDH2rer': True,
#   'G6PPer': True,
#   'G6Pter': True,
#   'GABAVESSEC': False,
#   'GACMTRc': True,
#   'GAPD': True,
#   'GCC2am': False,
#   'GCC2bim': False,
#   'GCC2cm': False,
#   'GCCam': False,
#   'GCCbim': False,
#   'GCCcm': False,
#   'GF6PTA': True,
#   'GHMT2r': True,
#   'GHMT2rm': True,
#   'GK1': True,
#   'GLCMter': False,
#   'GLCt1r': True,
#   'GLCt2_2': True,
#   'GLCt4': True,
#   'GLCter': False,
#   'GLCURter': False,
#   'GLNALANaEx': True,
#   'GLNASNNaEx': True,
#   'GLNCYSNaEx': True,
#   'GLNS': True,
#   'GLNSERNaEx': True,
#   'GLNt4': True,
#   'GLNTHRNaEx': True,
#   'GLNtm': False,
#   'GLNtN1': False,
#   'GLU5Km': True,
#   'GLUCYS': True,
#   'GLUDC': False,
#   'GLUDxm': True,
#   'GLUDym': True,
#   'GluForTx': False,
#   'GLUNm': True,
#   'GLUPRT': True,
#   'GLUt2m': True,
#   'GLUTCOADHm': True,
#   'GLUVESSEC': False,
#   'GLXtm': False,
#   'GLXtp': False,
#   'GLYAMDTRc': False,
#   'GLYATm': True,
#   'GLYBt4_2_r': False,
#   'GLYBtm': False,
#   'GLYC3Ptm': False,
#   'GLYOp': False,
#   'GLYt2r': True,
#   'GLYt4': True,
#   'GLYt7_211_r': True,
#   'GLYtm': True,
#   'GLYtp': False,
#   'GLYVESSEC': False,
#   'GMPS2': True,
#   'GND': True,
#   'GNDer': True,
#   'GNMT': True,
#   'GTHO': True,
#   'GTHOm': True,
#   'GTHP': True,
#   'GTHPm': True,
#   'GTHRDt': True,
#   'GTHS': True,
#   'GULNDer': False,
#   'GULNter': False,
#   'H2CO3D': True,
#   'H2O2syn': False,
#   'H2O2t': False,
#   'H2O2tm': False,
#   'H2O2tp': False,
#   'H2Ot': True,
#   'H2Oter': True,
#   'H2Otm': False,
#   'H2Otp': False,
#   'HACD1m': True,
#   'HACD9m': True,
#   'HCO3_CLt': True,
#   'HEX1': True,
#   'HGNTOR': False,
#   'HIBDm': True,
#   'HISD': False,
#   'HISDC': True,
#   'HISt4': True,
#   'HISTAtu': True,
#   'HISTAVESSEC': False,
#   'HIStiDF': False,
#   'HIStN1': False,
#   'HKYNH': True,
#   'HMGCOASim': False,
#   'HMGCOAtm': True,
#   'HMGLm': True,
#   'HOMt4': True,
#   'Htm': True,
#   'Htr': True,
#   'Htx': False,
#   'ICDHxm': True,
#   'ICDHy': True,
#   'ICDHyrm': True,
#   'ILEt4': False,
#   'ILEt5m': False,
#   'ILETA': False,
#   'ILETAm': True,
#   'ILEtec': True,
#   'IZPN': False,
#   'KCC2t': True,
#   'KYN3OX': True,
#   'KYNAKGAT': True,
#   'KYNATESYN': False,
#   'LDH_L': True,
#   'LEUt4': True,
#   'LEUt5m': False,
#   'LEUTA': True,
#   'LEUTAm': True,
#   'LEUtec': True,
#   'L_LACDcm': True,
#   'L_LACt2r': True,
#   'L_LACt4r': True,
#   'LYSt4': True,
#   'LYStiDF': True,
#   'LYStm': True,
#   'MACACI': True,
#   'MALSO3tm': True,
#   'MALSO4tm': True,
#   'MALtm': True,
#   'MALTSULtm': True,
#   'MCCCrm': True,
#   'MDH': True,
#   'MDHm': True,
#   'ME1m': True,
#   'ME2': True,
#   'ME2m': True,
#   'METAT': True,
#   'METLEUex': True,
#   'METS': True,
#   'METt4': True,
#   'METtec': True,
#   'MGCHrm': True,
#   'MGSA': False,
#   'MGSA2': False,
#   'MMEm': True,
#   'MMMm': True,
#   'MMSAD3m': True,
#   'MMTSADm': False,
#   'MTHFC': True,
#   'MTHFD': True,
#   'MTHGXLt': False,
#   'NADH2_u10m': True,
#   'NADHtpu': False,
#   'NADHtru': False,
#   'NADPHtru': False,
#   'NADPtru': False,
#   'NADtpu': False,
#   'NADtru': False,
#   'NAHCO3_HCLt': True,
#   'NAt': True,
#   'NAt3_1': True,
#   'NAt5': True,
#   'NCCt': False,
#   'NDPK1': True,
#   'NDPK1m': True,
#   'NDPK2': True,
#   'NDPK3': True,
#   'NDPK4': True,
#   'NDPK5': True,
#   'NDPK8': True,
#   'NDPK9': True,
#   'NH4t3r': False,
#   'NH4tp': False,
#   'NKCC2t': True,
#   'NRPPHRt4_2_r': False,
#   'NRPPHRtu': False,
#   'NRPPHRVESSEC': False,
#   'NTD7': True,
#   'O2St': False,
#   'O2Stm': False,
#   'O2Stx': False,
#   'O2t': True,
#   'O2ter': True,
#   'O2tm': True,
#   'O2tp': False,
#   'OBDHc': False,
#   'OCBTm': False,
#   'OIVD1m': True,
#   'OIVD2m': True,
#   'OIVD3m': True,
#   'ORNDC': True,
#   'ORNt3m': True,
#   'ORNt4m': True,
#   'ORNTArm': True,
#   'ORNtiDF': True,
#   'OXAHCOtex': True,
#   'P5CDm': True,
#   'P5CRm': True,
#   'P5CRxm': True,
#   'PCLAD': False,
#   'PCm': True,
#   'PCREATtmdiffir': False,
#   'PDHm': True,
#   'PE_HStm': True,
#   'PEPCK': False,
#   'PEPCKm': True,
#   'PFK': True,
#   'PGCD': True,
#   'PGI': True,
#   'PGK': True,
#   'PGL': True,
#   'PGLer': True,
#   'PGM': True,
#   'PHEt4': True,
#   'PHEtec': True,
#   'PIt7': False,
#   'PIter': True,
#   'PPA': True,
#   'PPAm': True,
#   'PPCOACm': True,
#   'PPCOAOm': True,
#   'PPItr': True,
#   'PPM': True,
#   'PRFGS': True,
#   'PRO1xm': True,
#   'PROD2m': True,
#   'PROt2r': True,
#   'PROt4': True,
#   'PRPNCOAHYDm': True,
#   'PRPPS': True,
#   'PSERT': True,
#   'PSFLIPm': True,
#   'PSP_L': True,
#   'PTRCOX1': True,
#   'PUNP1': True,
#   'PYK': True,
#   'PYRt2m': True,
#   'PYRt2p': True,
#   'PYRt2r': True,
#   'RETNt': False,
#   'RPE': True,
#   'RPI': True,
#   'SACCD3m': False,
#   'SACCD4m': False,
#   'SARCStm': True,
#   'SARDHm': True,
#   'SERALANaEx': True,
#   'SERASNNaEx': True,
#   'SERCYSNaEx': True,
#   'SERGLNexR': False,
#   'SERGLNNaEx': True,
#   'SERGLYexR': False,
#   'SERHL': False,
#   'SERLYSNaex': False,
#   'SERt4': True,
#   'SERTHRNaEx': True,
#   'SERtN1': False,
#   'SO4CLtex2': True,
#   'SO4HCOtex': True,
#   'SO4OXAtex2': True,
#   'SO4t4_2': False,
#   'SPMDOX': False,
#   'SPMS': True,
#   'SPODM': True,
#   'SPODMe': True,
#   'SPODMm': True,
#   'SPODMx': True,
#   'SPRMS': True,
#   'SUCCt2m': True,
#   'SUCCt4_2': True,
#   'SUCD1m': True,
#   'SUCOAS1m': True,
#   'SUCOASm': True,
#   'SULFOX': True,
#   'TALA': True,
#   'THD1m': True,
#   'THRALANaEx': True,
#   'THRASNNaEx': True,
#   'THRCYSNaEx': True,
#   'THRD_L': True,
#   'THRGLNexR': False,
#   'THRGLNNaEx': True,
#   'THRGLYexR': False,
#   'THRSERNaEx': True,
#   'THRt4': True,
#   'TKT1': True,
#   'TKT2': True,
#   'TPI': True,
#   'TRPO2': True,
#   'TRPt': True,
#   'TRPt4': False,
#   'TYRt': False,
#   'TYRt4': False,
#   'TYRTA': True,
#   'UDPGLCAter': True,
#   'UMPK': True,
#   'UMPK2': True,
#   'UMPK3': True,
#   'UMPK4': True,
#   'UMPK5': True,
#   'UMPK7': True,
#   'UMPtr': False,
#   'URCN': False,
#   'UREAt': True,
#   'UREAt5': False,
#   'UREAtm': False,
#   'VALt4': False,
#   'VALt5m': False,
#   'VALTA': False,
#   'VALTAm': True,
#   'VALtec': True,
#   'XYLUR': True,
#   'EX_fald_e': False,
#   'EX_ptrc_e': False,
#   'EX_spmd_e': False,
#   'r0010': True,
#   'r0021': True,
#   'r0022': True,
#   'r0028': True,
#   'r0034': True,
#   'r0055': False,
#   'r0060': False,
#   'r0062': False,
#   'r0074': True,
#   'r0081': True,
#   'r0085': True,
#   'r0086': True,
#   'r0119': True,
#   'r0122': False,
#   'r0127': False,
#   'r0142': True,
#   'r0153': False,
#   'r0156': False,
#   'r0157': False,
#   'r0165': False,
#   'r0173': True,
#   'r0178': False,
#   'r0179': False,
#   'r0191': True,
#   'r0202': True,
#   'r0249': True,
#   'r0280': False,
#   'r0295': True,
#   'r0301': True,
#   'r0317': True,
#   'r0354': True,
#   'r0355': True,
#   'r0365': False,
#   'r0398': True,
#   'r0399': False,
#   'r0413': False,
#   'r0426': True,
#   'r0450': False,
#   'r0464': True,
#   'r0483': True,
#   'r0509': True,
#   'r0525': False,
#   'r0541': True,
#   'r0549': True,
#   'r0552': True,
#   'r0553': True,
#   'r0560': False,
#   'r0570': True,
#   'r0596': True,
#   'r0645': False,
#   'r0647': False,
#   'r0655': True,
#   'r0669': True,
#   'r0683': True,
#   'r0779': True,
#   'r0784': False,
#   'r0792': True,
#   'r0801': True,
#   'r0812': True,
#   'r0817': False,
#   'r0819': True,
#   'r0821': True,
#   'r0822': True,
#   'r0829': True,
#   'r0830': True,
#   'r0838': False,
#   'r0839': False,
#   'r0840': False,
#   'r0841': True,
#   'r0860': False,
#   'r0879': True,
#   'r0881': False,
#   'r0885': True,
#   'r0899': False,
#   'r0911': True,
#   'r0913': True,
#   'r0915': True,
#   'r0917': True,
#   'r0924': False,
#   'r0941': True,
#   'r0942': True,
#   'r0944': False,
#   'r0946': False,
#   'r1030': False,
#   'r1050': False,
#   'r1051': True,
#   'r1052': False,
#   'r1088': False,
#   'r1090': True,
#   'r1109': False,
#   'r1143': False,
#   'r1144': False,
#   'r1147': True,
#   'r1154': True,
#   'r1155': True,
#   'r1162': False,
#   'r1291': False,
#   'r1421': False,
#   'r1427': False,
#   'r1428': False,
#   'r1429': False,
#   'r1434': False,
#   'r1435': False,
#   'r1453': True,
#   'r1454': True,
#   'r1464': False,
#   'r1493': False,
#   'r1530': True,
#   'r1538': False,
#   'r1544': True,
#   'r1546': True,
#   'r1547': True,
#   'r1548': True,
#   'r1549': True,
#   'r1551': True,
#   'r1552': True,
#   'r1553': True,
#   'r1554': True,
#   'r1556': True,
#   'r1557': True,
#   'r1559': True,
#   'r1560': True,
#   'r1561': True,
#   'r1562': True,
#   'r1563': True,
#   'r1564': True,
#   'r1565': True,
#   'r1566': True,
#   'r1567': True,
#   'r1568': True,
#   'r1569': True,
#   'r1570': True,
#   'r1571': True,
#   'r1573': True,
#   'r1574': True,
#   'r1575': True,
#   'r1576': True,
#   'r1578': True,
#   'r1579': True,
#   'r1580': True,
#   'r1581': True,
#   'r1583': True,
#   'r1584': True,
#   'r1585': True,
#   'r1586': True,
#   'r1587': True,
#   'r1588': True,
#   'r1589': True,
#   'r1590': True,
#   'r1591': True,
#   'r1592': True,
#   'r1593': True,
#   'r1594': True,
#   'r1595': True,
#   'r1596': True,
#   'r1597': True,
#   'r1598': True,
#   'r1599': True,
#   'r1600': True,
#   'r1602': True,
#   'r1603': True,
#   'r1604': True,
#   'r1605': True,
#   'r1606': True,
#   'r1607': True,
#   'r1608': True,
#   'r1609': True,
#   'r1610': True,
#   'r1611': True,
#   'r1612': True,
#   'r1613': True,
#   'r1614': True,
#   'r1615': True,
#   'r1616': True,
#   'r1617': True,
#   'r1618': True,
#   'r1619': True,
#   'r1620': True,
#   'r1621': True,
#   'r1622': True,
#   'r1623': True,
#   'r1624': True,
#   'r1625': True,
#   'r1626': True,
#   'r1627': True,
#   'r1628': True,
#   'r1629': True,
#   'r1630': True,
#   'r1631': True,
#   'r1632': True,
#   'r1633': True,
#   'r1634': True,
#   'r1635': True,
#   'r1636': True,
#   'r1637': True,
#   'r1638': True,
#   'r1639': True,
#   'r1640': True,
#   'r1641': True,
#   'r1642': True,
#   'r1643': True,
#   'r1644': True,
#   'r1645': True,
#   'r1646': True,
#   'r1647': True,
#   'r1648': True,
#   'r1649': True,
#   'r1650': True,
#   'r1651': True,
#   'r1652': True,
#   'r1653': True,
#   'r1654': True,
#   'r1655': True,
#   'r1656': True,
#   'r1657': True,
#   'r1658': True,
#   'r1659': True,
#   'r1660': True,
#   'r1661': True,
#   'r1662': True,
#   'r1664': True,
#   'r1665': True,
#   'r1666': True,
#   'r1667': True,
#   'r1668': True,
#   'r1669': True,
#   'r1670': True,
#   'r1671': True,
#   'r1672': True,
#   'r1673': True,
#   'r1674': True,
#   'r1675': True,
#   'r1676': True,
#   'r1677': True,
#   'r1678': True,
#   'r1679': True,
#   'r1680': True,
#   'r1681': True,
#   'r1682': True,
#   'r1683': True,
#   'r1684': True,
#   'r1685': True,
#   'r1686': True,
#   'r1687': True,
#   'r1690': True,
#   'r1691': True,
#   'r1692': True,
#   'r1693': True,
#   'r1695': True,
#   'r1696': True,
#   'r1698': True,
#   'r1700': True,
#   'r1701': True,
#   'r1702': True,
#   'r1705': True,
#   'r1706': True,
#   'r1707': True,
#   'r1708': True,
#   'r1710': True,
#   'r1711': True,
#   'r1713': True,
#   'r1715': True,
#   'r1716': True,
#   'r1717': True,
#   'r1720': True,
#   'r1721': True,
#   'r1722': True,
#   'r1723': True,
#   'r1725': True,
#   'r1726': True,
#   'r1728': True,
#   'r1730': True,
#   'r1731': True,
#   'r1732': True,
#   'r1733': True,
#   'r1734': True,
#   'r1735': True,
#   'r1736': True,
#   'r1737': True,
#   'r1738': True,
#   'r1739': True,
#   'r1740': True,
#   'r1741': True,
#   'r1742': True,
#   'r1743': True,
#   'r1744': True,
#   'r1745': True,
#   'r1746': True,
#   'r1747': True,
#   'r1748': True,
#   'r1749': True,
#   'r1750': True,
#   'r1751': True,
#   'r1752': True,
#   'r1753': True,
#   'r1754': True,
#   'r1755': True,
#   'r1756': True,
#   'r1757': True,
#   'r1758': True,
#   'r1759': True,
#   'r1760': True,
#   'r1761': True,
#   'r1762': True,
#   'r1763': True,
#   'r1764': True,
#   'r1765': True,
#   'r1766': True,
#   'r1767': True,
#   'r1768': True,
#   'r1769': True,
#   'r1770': True,
#   'r1771': True,
#   'r1772': True,
#   'r1773': True,
#   'r1774': True,
#   'r1775': True,
#   'r1776': True,
#   'r1777': True,
#   'r1778': True,
#   'r1779': True,
#   'r1780': True,
#   'r1781': True,
#   'r1782': True,
#   'r1783': True,
#   'r1784': True,
#   'r1785': True,
#   'r1786': True,
#   'r1787': True,
#   'r1788': True,
#   'r1789': True,
#   'r1790': True,
#   'r1791': True,
#   'r1792': True,
#   'r1796': True,
#   'r1797': True,
#   'r1798': True,
#   'r1799': True,
#   'r1800': True,
#   'r1801': True,
#   'r1803': True,
#   'r1805': True,
#   'r1806': True,
#   'r1807': True,
#   'r1808': True,
#   'r1809': True,
#   'r1810': True,
#   'r1811': True,
#   'r1812': True,
#   'r1813': True,
#   'r1814': True,
#   'r1815': True,
#   'r1816': True,
#   'r1817': True,
#   'r1818': True,
#   'r1819': True,
#   'r1820': True,
#   'r1821': True,
#   'r1822': True,
#   'r1823': True,
#   'r1824': True,
#   'r1825': True,
#   'r1826': True,
#   'r1827': True,
#   'r1828': True,
#   'r1829': True,
#   'r1830': True,
#   'r1831': True,
#   'r1832': True,
#   'r1833': True,
#   'r1834': True,
#   'r1835': True,
#   'r1836': True,
#   'r1837': True,
#   'r1841': True,
#   'r1842': True,
#   'r1843': True,
#   'r1844': True,
#   'r1846': True,
#   'r1847': True,
#   'r1848': True,
#   'r1850': True,
#   'r1851': True,
#   'r1852': True,
#   'r1853': True,
#   'r1854': True,
#   'r1855': True,
#   'r1856': True,
#   'r1857': True,
#   'r1858': True,
#   'r1859': True,
#   'r1860': True,
#   'r1861': True,
#   'r1862': True,
#   'r1863': True,
#   'r1864': True,
#   'r1865': True,
#   'r1866': True,
#   'r1867': True,
#   'r1871': True,
#   'r1872': True,
#   'r1873': True,
#   'r1874': True,
#   'r1876': True,
#   'r1877': True,
#   'r1879': True,
#   'r1880': True,
#   'r1881': True,
#   'r1882': True,
#   'r1883': True,
#   'r1884': True,
#   'r1885': True,
#   'r1886': True,
#   'r1887': True,
#   'r1888': True,
#   'r1889': True,
#   'r1890': True,
#   'r1891': True,
#   'r1892': True,
#   'r1893': True,
#   'r1894': True,
#   'r1895': True,
#   'r1896': True,
#   'r1897': True,
#   'r1898': True,
#   'r1899': True,
#   'r1900': True,
#   'r1901': True,
#   'r1902': True,
#   'r1903': True,
#   'r1904': True,
#   'r1905': True,
#   'r1906': True,
#   'r1907': True,
#   'r1908': True,
#   ...},
#  'ACH-000019': {'2AMACHYD': False,
#   '2AMADPTm': True,
#   '2DR1PP': False,
#   '2HCO3_NAt': True,
#   '2OXOADOXm': True,
#   '2OXOADPTm': True,
#   '34HPPOR': False,
#   '3AIBt': False,
#   '3AIBTm': True,
#   '3AIBtm': True,
#   '3HAO': False,
#   '3HBCOAHLm': False,
#   '3HKYNAKGAT': True,
#   '3MOBt2im': False,
#   '3MOPt2im': False,
#   '3SALAASPm': True,
#   '3SALATAi': True,
#   '3SALATAim': True,
#   '3SPYRSP': False,
#   '3SPYRSPm': False,
#   '4ABUTtm': False,
#   '4MOPt2im': True,
#   '5MTHFt': True,
#   '5MTHFt2': True,
#   'AACOAT': True,
#   'AACTOOR': False,
#   'AACTtm': False,
#   'AASAD3m': False,
#   'AATAi': True,
#   'ABTArm': True,
#   'ABUTD': True,
#   'ABUTt2r': True,
#   'ABUTt4_2_r': False,
#   'ACACT10m': True,
#   'ACACT1r': True,
#   'ACACt2': True,
#   'ACACt2m': True,
#   'ACETONEt2': True,
#   'ACETONEt2m': True,
#   'ACITL': True,
#   'ACOAD10m': True,
#   'ACOAD9m': True,
#   'ACOAHi': False,
#   'ACONT': True,
#   'ACONTm': True,
#   'ACS': True,
#   'ACSm': True,
#   'ACt2m': False,
#   'ACt2r': False,
#   'ACTLMO': True,
#   'ACTNMO': True,
#   'ACYP': True,
#   'ADCim': False,
#   'ADEt': True,
#   'ADK1': True,
#   'ADK1m': True,
#   'ADK3': False,
#   'ADK3m': True,
#   'ADMDC': True,
#   'ADNK1': True,
#   'ADPT': True,
#   'ADPtx': False,
#   'AGTim': False,
#   'AHC': True,
#   'AKGDm': True,
#   'AKGMALtm': True,
#   'AKGt4_3': True,
#   'ALAASNNaEx': True,
#   'ALACYSNaEx': True,
#   'ALAGLNexR': False,
#   'ALAGLNNaEx': True,
#   'ALAGLYexR': False,
#   'ALASERNaEx': True,
#   'ALAt2r': True,
#   'ALAt4': True,
#   'ALATA_L': True,
#   'ALATHRNaEx': True,
#   'ALAtN1': False,
#   'AMCOXO': False,
#   'AMETt2m': True,
#   'AMPtp': False,
#   'AOBUTDsm': False,
#   'APAT2rm': True,
#   'ARGLYSex': True,
#   'ARGN': True,
#   'ARGNm': True,
#   'ARGt4': True,
#   'ARGtiDF': True,
#   'ARGtm': True,
#   'ASNALANaEx': True,
#   'ASNCYSNaEx': True,
#   'ASNGLNNaEx': True,
#   'ASNS1': True,
#   'ASNSERNaEx': True,
#   'ASNt4': True,
#   'ASNTHRNaEx': True,
#   'ASNtN1': False,
#   'ASPGLUm': True,
#   'ASPTA': True,
#   'ASPTAm': True,
#   'ATP1ter': False,
#   'ATPS4m': True,
#   'ATPtm': True,
#   'ATPtx': False,
#   'BALAtmr': False,
#   'BALAVECSEC': False,
#   'BETALDHxm': False,
#   'BHMT': False,
#   'CATm': True,
#   'CATp': True,
#   'CBPS': True,
#   'CBPSam': True,
#   'CHLtm': False,
#   'CHOLD2m': True,
#   'CHOLt4': False,
#   'CHOLtu': True,
#   'CHSTEROLt': False,
#   'CHSTEROLt1': True,
#   'CHSTEROLt2': False,
#   'CHSTEROLt3': True,
#   'CITL': True,
#   'CITRtm': True,
#   'CITt4_2': False,
#   'CITtam': True,
#   'CITtbm': True,
#   'CK': True,
#   'CKc': True,
#   'CLFORtex': False,
#   'CLHCO3tex2': True,
#   'CLOHtex2': True,
#   'CLOXAtex2': True,
#   'CO2t': False,
#   'CO2ter': True,
#   'CO2tm': True,
#   'COAtm': True,
#   'CREATt4_2_r': True,
#   'CREATtmdiffir': False,
#   'CSm': True,
#   'CTPS1': True,
#   'CTPS2': True,
#   'CYOR_u10m': True,
#   'CYSALANaEx': True,
#   'CYSASNNaEx': True,
#   'CYSGLNNaEx': True,
#   'CYSGLUexR': True,
#   'CYSGLYexR': True,
#   'CYSO': False,
#   'CYSSERNaEx': True,
#   'CYSt4': True,
#   'CYStec': True,
#   'CYSTGL': True,
#   'CYSTHRNaEx': True,
#   'CYSTS': True,
#   'D_3AIBt': False,
#   'D3AIBTm': False,
#   'DATPtn': True,
#   'DCTPtn': True,
#   'DGTPtn': True,
#   'DHPR': True,
#   'ATPM': False,
#   'DMGDHm': False,
#   'DMGtm': False,
#   'DNDPt11m': True,
#   'DNDPt23m': True,
#   'DNDPt24m': True,
#   'DNDPt34m': True,
#   'DNDPt35m': True,
#   'DNDPt9m': True,
#   'DPGase': True,
#   'DPGM': True,
#   'DRBK': True,
#   'DTTPtn': True,
#   'ECOAH12m': True,
#   'ECOAH1m': True,
#   'ECOAH9m': True,
#   'ENO': True,
#   'EX_3aib_e': False,
#   'EX_3aib_D_e': False,
#   'EX_4abut_e': False,
#   'EX_ac_e': False,
#   'EX_acac_e': False,
#   'EX_acetone_e': False,
#   'EX_ade_e': False,
#   'EX_akg_e': False,
#   'EX_ala_B_e': False,
#   'EX_ala_L_e': False,
#   'EX_arg_L_e': True,
#   'EX_asn_L_e': True,
#   'EX_asp_L_e': True,
#   'EX_chol_e': True,
#   'EX_chsterol_e': False,
#   'EX_cit_e': False,
#   'EX_co2_e': False,
#   'EX_creat_e': False,
#   'EX_for_e': True,
#   'EX_glc_e': True,
#   'EX_gln_L_e': True,
#   'EX_glu_L_e': False,
#   'EX_gly_e': True,
#   'EX_glyb_e': False,
#   'EX_gthrd_e': False,
#   'EX_h_e': False,
#   'EX_h2o_e': True,
#   'EX_h2o2_e': False,
#   'EX_hco3_e': False,
#   'EX_his_L_e': True,
#   'EX_hista_e': False,
#   'EX_ile_L_e': True,
#   'EX_lac_L_e': False,
#   'EX_leu_L_e': True,
#   'EX_lys_L_e': True,
#   'EX_met_L_e': True,
#   'EX_mthgxl_e': False,
#   'EX_nh4_e': False,
#   'EX_o2_e': True,
#   'EX_o2s_e': False,
#   'EX_orn_e': False,
#   'EX_phe_L_e': True,
#   'EX_pi_e': True,
#   'EX_pro_L_e': True,
#   'EX_pyr_e': False,
#   'EX_ser_L_e': True,
#   'EX_so4_e': False,
#   'EX_succ_e': True,
#   'EX_thr_L_e': True,
#   'EX_trp_L_e': True,
#   'EX_tyr_L_e': True,
#   'EX_urea_e': True,
#   'EX_val_L_e': True,
#   'FALDtm': False,
#   'FBA': True,
#   'FBP': True,
#   'FDH': False,
#   'FKYNH': True,
#   'FORtr': True,
#   'FTCD': True,
#   'FTHFDH': True,
#   'FUM': True,
#   'FUMAC': True,
#   'FUMm': True,
#   'FUMSO3tm': True,
#   'FUMSO4tm': True,
#   'FUMtm': True,
#   'FUMTSULtm': True,
#   'G3PD1': True,
#   'G3PD2m': True,
#   'G5SADrm': True,
#   'G5SADs': False,
#   'G5SDym': True,
#   'G6PDA': True,
#   'G6PDH1rer': True,
#   'G6PDH2r': True,
#   'G6PDH2rer': True,
#   'G6PPer': True,
#   'G6Pter': True,
#   'GABAVESSEC': False,
#   'GACMTRc': True,
#   'GAPD': True,
#   'GCC2am': False,
#   'GCC2bim': False,
#   'GCC2cm': False,
#   'GCCam': False,
#   'GCCbim': False,
#   'GCCcm': False,
#   'GF6PTA': True,
#   'GHMT2r': True,
#   'GHMT2rm': True,
#   'GK1': True,
#   'GLCMter': False,
#   'GLCt1r': True,
#   'GLCt2_2': False,
#   'GLCt4': True,
#   'GLCter': False,
#   'GLCURter': False,
#   'GLNALANaEx': True,
#   'GLNASNNaEx': True,
#   'GLNCYSNaEx': True,
#   'GLNS': True,
#   'GLNSERNaEx': True,
#   'GLNt4': True,
#   'GLNTHRNaEx': True,
#   'GLNtm': False,
#   'GLNtN1': False,
#   'GLU5Km': True,
#   'GLUCYS': True,
#   'GLUDC': True,
#   'GLUDxm': True,
#   'GLUDym': True,
#   'GluForTx': True,
#   'GLUNm': True,
#   'GLUPRT': True,
#   'GLUt2m': True,
#   'GLUTCOADHm': True,
#   'GLUVESSEC': False,
#   'GLXtm': False,
#   'GLXtp': False,
#   'GLYAMDTRc': False,
#   'GLYATm': True,
#   'GLYBt4_2_r': False,
#   'GLYBtm': False,
#   'GLYC3Ptm': False,
#   'GLYOp': False,
#   'GLYt2r': True,
#   'GLYt4': True,
#   'GLYt7_211_r': True,
#   'GLYtm': True,
#   'GLYtp': False,
#   'GLYVESSEC': False,
#   'GMPS2': True,
#   'GND': True,
#   'GNDer': True,
#   'GNMT': True,
#   'GTHO': True,
#   'GTHOm': True,
#   'GTHP': True,
#   'GTHPm': True,
#   'GTHRDt': True,
#   'GTHS': True,
#   'GULNDer': False,
#   'GULNter': False,
#   'H2CO3D': True,
#   'H2O2syn': False,
#   'H2O2t': False,
#   'H2O2tm': False,
#   'H2O2tp': False,
#   'H2Ot': True,
#   'H2Oter': True,
#   'H2Otm': False,
#   'H2Otp': False,
#   'HACD1m': True,
#   'HACD9m': True,
#   'HCO3_CLt': True,
#   'HEX1': True,
#   'HGNTOR': True,
#   'HIBDm': True,
#   'HISD': False,
#   'HISDC': False,
#   'HISt4': True,
#   'HISTAtu': True,
#   'HISTAVESSEC': False,
#   'HIStiDF': False,
#   'HIStN1': False,
#   'HKYNH': True,
#   'HMGCOASim': False,
#   'HMGCOAtm': True,
#   'HMGLm': True,
#   'HOMt4': True,
#   'Htm': True,
#   'Htr': True,
#   'Htx': False,
#   'ICDHxm': True,
#   'ICDHy': True,
#   'ICDHyrm': True,
#   'ILEt4': True,
#   'ILEt5m': False,
#   'ILETA': False,
#   'ILETAm': True,
#   'ILEtec': True,
#   'IZPN': False,
#   'KCC2t': True,
#   'KYN3OX': False,
#   'KYNAKGAT': True,
#   'KYNATESYN': False,
#   'LDH_L': True,
#   'LEUt4': True,
#   'LEUt5m': False,
#   'LEUTA': True,
#   'LEUTAm': True,
#   'LEUtec': True,
#   'L_LACDcm': True,
#   'L_LACt2r': True,
#   'L_LACt4r': True,
#   'LYSt4': True,
#   'LYStiDF': True,
#   'LYStm': True,
#   'MACACI': True,
#   'MALSO3tm': True,
#   'MALSO4tm': True,
#   'MALtm': True,
#   'MALTSULtm': True,
#   'MCCCrm': True,
#   'MDH': True,
#   'MDHm': True,
#   'ME1m': True,
#   'ME2': True,
#   'ME2m': True,
#   'METAT': True,
#   'METLEUex': True,
#   'METS': True,
#   'METt4': True,
#   'METtec': True,
#   'MGCHrm': True,
#   'MGSA': False,
#   'MGSA2': False,
#   'MMEm': True,
#   'MMMm': True,
#   'MMSAD3m': True,
#   'MMTSADm': False,
#   'MTHFC': True,
#   'MTHFD': True,
#   'MTHGXLt': False,
#   'NADH2_u10m': True,
#   'NADHtpu': False,
#   'NADHtru': False,
#   'NADPHtru': False,
#   'NADPtru': False,
#   'NADtpu': False,
#   'NADtru': False,
#   'NAHCO3_HCLt': True,
#   'NAt': True,
#   'NAt3_1': True,
#   'NAt5': True,
#   'NCCt': False,
#   'NDPK1': True,
#   'NDPK1m': True,
#   'NDPK2': True,
#   'NDPK3': True,
#   'NDPK4': True,
#   'NDPK5': True,
#   'NDPK8': True,
#   'NDPK9': True,
#   'NH4t3r': True,
#   'NH4tp': False,
#   'NKCC2t': True,
#   'NRPPHRt4_2_r': False,
#   'NRPPHRtu': False,
#   'NRPPHRVESSEC': False,
#   'NTD7': True,
#   'O2St': False,
#   'O2Stm': False,
#   'O2Stx': False,
#   'O2t': True,
#   'O2ter': True,
#   'O2tm': True,
#   'O2tp': False,
#   'OBDHc': False,
#   'OCBTm': False,
#   'OIVD1m': True,
#   'OIVD2m': True,
#   'OIVD3m': True,
#   'ORNDC': True,
#   'ORNt3m': True,
#   'ORNt4m': True,
#   'ORNTArm': True,
#   'ORNtiDF': True,
#   'OXAHCOtex': True,
#   'P5CDm': True,
#   'P5CRm': True,
#   'P5CRxm': True,
#   'PCLAD': False,
#   'PCm': True,
#   'PCREATtmdiffir': False,
#   'PDHm': True,
#   'PE_HStm': True,
#   'PEPCK': False,
#   'PEPCKm': True,
#   'PFK': True,
#   'PGCD': True,
#   'PGI': True,
#   'PGK': True,
#   'PGL': True,
#   'PGLer': True,
#   'PGM': True,
#   'PHEt4': True,
#   'PHEtec': True,
#   'PIt7': False,
#   'PIter': True,
#   'PPA': True,
#   'PPAm': True,
#   'PPCOACm': True,
#   'PPCOAOm': True,
#   'PPItr': True,
#   'PPM': True,
#   'PRFGS': True,
#   'PRO1xm': True,
#   'PROD2m': True,
#   'PROt2r': True,
#   'PROt4': True,
#   'PRPNCOAHYDm': True,
#   'PRPPS': True,
#   'PSERT': True,
#   'PSFLIPm': True,
#   'PSP_L': True,
#   'PTRCOX1': True,
#   'PUNP1': True,
#   'PYK': True,
#   'PYRt2m': True,
#   'PYRt2p': True,
#   'PYRt2r': True,
#   'RETNt': False,
#   'RPE': True,
#   'RPI': True,
#   'SACCD3m': False,
#   'SACCD4m': False,
#   'SARCStm': True,
#   'SARDHm': True,
#   'SERALANaEx': True,
#   'SERASNNaEx': True,
#   'SERCYSNaEx': True,
#   'SERGLNexR': False,
#   'SERGLNNaEx': True,
#   'SERGLYexR': False,
#   'SERHL': False,
#   'SERLYSNaex': False,
#   'SERt4': True,
#   'SERTHRNaEx': True,
#   'SERtN1': False,
#   'SO4CLtex2': True,
#   'SO4HCOtex': True,
#   'SO4OXAtex2': True,
#   'SO4t4_2': False,
#   'SPMDOX': False,
#   'SPMS': True,
#   'SPODM': True,
#   'SPODMe': False,
#   'SPODMm': True,
#   'SPODMx': True,
#   'SPRMS': True,
#   'SUCCt2m': True,
#   'SUCCt4_2': True,
#   'SUCD1m': True,
#   'SUCOAS1m': True,
#   'SUCOASm': True,
#   'SULFOX': True,
#   'TALA': True,
#   'THD1m': True,
#   'THRALANaEx': True,
#   'THRASNNaEx': True,
#   'THRCYSNaEx': True,
#   'THRD_L': True,
#   'THRGLNexR': False,
#   'THRGLNNaEx': True,
#   'THRGLYexR': False,
#   'THRSERNaEx': True,
#   'THRt4': True,
#   'TKT1': True,
#   'TKT2': True,
#   'TPI': True,
#   'TRPO2': False,
#   'TRPt': True,
#   'TRPt4': True,
#   'TYRt': False,
#   'TYRt4': True,
#   'TYRTA': True,
#   'UDPGLCAter': True,
#   'UMPK': True,
#   'UMPK2': True,
#   'UMPK3': True,
#   'UMPK4': True,
#   'UMPK5': True,
#   'UMPK7': True,
#   'UMPtr': False,
#   'URCN': False,
#   'UREAt': True,
#   'UREAt5': False,
#   'UREAtm': False,
#   'VALt4': True,
#   'VALt5m': False,
#   'VALTA': False,
#   'VALTAm': True,
#   'VALtec': True,
#   'XYLUR': True,
#   'EX_fald_e': False,
#   'EX_ptrc_e': False,
#   'EX_spmd_e': False,
#   'r0010': True,
#   'r0021': True,
#   'r0022': True,
#   'r0028': True,
#   'r0034': False,
#   'r0055': False,
#   'r0060': False,
#   'r0062': False,
#   'r0074': True,
#   'r0081': True,
#   'r0085': True,
#   'r0086': True,
#   'r0119': True,
#   'r0122': False,
#   'r0127': False,
#   'r0142': True,
#   'r0153': False,
#   'r0156': False,
#   'r0157': False,
#   'r0165': False,
#   'r0173': True,
#   'r0178': True,
#   'r0179': False,
#   'r0191': True,
#   'r0202': False,
#   'r0249': True,
#   'r0280': False,
#   'r0295': True,
#   'r0301': True,
#   'r0317': True,
#   'r0354': True,
#   'r0355': True,
#   'r0365': False,
#   'r0398': True,
#   'r0399': True,
#   'r0413': False,
#   'r0426': True,
#   'r0450': True,
#   'r0464': True,
#   'r0483': True,
#   'r0509': True,
#   'r0525': False,
#   'r0541': True,
#   'r0549': True,
#   'r0552': True,
#   'r0553': True,
#   'r0560': True,
#   'r0570': True,
#   'r0596': True,
#   'r0645': False,
#   'r0647': False,
#   'r0655': True,
#   'r0669': True,
#   'r0683': True,
#   'r0779': True,
#   'r0784': False,
#   'r0792': True,
#   'r0801': True,
#   'r0812': True,
#   'r0817': True,
#   'r0819': True,
#   'r0821': True,
#   'r0822': True,
#   'r0829': True,
#   'r0830': True,
#   'r0838': False,
#   'r0839': False,
#   'r0840': False,
#   'r0841': True,
#   'r0860': False,
#   'r0879': True,
#   'r0881': False,
#   'r0885': True,
#   'r0899': False,
#   'r0911': True,
#   'r0913': True,
#   'r0915': True,
#   'r0917': True,
#   'r0924': False,
#   'r0941': True,
#   'r0942': True,
#   'r0944': False,
#   'r0946': False,
#   'r1030': False,
#   'r1050': False,
#   'r1051': True,
#   'r1052': False,
#   'r1088': False,
#   'r1090': True,
#   'r1109': False,
#   'r1143': False,
#   'r1144': False,
#   'r1147': True,
#   'r1154': True,
#   'r1155': True,
#   'r1162': False,
#   'r1291': False,
#   'r1421': False,
#   'r1427': False,
#   'r1428': False,
#   'r1429': False,
#   'r1434': False,
#   'r1435': False,
#   'r1453': True,
#   'r1454': True,
#   'r1464': False,
#   'r1493': False,
#   'r1530': True,
#   'r1538': False,
#   'r1544': True,
#   'r1546': True,
#   'r1547': True,
#   'r1548': True,
#   'r1549': True,
#   'r1551': True,
#   'r1552': True,
#   'r1553': True,
#   'r1554': True,
#   'r1556': True,
#   'r1557': True,
#   'r1559': True,
#   'r1560': True,
#   'r1561': True,
#   'r1562': True,
#   'r1563': True,
#   'r1564': True,
#   'r1565': True,
#   'r1566': True,
#   'r1567': True,
#   'r1568': True,
#   'r1569': True,
#   'r1570': True,
#   'r1571': True,
#   'r1573': True,
#   'r1574': True,
#   'r1575': True,
#   'r1576': True,
#   'r1578': True,
#   'r1579': True,
#   'r1580': True,
#   'r1581': True,
#   'r1583': True,
#   'r1584': True,
#   'r1585': True,
#   'r1586': True,
#   'r1587': True,
#   'r1588': True,
#   'r1589': True,
#   'r1590': True,
#   'r1591': True,
#   'r1592': True,
#   'r1593': True,
#   'r1594': True,
#   'r1595': True,
#   'r1596': True,
#   'r1597': True,
#   'r1598': True,
#   'r1599': True,
#   'r1600': True,
#   'r1602': True,
#   'r1603': True,
#   'r1604': True,
#   'r1605': True,
#   'r1606': True,
#   'r1607': True,
#   'r1608': True,
#   'r1609': True,
#   'r1610': True,
#   'r1611': True,
#   'r1612': True,
#   'r1613': True,
#   'r1614': True,
#   'r1615': True,
#   'r1616': True,
#   'r1617': True,
#   'r1618': True,
#   'r1619': True,
#   'r1620': True,
#   'r1621': True,
#   'r1622': True,
#   'r1623': True,
#   'r1624': True,
#   'r1625': True,
#   'r1626': True,
#   'r1627': True,
#   'r1628': True,
#   'r1629': True,
#   'r1630': True,
#   'r1631': True,
#   'r1632': True,
#   'r1633': True,
#   'r1634': True,
#   'r1635': True,
#   'r1636': True,
#   'r1637': True,
#   'r1638': True,
#   'r1639': True,
#   'r1640': True,
#   'r1641': True,
#   'r1642': True,
#   'r1643': True,
#   'r1644': True,
#   'r1645': True,
#   'r1646': True,
#   'r1647': True,
#   'r1648': True,
#   'r1649': True,
#   'r1650': True,
#   'r1651': True,
#   'r1652': True,
#   'r1653': True,
#   'r1654': True,
#   'r1655': True,
#   'r1656': True,
#   'r1657': True,
#   'r1658': True,
#   'r1659': True,
#   'r1660': True,
#   'r1661': True,
#   'r1662': True,
#   'r1664': True,
#   'r1665': True,
#   'r1666': True,
#   'r1667': True,
#   'r1668': True,
#   'r1669': True,
#   'r1670': True,
#   'r1671': True,
#   'r1672': True,
#   'r1673': True,
#   'r1674': True,
#   'r1675': True,
#   'r1676': True,
#   'r1677': True,
#   'r1678': True,
#   'r1679': True,
#   'r1680': True,
#   'r1681': True,
#   'r1682': True,
#   'r1683': True,
#   'r1684': True,
#   'r1685': True,
#   'r1686': True,
#   'r1687': True,
#   'r1690': True,
#   'r1691': True,
#   'r1692': True,
#   'r1693': True,
#   'r1695': True,
#   'r1696': True,
#   'r1698': True,
#   'r1700': True,
#   'r1701': True,
#   'r1702': True,
#   'r1705': True,
#   'r1706': True,
#   'r1707': True,
#   'r1708': True,
#   'r1710': True,
#   'r1711': True,
#   'r1713': True,
#   'r1715': True,
#   'r1716': True,
#   'r1717': True,
#   'r1720': True,
#   'r1721': True,
#   'r1722': True,
#   'r1723': True,
#   'r1725': True,
#   'r1726': True,
#   'r1728': True,
#   'r1730': True,
#   'r1731': True,
#   'r1732': True,
#   'r1733': True,
#   'r1734': True,
#   'r1735': True,
#   'r1736': True,
#   'r1737': True,
#   'r1738': True,
#   'r1739': True,
#   'r1740': True,
#   'r1741': True,
#   'r1742': True,
#   'r1743': True,
#   'r1744': True,
#   'r1745': True,
#   'r1746': True,
#   'r1747': True,
#   'r1748': True,
#   'r1749': True,
#   'r1750': True,
#   'r1751': True,
#   'r1752': True,
#   'r1753': True,
#   'r1754': True,
#   'r1755': True,
#   'r1756': True,
#   'r1757': True,
#   'r1758': True,
#   'r1759': True,
#   'r1760': True,
#   'r1761': True,
#   'r1762': True,
#   'r1763': True,
#   'r1764': True,
#   'r1765': True,
#   'r1766': True,
#   'r1767': True,
#   'r1768': True,
#   'r1769': True,
#   'r1770': True,
#   'r1771': True,
#   'r1772': True,
#   'r1773': True,
#   'r1774': True,
#   'r1775': True,
#   'r1776': True,
#   'r1777': True,
#   'r1778': True,
#   'r1779': True,
#   'r1780': True,
#   'r1781': True,
#   'r1782': True,
#   'r1783': True,
#   'r1784': True,
#   'r1785': True,
#   'r1786': True,
#   'r1787': True,
#   'r1788': True,
#   'r1789': True,
#   'r1790': True,
#   'r1791': True,
#   'r1792': True,
#   'r1796': True,
#   'r1797': True,
#   'r1798': True,
#   'r1799': True,
#   'r1800': True,
#   'r1801': True,
#   'r1803': True,
#   'r1805': True,
#   'r1806': True,
#   'r1807': True,
#   'r1808': True,
#   'r1809': True,
#   'r1810': True,
#   'r1811': True,
#   'r1812': True,
#   'r1813': True,
#   'r1814': True,
#   'r1815': True,
#   'r1816': True,
#   'r1817': True,
#   'r1818': True,
#   'r1819': True,
#   'r1820': True,
#   'r1821': True,
#   'r1822': True,
#   'r1823': True,
#   'r1824': True,
#   'r1825': True,
#   'r1826': True,
#   'r1827': True,
#   'r1828': True,
#   'r1829': True,
#   'r1830': True,
#   'r1831': True,
#   'r1832': True,
#   'r1833': True,
#   'r1834': True,
#   'r1835': True,
#   'r1836': True,
#   'r1837': True,
#   'r1841': True,
#   'r1842': True,
#   'r1843': True,
#   'r1844': True,
#   'r1846': True,
#   'r1847': True,
#   'r1848': True,
#   'r1850': True,
#   'r1851': True,
#   'r1852': True,
#   'r1853': True,
#   'r1854': True,
#   'r1855': True,
#   'r1856': True,
#   'r1857': True,
#   'r1858': True,
#   'r1859': True,
#   'r1860': True,
#   'r1861': True,
#   'r1862': True,
#   'r1863': True,
#   'r1864': True,
#   'r1865': True,
#   'r1866': True,
#   'r1867': True,
#   'r1871': True,
#   'r1872': True,
#   'r1873': True,
#   'r1874': True,
#   'r1876': True,
#   'r1877': True,
#   'r1879': True,
#   'r1880': True,
#   'r1881': True,
#   'r1882': True,
#   'r1883': True,
#   'r1884': True,
#   'r1885': True,
#   'r1886': True,
#   'r1887': True,
#   'r1888': True,
#   'r1889': True,
#   'r1890': True,
#   'r1891': True,
#   'r1892': True,
#   'r1893': True,
#   'r1894': True,
#   'r1895': True,
#   'r1896': True,
#   'r1897': True,
#   'r1898': True,
#   'r1899': True,
#   'r1900': True,
#   'r1901': True,
#   'r1902': True,
#   'r1903': True,
#   'r1904': True,
#   'r1905': True,
#   'r1906': True,
#   'r1907': True,
#   'r1908': True,
#   ...},
#  'ACH-000028': {'2AMACHYD': False,
#   '2AMADPTm': True,
#   '2DR1PP': False,
#   '2HCO3_NAt': True,
#   '2OXOADOXm': True,
#   '2OXOADPTm': True,
#   '34HPPOR': False,
#   '3AIBt': False,
#   '3AIBTm': True,
#   '3AIBtm': True,
#   '3HAO': False,
#   '3HBCOAHLm': False,
#   '3HKYNAKGAT': True,
#   '3MOBt2im': False,
#   '3MOPt2im': False,
#   '3SALAASPm': True,
#   '3SALATAi': True,
#   '3SALATAim': True,
#   '3SPYRSP': False,
#   '3SPYRSPm': False,
#   '4ABUTtm': False,
#   '4MOPt2im': False,
#   '5MTHFt': True,
#   '5MTHFt2': True,
#   'AACOAT': True,
#   'AACTOOR': False,
#   'AACTtm': False,
#   'AASAD3m': True,
#   'AATAi': True,
#   'ABTArm': True,
#   'ABUTD': True,
#   'ABUTt2r': True,
#   'ABUTt4_2_r': False,
#   'ACACT10m': True,
#   'ACACT1r': True,
#   'ACACt2': True,
#   'ACACt2m': True,
#   'ACETONEt2': True,
#   'ACETONEt2m': True,
#   'ACITL': True,
#   'ACOAD10m': True,
#   'ACOAD9m': True,
#   'ACOAHi': False,
#   'ACONT': True,
#   'ACONTm': True,
#   'ACS': True,
#   'ACSm': True,
#   'ACt2m': False,
#   'ACt2r': True,
#   'ACTLMO': True,
#   'ACTNMO': True,
#   'ACYP': True,
#   'ADCim': False,
#   'ADEt': True,
#   'ADK1': True,
#   'ADK1m': True,
#   'ADK3': False,
#   'ADK3m': True,
#   'ADMDC': True,
#   'ADNK1': True,
#   'ADPT': True,
#   'ADPtx': False,
#   'AGTim': False,
#   'AHC': True,
#   'AKGDm': True,
#   'AKGMALtm': True,
#   'AKGt4_3': False,
#   'ALAASNNaEx': True,
#   'ALACYSNaEx': True,
#   'ALAGLNexR': False,
#   'ALAGLNNaEx': True,
#   'ALAGLYexR': False,
#   'ALASERNaEx': True,
#   'ALAt2r': True,
#   'ALAt4': True,
#   'ALATA_L': True,
#   'ALATHRNaEx': True,
#   'ALAtN1': True,
#   'AMCOXO': False,
#   'AMETt2m': True,
#   'AMPtp': False,
#   'AOBUTDsm': False,
#   'APAT2rm': True,
#   'ARGLYSex': True,
#   'ARGN': True,
#   'ARGNm': True,
#   'ARGt4': False,
#   'ARGtiDF': True,
#   'ARGtm': True,
#   'ASNALANaEx': True,
#   'ASNCYSNaEx': True,
#   'ASNGLNNaEx': True,
#   'ASNS1': True,
#   'ASNSERNaEx': True,
#   'ASNt4': True,
#   'ASNTHRNaEx': True,
#   'ASNtN1': False,
#   'ASPGLUm': True,
#   'ASPTA': True,
#   'ASPTAm': True,
#   'ATP1ter': False,
#   'ATPS4m': True,
#   'ATPtm': True,
#   'ATPtx': False,
#   'BALAtmr': False,
#   'BALAVECSEC': False,
#   'BETALDHxm': False,
#   'BHMT': False,
#   'CATm': True,
#   'CATp': True,
#   'CBPS': True,
#   'CBPSam': False,
#   'CHLtm': False,
#   'CHOLD2m': True,
#   'CHOLt4': False,
#   'CHOLtu': True,
#   'CHSTEROLt': False,
#   'CHSTEROLt1': True,
#   'CHSTEROLt2': False,
#   'CHSTEROLt3': True,
#   'CITL': True,
#   'CITRtm': True,
#   'CITt4_2': False,
#   'CITtam': True,
#   'CITtbm': True,
#   'CK': True,
#   'CKc': True,
#   'CLFORtex': False,
#   'CLHCO3tex2': True,
#   'CLOHtex2': True,
#   'CLOXAtex2': True,
#   'CO2t': False,
#   'CO2ter': True,
#   'CO2tm': True,
#   'COAtm': True,
#   'CREATt4_2_r': True,
#   'CREATtmdiffir': False,
#   'CSm': True,
#   'CTPS1': True,
#   'CTPS2': True,
#   'CYOR_u10m': True,
#   'CYSALANaEx': True,
#   'CYSASNNaEx': True,
#   'CYSGLNNaEx': True,
#   'CYSGLUexR': True,
#   'CYSGLYexR': True,
#   'CYSO': False,
#   'CYSSERNaEx': True,
#   'CYSt4': True,
#   'CYStec': True,
#   'CYSTGL': True,
#   'CYSTHRNaEx': True,
#   'CYSTS': True,
#   'D_3AIBt': False,
#   'D3AIBTm': False,
#   'DATPtn': True,
#   'DCTPtn': True,
#   'DGTPtn': True,
#   'DHPR': True,
#   'ATPM': False,
#   'DMGDHm': True,
#   'DMGtm': False,
#   'DNDPt11m': True,
#   'DNDPt23m': True,
#   'DNDPt24m': True,
#   'DNDPt34m': True,
#   'DNDPt35m': True,
#   'DNDPt9m': True,
#   'DPGase': True,
#   'DPGM': True,
#   'DRBK': True,
#   'DTTPtn': True,
#   'ECOAH12m': True,
#   'ECOAH1m': True,
#   'ECOAH9m': True,
#   'ENO': True,
#   'EX_3aib_e': False,
#   'EX_3aib_D_e': False,
#   'EX_4abut_e': False,
#   'EX_ac_e': False,
#   'EX_acac_e': False,
#   'EX_acetone_e': False,
#   'EX_ade_e': False,
#   'EX_akg_e': False,
#   'EX_ala_B_e': False,
#   'EX_ala_L_e': False,
#   'EX_arg_L_e': True,
#   'EX_asn_L_e': True,
#   'EX_asp_L_e': True,
#   'EX_chol_e': True,
#   'EX_chsterol_e': False,
#   'EX_cit_e': False,
#   'EX_co2_e': False,
#   'EX_creat_e': False,
#   'EX_for_e': True,
#   'EX_glc_e': True,
#   'EX_gln_L_e': True,
#   'EX_glu_L_e': False,
#   'EX_gly_e': True,
#   'EX_glyb_e': False,
#   'EX_gthrd_e': False,
#   'EX_h_e': False,
#   'EX_h2o_e': True,
#   'EX_h2o2_e': False,
#   'EX_hco3_e': False,
#   'EX_his_L_e': True,
#   'EX_hista_e': False,
#   'EX_ile_L_e': True,
#   'EX_lac_L_e': False,
#   'EX_leu_L_e': True,
#   'EX_lys_L_e': True,
#   'EX_met_L_e': True,
#   'EX_mthgxl_e': False,
#   'EX_nh4_e': False,
#   'EX_o2_e': True,
#   'EX_o2s_e': False,
#   'EX_orn_e': False,
#   'EX_phe_L_e': True,
#   'EX_pi_e': True,
#   'EX_pro_L_e': True,
#   'EX_pyr_e': False,
#   'EX_ser_L_e': True,
#   'EX_so4_e': False,
#   'EX_succ_e': True,
#   'EX_thr_L_e': True,
#   'EX_trp_L_e': True,
#   'EX_tyr_L_e': True,
#   'EX_urea_e': True,
#   'EX_val_L_e': True,
#   'FALDtm': False,
#   'FBA': True,
#   'FBP': True,
#   'FDH': False,
#   'FKYNH': True,
#   'FORtr': True,
#   'FTCD': True,
#   'FTHFDH': False,
#   'FUM': True,
#   'FUMAC': True,
#   'FUMm': True,
#   'FUMSO3tm': True,
#   'FUMSO4tm': True,
#   'FUMtm': True,
#   'FUMTSULtm': True,
#   'G3PD1': True,
#   'G3PD2m': True,
#   'G5SADrm': True,
#   'G5SADs': False,
#   'G5SDym': True,
#   'G6PDA': True,
#   'G6PDH1rer': True,
#   'G6PDH2r': True,
#   'G6PDH2rer': True,
#   'G6PPer': True,
#   'G6Pter': True,
#   'GABAVESSEC': False,
#   'GACMTRc': True,
#   'GAPD': True,
#   'GCC2am': False,
#   'GCC2bim': False,
#   'GCC2cm': False,
#   'GCCam': False,
#   'GCCbim': False,
#   'GCCcm': False,
#   'GF6PTA': True,
#   'GHMT2r': True,
#   'GHMT2rm': True,
#   'GK1': True,
#   'GLCMter': False,
#   'GLCt1r': True,
#   'GLCt2_2': False,
#   'GLCt4': True,
#   'GLCter': False,
#   'GLCURter': False,
#   'GLNALANaEx': True,
#   'GLNASNNaEx': True,
#   'GLNCYSNaEx': True,
#   'GLNS': True,
#   'GLNSERNaEx': True,
#   'GLNt4': True,
#   'GLNTHRNaEx': True,
#   'GLNtm': False,
#   'GLNtN1': False,
#   'GLU5Km': True,
#   'GLUCYS': True,
#   'GLUDC': True,
#   'GLUDxm': True,
#   'GLUDym': True,
#   'GluForTx': True,
#   'GLUNm': True,
#   'GLUPRT': True,
#   'GLUt2m': True,
#   'GLUTCOADHm': True,
#   'GLUVESSEC': False,
#   'GLXtm': False,
#   'GLXtp': False,
#   'GLYAMDTRc': False,
#   'GLYATm': True,
#   'GLYBt4_2_r': False,
#   'GLYBtm': False,
#   'GLYC3Ptm': False,
#   'GLYOp': False,
#   'GLYt2r': True,
#   'GLYt4': True,
#   'GLYt7_211_r': True,
#   'GLYtm': True,
#   'GLYtp': False,
#   'GLYVESSEC': False,
#   'GMPS2': True,
#   'GND': True,
#   'GNDer': True,
#   'GNMT': True,
#   'GTHO': True,
#   'GTHOm': True,
#   'GTHP': True,
#   'GTHPm': True,
#   'GTHRDt': True,
#   'GTHS': True,
#   'GULNDer': False,
#   'GULNter': False,
#   'H2CO3D': True,
#   'H2O2syn': True,
#   'H2O2t': False,
#   'H2O2tm': False,
#   'H2O2tp': False,
#   'H2Ot': True,
#   'H2Oter': True,
#   'H2Otm': False,
#   'H2Otp': False,
#   'HACD1m': True,
#   'HACD9m': True,
#   'HCO3_CLt': True,
#   'HEX1': True,
#   'HGNTOR': False,
#   'HIBDm': True,
#   'HISD': False,
#   'HISDC': False,
#   'HISt4': True,
#   'HISTAtu': True,
#   'HISTAVESSEC': False,
#   'HIStiDF': False,
#   'HIStN1': False,
#   'HKYNH': True,
#   'HMGCOASim': True,
#   'HMGCOAtm': True,
#   'HMGLm': True,
#   'HOMt4': True,
#   'Htm': True,
#   'Htr': True,
#   'Htx': False,
#   'ICDHxm': True,
#   'ICDHy': True,
#   'ICDHyrm': True,
#   'ILEt4': False,
#   'ILEt5m': False,
#   'ILETA': False,
#   'ILETAm': True,
#   'ILEtec': True,
#   'IZPN': False,
#   'KCC2t': True,
#   'KYN3OX': False,
#   'KYNAKGAT': True,
#   'KYNATESYN': False,
#   'LDH_L': True,
#   'LEUt4': True,
#   'LEUt5m': False,
#   'LEUTA': False,
#   'LEUTAm': True,
#   'LEUtec': True,
#   'L_LACDcm': True,
#   'L_LACt2r': True,
#   'L_LACt4r': False,
#   'LYSt4': True,
#   'LYStiDF': True,
#   'LYStm': True,
#   'MACACI': True,
#   'MALSO3tm': True,
#   'MALSO4tm': True,
#   'MALtm': True,
#   'MALTSULtm': True,
#   'MCCCrm': True,
#   'MDH': True,
#   'MDHm': True,
#   'ME1m': True,
#   'ME2': True,
#   'ME2m': True,
#   'METAT': True,
#   'METLEUex': True,
#   'METS': True,
#   'METt4': True,
#   'METtec': True,
#   'MGCHrm': True,
#   'MGSA': False,
#   'MGSA2': False,
#   'MMEm': True,
#   'MMMm': True,
#   'MMSAD3m': True,
#   'MMTSADm': False,
#   'MTHFC': True,
#   'MTHFD': True,
#   'MTHGXLt': False,
#   'NADH2_u10m': True,
#   'NADHtpu': False,
#   'NADHtru': False,
#   'NADPHtru': False,
#   'NADPtru': False,
#   'NADtpu': False,
#   'NADtru': False,
#   'NAHCO3_HCLt': True,
#   'NAt': True,
#   'NAt3_1': True,
#   'NAt5': True,
#   'NCCt': False,
#   'NDPK1': True,
#   'NDPK1m': True,
#   'NDPK2': True,
#   'NDPK3': True,
#   'NDPK4': True,
#   'NDPK5': True,
#   'NDPK8': True,
#   'NDPK9': True,
#   'NH4t3r': True,
#   'NH4tp': False,
#   'NKCC2t': True,
#   'NRPPHRt4_2_r': False,
#   'NRPPHRtu': False,
#   'NRPPHRVESSEC': False,
#   'NTD7': True,
#   'O2St': False,
#   'O2Stm': False,
#   'O2Stx': False,
#   'O2t': True,
#   'O2ter': True,
#   'O2tm': True,
#   'O2tp': False,
#   'OBDHc': False,
#   'OCBTm': False,
#   'OIVD1m': True,
#   'OIVD2m': True,
#   'OIVD3m': True,
#   'ORNDC': True,
#   'ORNt3m': True,
#   'ORNt4m': True,
#   'ORNTArm': True,
#   'ORNtiDF': True,
#   'OXAHCOtex': True,
#   'P5CDm': True,
#   'P5CRm': True,
#   'P5CRxm': True,
#   'PCLAD': False,
#   'PCm': True,
#   'PCREATtmdiffir': False,
#   'PDHm': True,
#   'PE_HStm': True,
#   'PEPCK': False,
#   'PEPCKm': True,
#   'PFK': True,
#   'PGCD': True,
#   'PGI': True,
#   'PGK': True,
#   'PGL': True,
#   'PGLer': True,
#   'PGM': True,
#   'PHEt4': True,
#   'PHEtec': True,
#   'PIt7': False,
#   'PIter': True,
#   'PPA': True,
#   'PPAm': True,
#   'PPCOACm': True,
#   'PPCOAOm': True,
#   'PPItr': True,
#   'PPM': True,
#   'PRFGS': True,
#   'PRO1xm': True,
#   'PROD2m': True,
#   'PROt2r': True,
#   'PROt4': True,
#   'PRPNCOAHYDm': True,
#   'PRPPS': True,
#   'PSERT': True,
#   'PSFLIPm': True,
#   'PSP_L': True,
#   'PTRCOX1': True,
#   'PUNP1': True,
#   'PYK': True,
#   'PYRt2m': True,
#   'PYRt2p': True,
#   'PYRt2r': True,
#   'RETNt': False,
#   'RPE': True,
#   'RPI': True,
#   'SACCD3m': True,
#   'SACCD4m': True,
#   'SARCStm': True,
#   'SARDHm': True,
#   'SERALANaEx': True,
#   'SERASNNaEx': True,
#   'SERCYSNaEx': True,
#   'SERGLNexR': False,
#   'SERGLNNaEx': True,
#   'SERGLYexR': False,
#   'SERHL': False,
#   'SERLYSNaex': False,
#   'SERt4': True,
#   'SERTHRNaEx': True,
#   'SERtN1': False,
#   'SO4CLtex2': True,
#   'SO4HCOtex': True,
#   'SO4OXAtex2': True,
#   'SO4t4_2': False,
#   'SPMDOX': False,
#   'SPMS': True,
#   'SPODM': True,
#   'SPODMe': False,
#   'SPODMm': True,
#   'SPODMx': True,
#   'SPRMS': True,
#   'SUCCt2m': True,
#   'SUCCt4_2': True,
#   'SUCD1m': True,
#   'SUCOAS1m': True,
#   'SUCOASm': True,
#   'SULFOX': True,
#   'TALA': True,
#   'THD1m': True,
#   'THRALANaEx': True,
#   'THRASNNaEx': True,
#   'THRCYSNaEx': True,
#   'THRD_L': True,
#   'THRGLNexR': False,
#   'THRGLNNaEx': True,
#   'THRGLYexR': False,
#   'THRSERNaEx': True,
#   'THRt4': True,
#   'TKT1': True,
#   'TKT2': True,
#   'TPI': True,
#   'TRPO2': False,
#   'TRPt': True,
#   'TRPt4': False,
#   'TYRt': True,
#   'TYRt4': False,
#   'TYRTA': True,
#   'UDPGLCAter': True,
#   'UMPK': True,
#   'UMPK2': True,
#   'UMPK3': True,
#   'UMPK4': True,
#   'UMPK5': True,
#   'UMPK7': True,
#   'UMPtr': False,
#   'URCN': False,
#   'UREAt': True,
#   'UREAt5': False,
#   'UREAtm': False,
#   'VALt4': False,
#   'VALt5m': False,
#   'VALTA': False,
#   'VALTAm': True,
#   'VALtec': True,
#   'XYLUR': True,
#   'EX_fald_e': False,
#   'EX_ptrc_e': False,
#   'EX_spmd_e': False,
#   'r0010': True,
#   'r0021': True,
#   'r0022': True,
#   'r0028': True,
#   'r0034': False,
#   'r0055': False,
#   'r0060': False,
#   'r0062': False,
#   'r0074': True,
#   'r0081': True,
#   'r0085': True,
#   'r0086': True,
#   'r0119': True,
#   'r0122': False,
#   'r0127': False,
#   'r0142': True,
#   'r0153': False,
#   'r0156': False,
#   'r0157': False,
#   'r0165': False,
#   'r0173': True,
#   'r0178': True,
#   'r0179': False,
#   'r0191': True,
#   'r0202': False,
#   'r0249': True,
#   'r0280': False,
#   'r0295': True,
#   'r0301': True,
#   'r0317': True,
#   'r0354': True,
#   'r0355': True,
#   'r0365': False,
#   'r0398': True,
#   'r0399': False,
#   'r0413': False,
#   'r0426': True,
#   'r0450': True,
#   'r0464': True,
#   'r0483': True,
#   'r0509': True,
#   'r0525': True,
#   'r0541': True,
#   'r0549': True,
#   'r0552': True,
#   'r0553': True,
#   'r0560': True,
#   'r0570': True,
#   'r0596': True,
#   'r0645': False,
#   'r0647': False,
#   'r0655': True,
#   'r0669': True,
#   'r0683': True,
#   'r0779': True,
#   'r0784': False,
#   'r0792': True,
#   'r0801': True,
#   'r0812': True,
#   'r0817': True,
#   'r0819': True,
#   'r0821': True,
#   'r0822': True,
#   'r0829': True,
#   'r0830': True,
#   'r0838': False,
#   'r0839': False,
#   'r0840': False,
#   'r0841': True,
#   'r0860': False,
#   'r0879': True,
#   'r0881': False,
#   'r0885': True,
#   'r0899': False,
#   'r0911': True,
#   'r0913': True,
#   'r0915': True,
#   'r0917': True,
#   'r0924': False,
#   'r0941': True,
#   'r0942': True,
#   'r0944': False,
#   'r0946': False,
#   'r1030': False,
#   'r1050': False,
#   'r1051': True,
#   'r1052': False,
#   'r1088': False,
#   'r1090': True,
#   'r1109': False,
#   'r1143': False,
#   'r1144': False,
#   'r1147': True,
#   'r1154': True,
#   'r1155': True,
#   'r1162': False,
#   'r1291': False,
#   'r1421': False,
#   'r1427': False,
#   'r1428': False,
#   'r1429': False,
#   'r1434': False,
#   'r1435': True,
#   'r1453': True,
#   'r1454': True,
#   'r1464': False,
#   'r1493': False,
#   'r1530': True,
#   'r1538': False,
#   'r1544': True,
#   'r1546': True,
#   'r1547': True,
#   'r1548': True,
#   'r1549': True,
#   'r1551': True,
#   'r1552': True,
#   'r1553': True,
#   'r1554': True,
#   'r1556': True,
#   'r1557': True,
#   'r1559': True,
#   'r1560': True,
#   'r1561': True,
#   'r1562': True,
#   'r1563': True,
#   'r1564': True,
#   'r1565': True,
#   'r1566': True,
#   'r1567': True,
#   'r1568': True,
#   'r1569': True,
#   'r1570': True,
#   'r1571': True,
#   'r1573': True,
#   'r1574': True,
#   'r1575': True,
#   'r1576': True,
#   'r1578': True,
#   'r1579': True,
#   'r1580': True,
#   'r1581': True,
#   'r1583': True,
#   'r1584': True,
#   'r1585': True,
#   'r1586': True,
#   'r1587': True,
#   'r1588': True,
#   'r1589': True,
#   'r1590': True,
#   'r1591': True,
#   'r1592': True,
#   'r1593': True,
#   'r1594': True,
#   'r1595': True,
#   'r1596': True,
#   'r1597': True,
#   'r1598': True,
#   'r1599': True,
#   'r1600': True,
#   'r1602': True,
#   'r1603': True,
#   'r1604': True,
#   'r1605': True,
#   'r1606': True,
#   'r1607': True,
#   'r1608': True,
#   'r1609': True,
#   'r1610': True,
#   'r1611': True,
#   'r1612': True,
#   'r1613': True,
#   'r1614': True,
#   'r1615': True,
#   'r1616': True,
#   'r1617': True,
#   'r1618': True,
#   'r1619': True,
#   'r1620': True,
#   'r1621': True,
#   'r1622': True,
#   'r1623': True,
#   'r1624': True,
#   'r1625': True,
#   'r1626': True,
#   'r1627': True,
#   'r1628': True,
#   'r1629': True,
#   'r1630': True,
#   'r1631': True,
#   'r1632': True,
#   'r1633': True,
#   'r1634': True,
#   'r1635': True,
#   'r1636': True,
#   'r1637': True,
#   'r1638': True,
#   'r1639': True,
#   'r1640': True,
#   'r1641': True,
#   'r1642': True,
#   'r1643': True,
#   'r1644': True,
#   'r1645': True,
#   'r1646': True,
#   'r1647': True,
#   'r1648': True,
#   'r1649': True,
#   'r1650': True,
#   'r1651': True,
#   'r1652': True,
#   'r1653': True,
#   'r1654': True,
#   'r1655': True,
#   'r1656': True,
#   'r1657': True,
#   'r1658': True,
#   'r1659': True,
#   'r1660': True,
#   'r1661': True,
#   'r1662': True,
#   'r1664': True,
#   'r1665': True,
#   'r1666': True,
#   'r1667': True,
#   'r1668': True,
#   'r1669': True,
#   'r1670': True,
#   'r1671': True,
#   'r1672': True,
#   'r1673': True,
#   'r1674': True,
#   'r1675': True,
#   'r1676': True,
#   'r1677': True,
#   'r1678': True,
#   'r1679': True,
#   'r1680': True,
#   'r1681': True,
#   'r1682': True,
#   'r1683': True,
#   'r1684': True,
#   'r1685': True,
#   'r1686': True,
#   'r1687': True,
#   'r1690': True,
#   'r1691': True,
#   'r1692': True,
#   'r1693': True,
#   'r1695': True,
#   'r1696': True,
#   'r1698': True,
#   'r1700': True,
#   'r1701': True,
#   'r1702': True,
#   'r1705': True,
#   'r1706': True,
#   'r1707': True,
#   'r1708': True,
#   'r1710': True,
#   'r1711': True,
#   'r1713': True,
#   'r1715': True,
#   'r1716': True,
#   'r1717': True,
#   'r1720': True,
#   'r1721': True,
#   'r1722': True,
#   'r1723': True,
#   'r1725': True,
#   'r1726': True,
#   'r1728': True,
#   'r1730': True,
#   'r1731': True,
#   'r1732': True,
#   'r1733': True,
#   'r1734': True,
#   'r1735': True,
#   'r1736': True,
#   'r1737': True,
#   'r1738': True,
#   'r1739': True,
#   'r1740': True,
#   'r1741': True,
#   'r1742': True,
#   'r1743': True,
#   'r1744': True,
#   'r1745': True,
#   'r1746': True,
#   'r1747': True,
#   'r1748': True,
#   'r1749': True,
#   'r1750': True,
#   'r1751': True,
#   'r1752': True,
#   'r1753': True,
#   'r1754': True,
#   'r1755': True,
#   'r1756': True,
#   'r1757': True,
#   'r1758': True,
#   'r1759': True,
#   'r1760': True,
#   'r1761': True,
#   'r1762': True,
#   'r1763': True,
#   'r1764': True,
#   'r1765': True,
#   'r1766': True,
#   'r1767': True,
#   'r1768': True,
#   'r1769': True,
#   'r1770': True,
#   'r1771': True,
#   'r1772': True,
#   'r1773': True,
#   'r1774': True,
#   'r1775': True,
#   'r1776': True,
#   'r1777': True,
#   'r1778': True,
#   'r1779': True,
#   'r1780': True,
#   'r1781': True,
#   'r1782': True,
#   'r1783': True,
#   'r1784': True,
#   'r1785': True,
#   'r1786': True,
#   'r1787': True,
#   'r1788': True,
#   'r1789': True,
#   'r1790': True,
#   'r1791': True,
#   'r1792': True,
#   'r1796': True,
#   'r1797': True,
#   'r1798': True,
#   'r1799': True,
#   'r1800': True,
#   'r1801': True,
#   'r1803': True,
#   'r1805': True,
#   'r1806': True,
#   'r1807': True,
#   'r1808': True,
#   'r1809': True,
#   'r1810': True,
#   'r1811': True,
#   'r1812': True,
#   'r1813': True,
#   'r1814': True,
#   'r1815': True,
#   'r1816': True,
#   'r1817': True,
#   'r1818': True,
#   'r1819': True,
#   'r1820': True,
#   'r1821': True,
#   'r1822': True,
#   'r1823': True,
#   'r1824': True,
#   'r1825': True,
#   'r1826': True,
#   'r1827': True,
#   'r1828': True,
#   'r1829': True,
#   'r1830': True,
#   'r1831': True,
#   'r1832': True,
#   'r1833': True,
#   'r1834': True,
#   'r1835': True,
#   'r1836': True,
#   'r1837': True,
#   'r1841': True,
#   'r1842': True,
#   'r1843': True,
#   'r1844': True,
#   'r1846': True,
#   'r1847': True,
#   'r1848': True,
#   'r1850': True,
#   'r1851': True,
#   'r1852': True,
#   'r1853': True,
#   'r1854': True,
#   'r1855': True,
#   'r1856': True,
#   'r1857': True,
#   'r1858': True,
#   'r1859': True,
#   'r1860': True,
#   'r1861': True,
#   'r1862': True,
#   'r1863': True,
#   'r1864': True,
#   'r1865': True,
#   'r1866': True,
#   'r1867': True,
#   'r1871': True,
#   'r1872': True,
#   'r1873': True,
#   'r1874': True,
#   'r1876': True,
#   'r1877': True,
#   'r1879': True,
#   'r1880': True,
#   'r1881': True,
#   'r1882': True,
#   'r1883': True,
#   'r1884': True,
#   'r1885': True,
#   'r1886': True,
#   'r1887': True,
#   'r1888': True,
#   'r1889': True,
#   'r1890': True,
#   'r1891': True,
#   'r1892': True,
#   'r1893': True,
#   'r1894': True,
#   'r1895': True,
#   'r1896': True,
#   'r1897': True,
#   'r1898': True,
#   'r1899': True,
#   'r1900': True,
#   'r1901': True,
#   'r1902': True,
#   'r1903': True,
#   'r1904': True,
#   'r1905': True,
#   'r1906': True,
#   'r1907': True,
#   'r1908': True,
#   ...}}

# %%
reconstructed_models = {c: sbml_model_reconstruction(model, res) for c, res in results.items()}
reconstructed_models
# Out:
# C:\Users\biosy\anaconda3\envs\s2m2\lib\site-packages\cobra\core\group.py:147: UserWarning: need to pass in a list
#   warn("need to pass in a list")
# Model Objective: Maximize
# 1.0*biomass - 1.0*biomass_reverse_01e59
# Objective Production: <Solution 0.035 at 0x19236605508>
# Model reconstruction finished.
# Model Objective: Maximize
# 1.0*biomass - 1.0*biomass_reverse_01e59
# Objective Production: <Solution 0.035 at 0x192325c0ec8>
# Model reconstruction finished.
# Model Objective: Maximize
# 1.0*biomass - 1.0*biomass_reverse_01e59
# Objective Production: <Solution 0.035 at 0x19234743ec8>
# Model reconstruction finished.
# {'ACH-000017': <Model Reconstructed Model at 0x192382e8688>,
#  'ACH-000019': <Model Reconstructed Model at 0x19238022c48>,
#  'ACH-000028': <Model Reconstructed Model at 0x192325cb548>}
