# %% [markdown]
# ### Exercise 1

# %%
import cobra

# %%
model = cobra.io.read_sbml_model('MODEL1612130000_url.xml')
# Out:
# Model does not contain SBML fbc package information.
# SBML package 'layout' not supported by cobrapy, information is not parsed
# SBML package 'render' not supported by cobrapy, information is not parsed
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_oligoP_v "oligophosphate (5-P)">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_polyP_v "polyphosphate (100-P)">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_h2o_v "H2O">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_h2o_c "H2O">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_ppi_c "Diphosphate">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_h_c "H+">
# ...

# %%
sim_fba = model.optimize()

# %%
import escher

# %%
builder = escher.Builder(map_name = 'iMM904.Central carbon metabolism')
builder.model = model

# %%
builder.reaction_data = sim_fba.fluxes
builder
# Out:
# Builder(reaction_data={'ADPtn': 0.0, 'ATPtn': 0.0, 'FACOAE140': 0.002870681850565546, 'FACOAL260': 0.0, 'GLCte…

# %%
cobra.io.sbml.read_sbml_model?

# %%
import cplex

# %% [markdown]
# Let's start by reading the model using COBRApy package

# %% [markdown]
# a) Open the model in Python using the load_matlab_model() function

# %%
import cobra
model = cobra.io.load_matlab_model("models/redHUMAN_recon2_smin.mat")

# %% [markdown]
# b) Get the information about the biomass and PFK reactions, ATP metabolite in cytosol and glucose metabolite in the extracellular space

# %%
model.reactions.biomass
# Out:
# <Reaction biomass at 0x7f5b220036d0>

# %%
model.reactions.PFK
# Out:
# <Reaction PFK at 0x7f5b22146a10>

# %%
model.metabolites.atp_c
# Out:
# <Metabolite atp_c at 0x7f5b2ae3ced0>

# %%
model.metabolites.glc_D_e
# Out:
# <Metabolite glc_D_e at 0x7f5b2e3af110>

# %% [markdown]
# c) Run FBA for the model

# %%
sim_fba = model.optimize()
model.summary(sim_fba)
# Out:
# <h3>Objective</h3><p>1.0 biomass = 0.03536465206938496</p><h4>Uptake</h4><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Metabolite</th>
#       <th>Reaction</th>
#       <th>Flux</th>
#       <th>C-Number</th>
#       <th>C-Flux</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>arg_L_e</td>
#       <td>EX_arg_L_e</td>
#       <td>0.01271</td>
#       <td>6</td>
#       <td>3.67%</td>
#     </tr>
#     <tr>
#       <td>chol_e</td>
#       <td>EX_chol_e</td>
#       <td>0.007434</td>
#       <td>5</td>
#       <td>1.79%</td>
#     </tr>
#     <tr>
#       <td>glc_D_e</td>
#       <td>EX_glc_e</td>
#       <td>0.04075</td>
#       <td>6</td>
#       <td>11.77%</td>
#     </tr>
#     <tr>
#       <td>gln_L_e</td>
#       <td>EX_gln_L_e</td>
#       <td>0.05305</td>
#       <td>5</td>
#       <td>12.77%</td>
#     </tr>
#     <tr>
#       <td>gly_e</td>
#       <td>EX_gly_e</td>
#       <td>0.003116</td>
# ...

# %% [markdown]
# d) Run pFBA for the model. What are the main differences between the two optimizations (fluxes, reactions, metabolites)?

# %%
sim_pfba = cobra.flux_analysis.pfba(model)
model.summary(sim_pfba)
# Out:
# <h3>Objective</h3><p>1.0 biomass = 0.03536465206938496</p><h4>Uptake</h4><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Metabolite</th>
#       <th>Reaction</th>
#       <th>Flux</th>
#       <th>C-Number</th>
#       <th>C-Flux</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>arg_L_e</td>
#       <td>EX_arg_L_e</td>
#       <td>0.02576</td>
#       <td>6</td>
#       <td>8.23%</td>
#     </tr>
#     <tr>
#       <td>asn_L_e</td>
#       <td>EX_asn_L_e</td>
#       <td>0.01202</td>
#       <td>4</td>
#       <td>2.56%</td>
#     </tr>
#     <tr>
#       <td>asp_L_e</td>
#       <td>EX_asp_L_e</td>
#       <td>0.009781</td>
#       <td>4</td>
#       <td>2.08%</td>
#     </tr>
#     <tr>
#       <td>chol_e</td>
#       <td>EX_chol_e</td>
#       <td>0.006081</td>
#       <td>5</td>
#       <td>1.62%</td>
#     </tr>
#     <tr>
#       <td>glc_D_e</td>
#       <td>EX_glc_e</td>
#       <td>0.05401</td>
# ...

# %% [markdown]
# Biomass is the same. The C-flux between uptake reactions are different, alongside with their fluxes. Hydrogen is not consumed in the pFBA simulation. Formaldehyde is not secreted on the pFBA simulation. There is a shift of C-Flux of secreted metabolite, since in pFBA is mostly in the form of HCO3 and in the FBA simulation is in HCO3 (-30%), lactate and putrescine.

# %% [markdown]
# e) Knockout the drain associated with **glucose**. Optimize the model with FBA and pFBA. What happens?

# %%
model_wo_glc = model.copy()
model_wo_glc.reactions.EX_glc_e.bounds = [0.0,0.0]
model_wo_glc.reactions.EX_glc_e.bounds
# Out:
# (0.0, 0.0)

# %%
model_wo_glc.summary(model_wo_glc.optimize())
# Out:
# <h3>Objective</h3><p>1.0 biomass = 0.03536465206938496</p><h4>Uptake</h4><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Metabolite</th>
#       <th>Reaction</th>
#       <th>Flux</th>
#       <th>C-Number</th>
#       <th>C-Flux</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>arg_L_e</td>
#       <td>EX_arg_L_e</td>
#       <td>0.0752</td>
#       <td>6</td>
#       <td>7.10%</td>
#     </tr>
#     <tr>
#       <td>asn_L_e</td>
#       <td>EX_asn_L_e</td>
#       <td>0.01511</td>
#       <td>4</td>
#       <td>0.95%</td>
#     </tr>
#     <tr>
#       <td>asp_L_e</td>
#       <td>EX_asp_L_e</td>
#       <td>0.009781</td>
#       <td>4</td>
#       <td>0.62%</td>
#     </tr>
#     <tr>
#       <td>chol_e</td>
#       <td>EX_chol_e</td>
#       <td>0.006081</td>
#       <td>5</td>
#       <td>0.48%</td>
#     </tr>
#     <tr>
#       <td>cit_e</td>
#       <td>EX_cit_e</td>
#       <td>0.0006654</td>
# ...

# %%
model_wo_glc.summary(cobra.flux_analysis.pfba(model_wo_glc))
# Out:
# <h3>Objective</h3><p>1.0 biomass = 0.03536465206938496</p><h4>Uptake</h4><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Metabolite</th>
#       <th>Reaction</th>
#       <th>Flux</th>
#       <th>C-Number</th>
#       <th>C-Flux</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>ala_L_e</td>
#       <td>EX_ala_L_e</td>
#       <td>0.01375</td>
#       <td>3</td>
#       <td>2.24%</td>
#     </tr>
#     <tr>
#       <td>arg_L_e</td>
#       <td>EX_arg_L_e</td>
#       <td>0.01783</td>
#       <td>6</td>
#       <td>5.81%</td>
#     </tr>
#     <tr>
#       <td>asn_L_e</td>
#       <td>EX_asn_L_e</td>
#       <td>0.009882</td>
#       <td>4</td>
#       <td>2.15%</td>
#     </tr>
#     <tr>
#       <td>asp_L_e</td>
#       <td>EX_asp_L_e</td>
#       <td>0.009781</td>
#       <td>4</td>
#       <td>2.12%</td>
#     </tr>
#     <tr>
#       <td>chol_e</td>
#       <td>EX_chol_e</td>
#       <td>0.006081</td>
# ...

# %% [markdown]
# Biomass is the same. There is a shift in the secretion of the C, FBA uses CO2 to do it, in the pFBA it goes again with the HCO3. The drain for the glucose has disappeared from both cases, as expected. Aspartate and threonine is being consumed in the pFBA and not in the FBA.

# %% [markdown]
# f) Find he essential reactions for the model after knocking out the previous reactions. What are the differences when compared to the "regular" model?

# %%
essential_normal = cobra.flux_analysis.find_essential_reactions(model)
essential_wo_glc = cobra.flux_analysis.find_essential_reactions(model_wo_glc)

# %% [markdown]
# (Have to make this, since there are two different model with different memory addresses)

# %%
set([e.id for e in essential_wo_glc]) - set([e.id for e in essential_normal])
# Out:
# {'ENO', 'FBA', 'FBP', 'GAPD', 'PGI', 'PGK', 'PGM', 'TPI'}

# %% [markdown]
# There are 7 different essential reactions

# %%
import escher
builder = escher.Builder(map_name='RECON1.Glycolysis TCA PPP')
builder.model = model

# %% [markdown]
# ### Exercise 2

# %% [markdown]
# You have to download the .csv file containing the information for breast cancer cell lines present in the CCLE panel. The nomenclature has been normalized for what is found in the metabolic model of this exercise.

# %% [markdown]
# a) Read the file containing the information with the *pandas* package

# %%
import pandas as pd
df_expression = pd.read_csv('data/CCLE_breast_cancer_expression.csv', index_col=0)
df_info = pd.read_csv('data/CCLE_breast_cancer_info.csv', index_col=0)

# %%
df_expression
# Out:
#                10165      6514     51557        47      6563      3421  \
# DepMap_ID
# ACH-000017  5.380591  0.000000  0.056584  7.664483  0.111031  6.116240
# ACH-000019  4.358256  0.000000  0.014355  6.361944  0.097611  6.730776
# ACH-000028  4.808385  0.000000  0.000000  6.352441  0.070389  6.647171
# ACH-000044  3.555816  0.000000  0.000000  5.169123  2.505891  5.816856
# ACH-000097  4.288359  0.000000  0.014355  6.190417  0.137504  5.934517
# ACH-000111  4.495695  0.028569  0.014355  7.096241  0.344828  6.041550
# ACH-000117  4.098453  0.000000  0.028569  5.948601  0.250962  6.443607
# ACH-000147  3.982765  0.014355  0.014355  7.229300  0.163499  5.130107
# ACH-000148  2.629939  0.028569  0.000000  7.282440  0.056584  5.712321
# ACH-000196  4.001802  0.137504  0.000000  7.210428  0.056584  4.609991
# ACH-000212  3.890447  0.000000  0.000000  6.742949  3.680324  5.783719
# ACH-000223  3.196922  0.000000  0.000000  6.202614  0.137504  5.288359
# ...

# %% [markdown]
# b) Calculate the mean for 3 different genes

# %%
df_expression.loc[:,['10165','6514', '51557']].mean()
# Out:
# 10165    4.292774
# 6514     0.007298
# 51557    0.081124
# dtype: float64

# %%
df_expression.loc[:,df_expression.columns[:20]].plot(kind='box')

# %% [markdown]
# c) Select the samples 'ACH-000019', 'ACH-000028', 'ACH-000349'. With them, reconstruct a tissue model for each of them with FastCORE algorithm. Perform FBA and pFBA for all the 3 samples reconstructed. Highlight the main differences between them.

# %%
from troppo.omics.readers.generic import TabularReader
from troppo.methods_wrappers import ReconstructionWrapper
from numpy import linspace
from cobamp.gpr.core import GPR_GENE_RE
import re
patt = re.compile('__COBAMPGPRDOT__[0-9]{1}')
replace_alt_transcripts = lambda x: patt.sub('',x)
threshold = 15
def integration_fx(data_map):
    return [[k for k, v in data_map.get_scores().items() if
             (v is not None and v > threshold) or k in ['biomass']]]

# %%
tab_rdr = TabularReader(path_or_df=df_expression, nomenclature='entrez_id', omics_type='transcriptomics', cache_df=True)
ocs = tab_rdr.to_containers()
# Out:
# The new ID designation is incorrect, must be one of the following:
#  ['hgnc_id', 'symbol', 'name', 'locus_group', 'locus_type', 'status', 'location', 'location_sortable', 'alias_symbol', 'alias_name', 'prev_symbol', 'prev_name', 'gene_family', 'gene_family_id', 'date_approved_reserved', 'date_symbol_changed', 'date_name_changed', 'date_modified', 'entrez_id', 'ensembl_gene_id', 'vega_id', 'ucsc_id', 'ena', 'refseq_accession', 'ccds_id', 'uniprot_ids', 'pubmed_id', 'mgd_id', 'rgd_id', 'lsdb', 'cosmic', 'omim_id', 'mirbase', 'homeodb', 'snornabase', 'bioparadigms_slc', 'orphanet', 'pseudogene.org', 'horde_id', 'merops', 'imgt', 'iuphar', 'kznf_gene_catalog', 'mamit-trnadb', 'cd', 'lncrnadb', 'enzyme_id', 'intermediate_filament_db', 'rna_central_ids', 'lncipedia', 'gtrnadb', 'agr', 'mane_select']

# %%
samples = ['ACH-000019', 'ACH-000028', 'ACH-000349']

# %%
oc_sample = [oc for oc in ocs if oc.get_Condition() in samples]

# %%
oc_sample = []
for container in ocs:
    if container.get_Condition() in samples:
        oc_sample.append(container)

# %%
for container in oc_sample:
    print(container.get_Condition())
# Out:
# ACH-000019
# ACH-000028
# ACH-000349

# %%
rw = ReconstructionWrapper(model, ttg_ratio=9999, gpr_gene_parse_function = replace_alt_transcripts)

# %%
model.genes
# Out:
# [<Gene 10993.1 at 0x7f0eafd185d0>,
#  <Gene 89874.1 at 0x7f0eafd18750>,
#  <Gene 57835.1 at 0x7f0eafd18850>,
#  <Gene 57835.2 at 0x7f0eafd18a50>,
#  <Gene 57835.4 at 0x7f0eafd18ad0>,
#  <Gene 57835.3 at 0x7f0eafd18b50>,
#  <Gene 8671.1 at 0x7f0eafd187d0>,
#  <Gene 4967.1 at 0x7f0eafd18a90>,
#  <Gene 8050.1 at 0x7f0eafd18910>,
#  <Gene 1738.1 at 0x7f0eafd18b10>,
#  <Gene 1743.1 at 0x7f0eafd18f90>,
#  <Gene 4967.2 at 0x7f0eafd18fd0>,
#  <Gene 3242.1 at 0x7f0eafd18f10>,
#  <Gene 18.2 at 0x7f0eafd20150>,
#  <Gene 18.1 at 0x7f0eafd20250>,
#  <Gene 23498.1 at 0x7f0eafd18b90>,
#  <Gene 51166.1 at 0x7f0eafd20890>,
#  <Gene 883.1 at 0x7f0eafd20550>,
#  <Gene 51166.2 at 0x7f0eafd20850>,
#  <Gene 8604.1 at 0x7f0eafd20b10>,
#  <Gene 10165.1 at 0x7f0eafd20b50>,
#  <Gene 2805.1 at 0x7f0eafd20910>,
#  <Gene 2806.1 at 0x7f0eafd20d90>,
#  <Gene 2348.1 at 0x7f0eafd20e10>,
#  <Gene 2352.1 at 0x7f0eafd2f610>,
#  <Gene 2348.3 at 0x7f0eafd2f050>,
#  <Gene 2348.2 at 0x7f0eafd2f310>,
# ...

# %%
r_models = {}
for sample in oc_sample:
    r_models[sample.get_Condition()] = rw.run_from_omics(omics_data = sample, algorithm = 'fastcore', and_or_funcs=(min,sum), integration_strategy=('custom', [integration_fx]), solver='GLPK')
# Out:
# J size19
# [  74   94  101  102  279  303  314  315  364  389  427  456  463  470
#   478  504  534 1271 1336]
# before LP7
# LP7
# -0.0019000000000000006
# done LP7
# LP9
# 3484.4448449191686
# done LP9
# 5 224
# before LP7
# LP7
# -0.00030000000000000003
# done LP7
# LP9
# 72.5
# done LP9
# 5 235
# before LP7
# LP7
# 0.0
# done LP7
# 2 235
# Flipped
# before LP7
# LP7
# -0.0002
# done LP7
# LP9
# 80.0
# done LP9
# 2 246
# 0 246
# J size13
# [  74  102  314  315  364  389  427  456  463  470  478 1271 1336]
# before LP7
# LP7
# -0.0013000000000000004
# done LP7
# LP9
# 3526.2034090199936
# done LP9
# 5 224
# before LP7
# LP7
# -0.00030000000000000003
# done LP7
# LP9
# 42.500000000001364
# done LP9
# 5 235
# before LP7
# LP7
# 0.0
# done LP7
# 2 235
# Flipped
# before LP7
# LP7
# -0.0002
# done LP7
# LP9
# 80.0
# done LP9
# 2 245
# 0 245
# J size13
# [  74  101  102  314  315  364  389  427  463  470  478 1271 1336]
# before LP7
# LP7
# -0.0013000000000000004
# done LP7
# LP9
# ...

# %%
len([name_reaction for name_reaction,value in r_models['ACH-000349'].items() if value is True])
# Out:
# 1008

# %%
with model as test_model:
    reactions_to_deactivate = [name_reaction for name_reaction,value in r_models['ACH-000349'].items() if value is False]
    for r in reactions_to_deactivate:
        test_model.reactions.get_by_id(r).bounds = [0.0,0.0]
    solution_fba = test_model.optimize()
    solution_pfba = cobra.flux_analysis.pfba(test_model)

# %%
model.summary(solution_fba)
# Out:
# <h3>Objective</h3><p>1.0 biomass = 0.03536465206938496</p><h4>Uptake</h4><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Metabolite</th>
#       <th>Reaction</th>
#       <th>Flux</th>
#       <th>C-Number</th>
#       <th>C-Flux</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>arg_L_e</td>
#       <td>EX_arg_L_e</td>
#       <td>0.02592</td>
#       <td>6</td>
#       <td>2.11%</td>
#     </tr>
#     <tr>
#       <td>asn_L_e</td>
#       <td>EX_asn_L_e</td>
#       <td>0.009882</td>
#       <td>4</td>
#       <td>0.54%</td>
#     </tr>
#     <tr>
#       <td>chol_e</td>
#       <td>EX_chol_e</td>
#       <td>0.006081</td>
#       <td>5</td>
#       <td>0.41%</td>
#     </tr>
#     <tr>
#       <td>glc_D_e</td>
#       <td>EX_glc_e</td>
#       <td>0.9056</td>
#       <td>6</td>
#       <td>73.75%</td>
#     </tr>
#     <tr>
#       <td>gln_L_e</td>
#       <td>EX_gln_L_e</td>
#       <td>0.1598</td>
# ...

# %%
model.summary(solution_pfba)
# Out:
# <h3>Objective</h3><p>1.0 biomass = 0.03536465206938496</p><h4>Uptake</h4><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Metabolite</th>
#       <th>Reaction</th>
#       <th>Flux</th>
#       <th>C-Number</th>
#       <th>C-Flux</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>arg_L_e</td>
#       <td>EX_arg_L_e</td>
#       <td>0.01435</td>
#       <td>6</td>
#       <td>2.23%</td>
#     </tr>
#     <tr>
#       <td>asn_L_e</td>
#       <td>EX_asn_L_e</td>
#       <td>0.009882</td>
#       <td>4</td>
#       <td>1.02%</td>
#     </tr>
#     <tr>
#       <td>chol_e</td>
#       <td>EX_chol_e</td>
#       <td>0.006081</td>
#       <td>5</td>
#       <td>0.79%</td>
#     </tr>
#     <tr>
#       <td>glc_D_e</td>
#       <td>EX_glc_e</td>
#       <td>0.4008</td>
#       <td>6</td>
#       <td>62.26%</td>
#     </tr>
#     <tr>
#       <td>gln_L_e</td>
#       <td>EX_gln_L_e</td>
#       <td>0.02527</td>
# ...

# %% [markdown]
# d) Try to reproduce the Warburg Effect (if already not present). Hint: Change the uptake of the oxygen drain to a small value, or a bigger one, if the effect is already present.

# %%
builder.reaction_data = solution_pfba.fluxes
builder
# Out:
# Builder(allow_building_duplicate_reactions=False, and_method_in_gene_reaction_rule='mean', cofactors=['atp', '…

# %% [markdown]
# e) Select another random sample. Reconstruct 3 models with different thresholds. What are the main differences?

# %%
threshold = 7

# %%
model.reactions
# Out:
# {}
